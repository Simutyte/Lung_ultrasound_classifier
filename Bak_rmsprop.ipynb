# %%
import torch
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import torchvision.transforms.functional as TF
import shutil
import math
from torch.utils.data import DataLoader
import torch.utils.data as data
from datetime import datetime
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# #Images

# %%
# !git clone https://github.com/BorgwardtLab/covid19_ultrasound.git
# !cd covid19_ultrasound/pocovidnet/
# !pip install -e .
# Out:
# Cloning into 'covid19_ultrasound'...
# remote: Enumerating objects: 4531, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 4531 (delta 37), reused 29 (delta 10), pack-reused 4453
# Receiving objects: 100% (4531/4531), 165.49 MiB | 13.23 MiB/s, done.
# Resolving deltas: 100% (369/369), done.
# Updating files: 100% (3873/3873), done.
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
#copy data folder for further work
# !cp -r /content/covid19_ultrasound/data /content/

# %%
#check how many files are in each folder (images or video files)
# !ls -1 /content/data/pocus_images/convex | wc -l
# !ls -1 /content/data/pocus_images/linear | wc -l
# !ls -1 /content/data/pocus_videos/convex | wc -l
# !ls -1 /content/data/pocus_videos/linear | wc -l
# Out:
# 29
# 3
# 124
# 11

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Get the files used by the authors of the dataset, with some modifications (mostly path fixes)
file_names = ['crop.json', 'crop_processed_data.py', 'get_and_process_web_data.sh', 'build_image_dataset.py', 'cross_val_splitter.py']

# define source and destination path
source_folder = '/content/drive/MyDrive/Bakis'
destination_folder = '/content/'

# Copy the files
for file_name in file_names:
    source_path = os.path.join(source_folder, file_name)
    destination_path = os.path.join(destination_folder, file_name)
    if os.path.isfile(source_path):
        shutil.copy(source_path, destination_path)

# %%
#Files from web
# !cd covid19_ultrasound/data
# !sh /content/get_and_process_web_data.sh
# Out:
# youtube-dl could not be found, installing now..
# --2024-05-23 08:08:24--  https://yt-dl.org/downloads/latest/youtube-dl
# Resolving yt-dl.org (yt-dl.org)... 95.143.172.170, 2001:1a50:11:0:5f:8f:acaa:177
# Connecting to yt-dl.org (yt-dl.org)|95.143.172.170|:443... connected.
# HTTP request sent, awaiting response... 451 Unavailable For Legal Reasons
# 2024-05-23 08:08:27 ERROR 451: Unavailable For Legal Reasons.
#
# Grabbing data now..
# --2024-05-23 08:08:27--  https://clarius.com/wp-content/uploads/2020/03/1-blines.gif
# Resolving clarius.com (clarius.com)... 172.67.72.226, 104.26.9.204, 104.26.8.204, ...
# Connecting to clarius.com (clarius.com)|172.67.72.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10635005 (10M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Cov-clarius.gif’
#
# tmp/pocus_videos/co 100%[===================>]  10.14M  8.33MB/s    in 1.2s
#
# 2024-05-23 08:08:29 (8.33 MB/s) - ‘tmp/pocus_videos/convex/Cov-clarius.gif’ saved [10635005/10635005]
#
# --2024-05-23 08:08:29--  https://clarius.com/wp-content/uploads/2020/03/3-large-consolidation.gif
# Resolving clarius.com (clarius.com)... 172.67.72.226, 104.26.9.204, 104.26.8.204, ...
# Connecting to clarius.com (clarius.com)|172.67.72.226|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1061108 (1.0M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Reg-nephropocus.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.01M  --.-KB/s    in 0.09s
#
# 2024-05-23 08:08:35 (11.9 MB/s) - ‘tmp/pocus_videos/convex/Reg-nephropocus.gif’ saved [1061108/1061108]
#
# --2024-05-23 08:08:35--  https://www.bcpocus.ca/wp-content/uploads/2018/07/A-lines.gif
# Resolving www.bcpocus.ca (www.bcpocus.ca)... 104.152.168.41
# Connecting to www.bcpocus.ca (www.bcpocus.ca)|104.152.168.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1311393 (1.2M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Reg-bcpocus.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.25M  1.04MB/s    in 1.2s
#
# 2024-05-23 08:08:38 (1.04 MB/s) - ‘tmp/pocus_videos/convex/Reg-bcpocus.gif’ saved [1311393/1311393]
#
# /content/get_and_process_web_data.sh: 25: ab: not found
# /content/get_and_process_web_data.sh: 26: ab: not found
# /content/get_and_process_web_data.sh: 27: ab: not found
# --2024-05-23 08:08:38--  https://images.squarespace-cdn.com/content/v1/5c69e7d7b91449698da66e65/1590627160853-3ULNVXBBJD5LVR930CU1/ke17ZwdGBToddI8pDm48kI8YiP-OhoX1jaED3zwYDitZw-zPPgdn4jUwVcJE1ZvWQUxwkmyExglNqGp0IvTJZUJFbgE-7XRK3dMEBRBhUpw0zQBx-_xluAT7IF9HiONY7KDc7zDddqX0ywCRyjQsO3pixv1ek7N_oX80uiIUqvU/LungPoint.ezgif.gif?format=750w
# Resolving images.squarespace-cdn.com (images.squarespace-cdn.com)... 151.101.0.238, 151.101.64.238, 151.101.128.238, ...
# Connecting to images.squarespace-cdn.com (images.squarespace-cdn.com)|151.101.0.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15815746 (15M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-nephropocus.gif’
#
# tmp/pocus_videos/li 100%[===================>]  15.08M  79.8MB/s    in 0.2s
#
# 2024-05-23 08:08:39 (79.8 MB/s) - ‘tmp/pocus_videos/linear/Reg-nephropocus.gif’ saved [15815746/15815746]
#
# --2024-05-23 08:08:39--  https://i0.wp.com/criticalcarenorthampton.com/wp-content/uploads/2016/11/normal-lung.gif?resize=480,360
# --2024-05-23 08:08:39--  https://i0.wp.com/criticalcarenorthampton.com/wp-content/uploads/2016/11/pneumothorax-case-3-litfl-ultrasound-clinical-cases.gif?resize=480,360
# --2024-05-23 08:08:39--  https://hls.cf.brightcove.com/1611106596001/4304256093001/1611106596001_4304256093001_s-1.ts?pubId=1611106596001&videoId=4304084884001
# Resolving i0.wp.com (i0.wp.com)... Resolving i0.wp.com (i0.wp.com)... Resolving hls.cf.brightcove.com (hls.cf.brightcove.com)... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... connected.
# connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... failed: Name or service not known.
# wget: unable to resolve host address ‘hls.cf.brightcove.com’
# --2024-05-23 08:08:39--  https://f1.media.brightcove.com/3/1611106596001/4304256034001/1611106596001_4304256034001_s-1.ts?pubId=1611106596001&videoId=4304052567001
# Resolving f1.media.brightcove.com (f1.media.brightcove.com)... 151.101.2.27, 151.101.66.27, 151.101.130.27, ...
# Connecting to f1.media.brightcove.com (f1.media.brightcove.com)|151.101.2.27|:443... 200 OK
# Length: 4468440 (4.3M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-minimalmovement.gif’
#
#           tmp/pocus   0%[                    ]       0  --.-KB/s               connected.
# 200 OK
# Length: 2090784 (2.0M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-NormalLung.gif’
#
#          tmp/pocus_  25%[====>               ] 515.43K  2.39MB/s               503 No healthy IP available for the backend
# 2024-05-23 08:08:39 ERROR 503: No healthy IP available for the backend.
#
# --2024-05-23 08:08:39--  https://img.grepmed.com/uploads/7415/blines-pocus-pulmonary-lung-covid19-original.mp4
# tmp/pocus_videos/li 100%[===================>]   4.26M  13.1MB/s    in 0.3s
#
# 2024-05-23 08:08:40 (13.1 MB/s) - ‘tmp/pocus_videos/linear/Reg-minimalmovement.gif’ saved [4468440/4468440]
#
# 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
#         tmp/pocus_v  81%[===============>    ]   1.63M  3.96MB/s               connected.
# tmp/pocus_videos/li 100%[===================>]   1.99M  4.52MB/s    in 0.4s
#
# 2024-05-23 08:08:40 (4.52 MB/s) - ‘tmp/pocus_videos/linear/Reg-NormalLung.gif’ saved [2090784/2090784]
#
# HTTP request sent, awaiting response... 200 OK
# Length: 676851 (661K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 660.99K   971KB/s    in 0.7s
#
# 2024-05-23 08:08:41 (971 KB/s) - ‘tmp/pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4’ saved [676851/676851]
#
# --2024-05-23 08:08:41--  https://img.grepmed.com/uploads/7410/sparing-lung-ultrasound-subpleural-blines-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 495270 (484K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grepmed2.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 483.66K   781KB/s    in 0.6s
#
# 2024-05-23 08:08:42 (781 KB/s) - ‘tmp/pocus_videos/convex/Cov-grepmed2.mp4’ saved [495270/495270]
#
# --2024-05-23 08:08:42--  https://img.grepmed.com/uploads/5721/airbronchogram-pulmonary-pocus-pneumonia-lung-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2328631 (2.2M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/pneu-gred-6.gif’
#
# tmp/pocus_videos/co 100%[===================>]   2.22M  2.45MB/s    in 0.9s
#
# 2024-05-23 08:08:43 (2.45 MB/s) - ‘tmp/pocus_videos/convex/pneu-gred-6.gif’ saved [2328631/2328631]
#
# --2024-05-23 08:08:43--  https://img.grepmed.com/uploads/6903/ultrasound-pocus-bronchograms-lung-pulmonary-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 752146 (735K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia1.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 734.52K  1.04MB/s    in 0.7s
#
# 2024-05-23 08:08:45 (1.04 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia1.mp4’ saved [752146/752146]
#
# --2024-05-23 08:08:45--  https://img.grepmed.com/uploads/6876/bronchograms-air-pulmonary-pocus-ultrasound-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2206754 (2.1M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   2.10M  2.37MB/s    in 0.9s
#
# 2024-05-23 08:08:46 (2.37 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4’ saved [2206754/2206754]
#
# --2024-05-23 08:08:46--  https://img.grepmed.com/uploads/6431/ultrasound-lung-pneumonia-shredsign-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1626541 (1.6M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia4.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.55M  1.84MB/s    in 0.8s
#
# 2024-05-23 08:08:47 (1.84 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia4.mp4’ saved [1626541/1626541]
#
# --2024-05-23 08:08:47--  https://img.grepmed.com/uploads/1304/airbronchograms-pneumonia-sonostuff-effusion-clinical-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1061627 (1.0M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/pneu-gred-7.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.01M  1.34MB/s    in 0.8s
#
# 2024-05-23 08:08:49 (1.34 MB/s) - ‘tmp/pocus_videos/convex/pneu-gred-7.gif’ saved [1061627/1061627]
#
# --2024-05-23 08:08:49--  https://img.grepmed.com/uploads/6439/pulmonary-ultrasound-pocus-clinical-lung-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1346485 (1.3M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia3.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.28M  1.60MB/s    in 0.8s
#
# 2024-05-23 08:08:50 (1.60 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia3.mp4’ saved [1346485/1346485]
#
# --2024-05-23 08:08:50--  https://img.grepmed.com/uploads/7408/pocus-alines-lung-normal-ultrasound-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186605 (182K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Reg-Grep-Alines.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 182.23K   428KB/s    in 0.4s
#
# 2024-05-23 08:08:51 (428 KB/s) - ‘tmp/pocus_videos/convex/Reg-Grep-Alines.mp4’ saved [186605/186605]
#
# --2024-05-23 08:08:51--  https://img.grepmed.com/uploads/5325/clinical-pulmonary-lung-normal-artifact-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882045 (1.8M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Reg-Grep-Normal.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.79M  2.09MB/s    in 0.9s
#
# 2024-05-23 08:08:52 (2.09 MB/s) - ‘tmp/pocus_videos/convex/Reg-Grep-Normal.gif’ saved [1882045/1882045]
#
# --2024-05-23 08:08:52--  https://img.grepmed.com/uploads/7583/lung-pocus-ultrasound-shredsign-consolidation-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 805344 (786K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 786.47K  1.08MB/s    in 0.7s
#
# 2024-05-23 08:08:54 (1.08 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4’ saved [805344/805344]
#
# --2024-05-23 08:08:54--  https://img.grepmed.com/uploads/7582/pocus-pneumonia-bacterial-hepatization-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 371402 (363K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 362.70K   648KB/s    in 0.6s
#
# 2024-05-23 08:08:55 (648 KB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4’ saved [371402/371402]
#
# --2024-05-23 08:08:55--  https://img.grepmed.com/uploads/6952/pocus-clinical-lung-pulmonary-pneumonia-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 372273 (364K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pulmonary-pneumonia.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 363.55K   648KB/s    in 0.6s
#
# 2024-05-23 08:08:56 (648 KB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pulmonary-pneumonia.mp4’ saved [372273/372273]
#
# --2024-05-23 08:08:56--  https://img.grepmed.com/uploads/7543/clinical-covid19-pocus-sarscov2-lung-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216695 (212K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7543.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 211.62K   460KB/s    in 0.5s
#
# 2024-05-23 08:08:57 (460 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7543.mp4’ saved [216695/216695]
#
# --2024-05-23 08:08:57--  https://img.grepmed.com/uploads/7525/lung-ultrasound-pocus-coronavirus-covid19-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1204137 (1.1M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7525.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.15M  1.46MB/s    in 0.8s
#
# 2024-05-23 08:08:58 (1.46 MB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7525.mp4’ saved [1204137/1204137]
#
# --2024-05-23 08:08:58--  https://img.grepmed.com/uploads/7511/ultrasound-covid19-pocus-sarscov2-coronavirus-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 541663 (529K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7511.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 528.97K   847KB/s    in 0.6s
#
# 2024-05-23 08:08:59 (847 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7511.mp4’ saved [541663/541663]
#
# --2024-05-23 08:08:59--  https://img.grepmed.com/uploads/7510/clinical-blines-covid19-pocus-lung-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 437912 (428K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7510.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 427.65K   722KB/s    in 0.6s
#
# 2024-05-23 08:09:00 (722 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7510.mp4’ saved [437912/437912]
#
# --2024-05-23 08:09:00--  https://img.grepmed.com/uploads/7507/ultrasound-sarscov2-pocus-clinical-lung-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 91609 (89K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7507.mp4’
#
# tmp/pocus_videos/co 100%[===================>]  89.46K   310KB/s    in 0.3s
#
# 2024-05-23 08:09:01 (310 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7507.mp4’ saved [91609/91609]
#
# --2024-05-23 08:09:01--  https://img.grepmed.com/uploads/7505/covid19-pocus-ultrasound-sarscov2-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 705391 (689K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7505.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 688.86K  1003KB/s    in 0.7s
#
# 2024-05-23 08:09:02 (1003 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7505.mp4’ saved [705391/705391]
#
# --2024-05-23 08:09:02--  https://img.grepmed.com/uploads/7453/covid19-lung-sarscov2-coronavirus-skiplesions-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444081 (434K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grep-7453.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 433.67K   736KB/s    in 0.6s
#
# 2024-05-23 08:09:03 (736 KB/s) - ‘tmp/pocus_videos/convex/Cov-grep-7453.mp4’ saved [444081/444081]
#
# --2024-05-23 08:09:03--  https://img.grepmed.com/uploads/7578/ultrasound-sliding-pulmonary-normal-alines-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65265 (64K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/linear/Reg-grep-normal-alines-original.mp4’
#
# tmp/pocus_videos/li 100%[===================>]  63.74K   262KB/s    in 0.2s
#
# 2024-05-23 08:09:04 (262 KB/s) - ‘tmp/pocus_videos/linear/Reg-grep-normal-alines-original.mp4’ saved [65265/65265]
#
# --2024-05-23 08:09:04--  https://img.grepmed.com/uploads/7500/clinical-subpleural-coronavirus-covid19-pocus-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 310830 (304K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/linear/Cov-grep-7500.mp4’
#
# tmp/pocus_videos/li 100%[===================>] 303.54K   589KB/s    in 0.5s
#
# 2024-05-23 08:09:05 (589 KB/s) - ‘tmp/pocus_videos/linear/Cov-grep-7500.mp4’ saved [310830/310830]
#
# --2024-05-23 08:09:05--  https://img.grepmed.com/uploads/7432/ultrasound-sarscov2-lung-covid19-pocus-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1049745 (1.0M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/linear/Cov-grep-7432.mp4’
#
# tmp/pocus_videos/li 100%[===================>]   1.00M  1.32MB/s    in 0.8s
#
# 2024-05-23 08:09:07 (1.32 MB/s) - ‘tmp/pocus_videos/linear/Cov-grep-7432.mp4’ saved [1049745/1049745]
#
# --2024-05-23 08:09:07--  https://img.grepmed.com/uploads/7431/lung-pocus-coronavirus-ultrasound-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.17, 18.154.206.35, 18.154.206.65, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122958 (120K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/linear/Cov-grep-7431.mp4’
#
# tmp/pocus_videos/li 100%[===================>] 120.08K   366KB/s    in 0.3s
#
# 2024-05-23 08:09:07 (366 KB/s) - ‘tmp/pocus_videos/linear/Cov-grep-7431.mp4’ saved [122958/122958]
#
# --2024-05-23 08:09:07--  https://ars.els-cdn.com/content/image/1-s2.0-S0733862715000772-mmc4.mp4
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1706929 (1.6M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Reg_alines_advancesVid4.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.63M  5.93MB/s    in 0.3s
#
# 2024-05-23 08:09:08 (5.93 MB/s) - ‘tmp/pocus_videos/convex/Reg_alines_advancesVid4.mp4’ saved [1706929/1706929]
#
# --2024-05-23 08:09:08--  https://ars.els-cdn.com/content/image/1-s2.0-S0733862715000772-mmc9.mp4
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2147566 (2.0M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Vir_blines_advancesVid9.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   2.05M  2.61MB/s    in 0.8s
#
# 2024-05-23 08:09:10 (2.61 MB/s) - ‘tmp/pocus_videos/convex/Vir_blines_advancesVid9.mp4’ saved [2147566/2147566]
#
# --2024-05-23 08:09:10--  https://ars.els-cdn.com/content/image/1-s2.0-S0733862715000772-mmc10.mp4
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4055640 (3.9M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu_consol_advancesVid10.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   3.87M  4.86MB/s    in 0.8s
#
# 2024-05-23 08:09:11 (4.86 MB/s) - ‘tmp/pocus_videos/convex/Pneu_consol_advancesVid10.mp4’ saved [4055640/4055640]
#
# --2024-05-23 08:09:11--  https://static-content.springer.com/esm/art%3A10.1186%2Fcc5668/MediaObjects/13054_2007_5188_MOESM1_ESM.avi
# Resolving static-content.springer.com (static-content.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to static-content.springer.com (static-content.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19393024 (18M) [application/x-troff-msvideo]
# Saving to: ‘tmp/pocus_videos/convex/Reg_clinicalreview_mov1.mp4’
#
# tmp/pocus_videos/co 100%[===================>]  18.49M   111MB/s    in 0.2s
#
# 2024-05-23 08:09:15 (111 MB/s) - ‘tmp/pocus_videos/convex/Reg_clinicalreview_mov1.mp4’ saved [19393024/19393024]
#
# --2024-05-23 08:09:15--  https://static-content.springer.com/esm/art%3A10.1186%2Fcc5668/MediaObjects/13054_2007_5188_MOESM4_ESM.avi
# Resolving static-content.springer.com (static-content.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to static-content.springer.com (static-content.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13299200 (13M) [application/x-troff-msvideo]
# Saving to: ‘tmp/pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4’
#
# tmp/pocus_videos/co 100%[===================>]  12.68M  --.-KB/s    in 0.1s
#
# 2024-05-23 08:09:19 (95.7 MB/s) - ‘tmp/pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4’ saved [13299200/13299200]
#
# --2024-05-23 08:09:19--  https://ars.els-cdn.com/content/image/1-s2.0-S2352047720300204-gr1_lrg.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 326370 (319K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_ablines_covidmanifestations_paper1.png’
#
# tmp/pocus_images/co 100%[===================>] 318.72K  1.14MB/s    in 0.3s
#
# 2024-05-23 08:09:19 (1.14 MB/s) - ‘tmp/pocus_images/convex/Cov_ablines_covidmanifestations_paper1.png’ saved [326370/326370]
#
# --2024-05-23 08:09:19--  https://ars.els-cdn.com/content/image/1-s2.0-S2352047720300204-gr2_lrg.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 492428 (481K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_covidmanifestation_paper2.png’
#
# tmp/pocus_images/co 100%[===================>] 480.89K  --.-KB/s    in 0.02s
#
# 2024-05-23 08:09:20 (27.9 MB/s) - ‘tmp/pocus_images/convex/Cov_blines_covidmanifestation_paper2.png’ saved [492428/492428]
#
# --2024-05-23 08:09:20--  https://ars.els-cdn.com/content/image/1-s2.0-S2352047720300204-gr3_lrg.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 367787 (359K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/linear/Cov_irregularpleural_covidmanifestations_paper3.png’
#
# tmp/pocus_images/li 100%[===================>] 359.17K  1.36MB/s    in 0.3s
#
# 2024-05-23 08:09:21 (1.36 MB/s) - ‘tmp/pocus_images/linear/Cov_irregularpleural_covidmanifestations_paper3.png’ saved [367787/367787]
#
# --2024-05-23 08:09:21--  https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fjum.15367&file=jum15367-sup-0001-VideoS1.avi
# Resolving onlinelibrary.wiley.com (onlinelibrary.wiley.com)... 162.159.130.87, 162.159.129.87, 2606:4700:7::a29f:8157, ...
# Connecting to onlinelibrary.wiley.com (onlinelibrary.wiley.com)|162.159.130.87|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-05-23 08:09:21 ERROR 403: Forbidden.
#
# --2024-05-23 08:09:21--  https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fjum.15367&file=jum15367-sup-0002-VideoS2.avi
# Resolving onlinelibrary.wiley.com (onlinelibrary.wiley.com)... 162.159.130.87, 162.159.129.87, 2606:4700:7::a29f:8157, ...
# Connecting to onlinelibrary.wiley.com (onlinelibrary.wiley.com)|162.159.130.87|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-05-23 08:09:21 ERROR 403: Forbidden.
#
# --2024-05-23 08:09:21--  https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fjum.15367&file=jum15367-sup-0003-VideoS3.avi
# Resolving onlinelibrary.wiley.com (onlinelibrary.wiley.com)... 162.159.130.87, 162.159.129.87, 2606:4700:7::a29f:8157, ...
# Connecting to onlinelibrary.wiley.com (onlinelibrary.wiley.com)|162.159.130.87|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-05-23 08:09:21 ERROR 403: Forbidden.
#
# --2024-05-23 08:09:21--  https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fjum.15367&file=jum15367-sup-0004-VideoS4.avi
# Resolving onlinelibrary.wiley.com (onlinelibrary.wiley.com)... 162.159.130.87, 162.159.129.87, 2606:4700:7::a29f:8157, ...
# Connecting to onlinelibrary.wiley.com (onlinelibrary.wiley.com)|162.159.130.87|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-05-23 08:09:21 ERROR 403: Forbidden.
:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://karger.com/WebMaterial/ShowPic/150968 [following]
# --2024-05-23 08:09:24--  https://karger.com/WebMaterial/ShowPic/150968
# Resolving karger.com (karger.com)... 20.246.173.94
# Connecting to karger.com (karger.com)|20.246.173.94|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2024-05-23 08:09:25 ERROR 404: Not Found.
#
# --2024-05-23 08:09:25--  https://ars.els-cdn.com/content/image/1-s2.0-S0720048X16304260-gr5.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44766 (44K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/linear/Pneu_leftbasal_pedriatic_pneumonia.png’
#
# tmp/pocus_images/li 100%[===================>]  43.72K  --.-KB/s    in 0.004s
#
# 2024-05-23 08:09:26 (11.8 MB/s) - ‘tmp/pocus_images/linear/Pneu_leftbasal_pedriatic_pneumonia.png’ saved [44766/44766]
#
# --2024-05-23 08:09:26--  https://ars.els-cdn.com/content/image/1-s2.0-S0720048X16304260-gr6.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48606 (47K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png’
#
# tmp/pocus_images/li 100%[===================>]  47.47K  --.-KB/s    in 0.004s
#
# 2024-05-23 08:09:26 (11.3 MB/s) - ‘tmp/pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png’ saved [48606/48606]
#
# --2024-05-23 08:09:26--  https://ars.els-cdn.com/content/image/1-s2.0-S0002937820304683-gr1.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40305 (39K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pregnantPublication1.png’
#
# tmp/pocus_images/co 100%[===================>]  39.36K  --.-KB/s    in 0.004s
#
# 2024-05-23 08:09:26 (10.9 MB/s) - ‘tmp/pocus_images/convex/Cov_pregnantPublication1.png’ saved [40305/40305]
#
# --2024-05-23 08:09:26--  https://ars.els-cdn.com/content/image/1-s2.0-S0002937820304683-gr1.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 172.64.155.214, 104.18.32.42, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|172.64.155.214|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40305 (39K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pregnantPublication2.png’
#
# tmp/pocus_images/co 100%[===================>]  39.36K  --.-KB/s    in 0.003s
#
# 2024-05-23 08:09:27 (12.1 MB/s) - ‘tmp/pocus_images/convex/Cov_pregnantPublication2.png’ saved [40305/40305]
#
# --2024-05-23 08:09:27--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig1_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig1.png’
#
# tmp/pocus_images/co     [ <=>                ]  29.99K  --.-KB/s    in 0.03s
#
# 2024-05-23 08:09:27 (1.05 MB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig1.png’ saved [30712]
#
# --2024-05-23 08:09:27--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig2_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig2.png’
#
# tmp/pocus_images/co     [ <=>                ]  31.42K  --.-KB/s    in 0.01s
#
# 2024-05-23 08:09:28 (2.34 MB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig2.png’ saved [32172]
#
# --2024-05-23 08:09:28--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig3_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig3.png’
#
# tmp/pocus_images/co     [  <=>               ]  74.43K   274KB/s    in 0.3s
#
# 2024-05-23 08:09:28 (274 KB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig3.png’ saved [76216]
#
# --2024-05-23 08:09:28--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig7_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png’
#
# tmp/pocus_images/co     [ <=>                ]  34.69K  --.-KB/s    in 0.01s
#
# 2024-05-23 08:09:29 (2.54 MB/s) - ‘tmp/pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png’ saved [35518]
#
# --2024-05-23 08:09:29--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig4_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png’
#
# tmp/pocus_images/co     [ <=>                ]  32.72K  --.-KB/s    in 0.05s
#
# 2024-05-23 08:09:29 (634 KB/s) - ‘tmp/pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png’ saved [33509]
#
# --2024-05-23 08:09:29--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig8_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png’
#
# tmp/pocus_images/co     [ <=>                ]  30.15K  --.-KB/s    in 0.02s
#
# 2024-05-23 08:09:30 (1.83 MB/s) - ‘tmp/pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png’ saved [30874]
#
# --2024-05-23 08:09:30--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig5_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png’
#
# tmp/pocus_images/co     [ <=>                ]  26.89K  --.-KB/s    in 0.008s
#
# 2024-05-23 08:09:30 (3.16 MB/s) - ‘tmp/pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png’ saved [27536]
#
# --2024-05-23 08:09:30--  https://journals.viamedica.pl/advances_in_respiratory_medicine/article/viewFile/41845/36561/110994
# Resolving journals.viamedica.pl (journals.viamedica.pl)... 195.116.62.118
# Connecting to journals.viamedica.pl (journals.viamedica.pl)|195.116.62.118|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://journals.viamedica.pl/ [following]
# --2024-05-23 08:09:33--  https://journals.viamedica.pl/
# Reusing existing connection to journals.viamedica.pl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tmp/pocus_images/convex/Reg_publication1.png’
#
# tmp/pocus_images/co     [    <=>             ]  92.01K   124KB/s    in 0.7s
#
# 2024-05-23 08:09:34 (124 KB/s) - ‘tmp/pocus_images/convex/Reg_publication1.png’ saved [94215]
#
# --2024-05-23 08:09:34--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig03.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167679 (164K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb1.png’
#
# tmp/pocus_images/co 100%[===================>] 163.75K   117KB/s    in 1.4s
#
# 2024-05-23 08:09:38 (117 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb1.png’ saved [167679/167679]
#
# --2024-05-23 08:09:38--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig03.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167679 (164K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb1_2.png’
#
# tmp/pocus_images/co 100%[===================>] 163.75K   134KB/s    in 1.2s
#
# 2024-05-23 08:09:40 (134 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb1_2.png’ saved [167679/167679]
#
# --2024-05-23 08:09:40--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig06-1-1024x682.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 428501 (418K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb3.png’
#
# tmp/pocus_images/co 100%[===================>] 418.46K   169KB/s    in 2.5s
#
# 2024-05-23 08:09:43 (169 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb3.png’ saved [428501/428501]
#
# --2024-05-23 08:09:43--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig01.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 325738 (318K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_efsumb2.png’
#
# tmp/pocus_images/co 100%[===================>] 318.10K   163KB/s    in 1.9s
#
# 2024-05-23 08:09:47 (163 KB/s) - ‘tmp/pocus_images/convex/Reg_efsumb2.png’ saved [325738/325738]
#
# --2024-05-23 08:09:47--  https://sonographiebilder.de/fileadmin/_processed_/c/b/csm_Pneumonie_li_canifizierend_24ebb9e166.jpg
# Resolving sonographiebilder.de (sonographiebilder.de)... 88.198.28.130
# Connecting to sonographiebilder.de (sonographiebilder.de)|88.198.28.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143839 (140K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_sonographiebilder1.jpg’
#
# tmp/pocus_images/co 100%[===================>] 140.47K   196KB/s    in 0.7s
#
# 2024-05-23 08:09:49 (196 KB/s) - ‘tmp/pocus_images/convex/Pneu_sonographiebilder1.jpg’ saved [143839/143839]
#
# --2024-05-23 08:09:49--  https://sonographiebilder.de/fileadmin/_migrated/pics/Pneumonie__3_.jpg
# Resolving sonographiebilder.de (sonographiebilder.de)... 88.198.28.130
# Connecting to sonographiebilder.de (sonographiebilder.de)|88.198.28.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67171 (66K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_sonographiebilder2.jpg’
#
# tmp/pocus_images/co 100%[===================>]  65.60K   137KB/s    in 0.5s
#
# 2024-05-23 08:09:50 (137 KB/s) - ‘tmp/pocus_images/convex/Pneu_sonographiebilder2.jpg’ saved [67171/67171]
#
# --2024-05-23 08:09:50--  https://www.jem-journal.com/cms/10.1016/j.jemermed.2020.06.032/attachment/69e81993-824e-4a79-9b61-8683b242a328/mmc1.mp4
# Resolving www.jem-journal.com (www.jem-journal.com)... 104.18.124.114, 104.18.123.114
# Connecting to www.jem-journal.com (www.jem-journal.com)|104.18.124.114|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2024-05-23 08:09:50 ERROR 403: Forbidden.
#
# --2024-05-23 08:09:50--  https://static.healthcare.siemens.com/siemens_hwem-hwem_ssxa_websites-context-root/wcm/idc/groups/public/@global/documents/image/mda5/nzg3/~edisp/jun-5c1-lung-hepatization-07275343/~renditions/jun-5c1-lung-hepatization-07275343~8.jpg
# Resolving static.healthcare.siemens.com (static.healthcare.siemens.com)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘static.healthcare.siemens.com’
# --2024-05-23 08:09:50--  https://static.healthcare.siemens.com/siemens_hwem-hwem_ssxa_websites-context-root/wcm/idc/groups/public/@global/documents/image/mda5/nzg3/~edisp/jun-5c1-lung-4-b-lines-07275344/~renditions/jun-5c1-lung-4-b-lines-07275344~8.jpg
# Resolving static.healthcare.siemens.com (static.healthcare.siemens.com)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘static.healthcare.siemens.com’
# --2024-05-23 08:09:50--  https://static.healthcare.siemens.com/siemens_hwem-hwem_ssxa_websites-context-root/wcm/idc/groups/public/@global/documents/image/mda5/nzg3/~edisp/seq-10l4-lung-b-lines-pleuritis-07275337/~renditions/seq-10l4-lung-b-lines-pleuritis-07275337~8.jpg
# Resolving static.healthcare.siemens.com (static.healthcare.siemens.com)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘static.healthcare.siemens.com’
# --2024-05-23 08:09:50--  https://house-fastly-signed-eu-west-1-prod.brightcovecdn.com/media/v1/hls/v4/clear/2744552178001/5ef91327-742a-48cb-9ade-d04374e5dcac/49587bc4-0dac-48b4-ba3a-93d41d44cbf0/5x/segment0.ts?fastly_token=%3D
# Resolving house-fastly-signed-eu-west-1-prod.brightcovecdn.com (house-fastly-signed-eu-west-1-prod.brightcovecdn.com)... 146.75.42.27, 2a04:4e42:87::539
# Connecting to house-fastly-signed-eu-west-1-prod.brightcovecdn.com (house-fastly-signed-eu-west-1-prod.brightcovecdn.com)|146.75.42.27|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.
# --2024-05-23 08:09:51--  https://cdn.amegroups.cn/journals/amepc/files/journals/8/articles/46675/public/46675-PB8-6552-R1.png
# Resolving cdn.amegroups.cn (cdn.amegroups.cn)... 192.169.122.217
# Connecting to cdn.amegroups.cn (cdn.amegroups.cn)|192.169.122.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1508419 (1.4M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_Chen_2020_3A.png’
#
# tmp/pocus_images/co 100%[===================>]   1.44M  --.-KB/s    in 0.03s
#
# 2024-05-23 08:09:51 (45.0 MB/s) - ‘tmp/pocus_images/convex/Reg_Chen_2020_3A.png’ saved [1508419/1508419]
#
# --2024-05-23 08:09:51--  https://cdn.amegroups.cn/journals/amepc/files/journals/8/articles/46675/public/46675-PB8-6552-R1.png
# Resolving cdn.amegroups.cn (cdn.amegroups.cn)... 192.169.122.217
# Connecting to cdn.amegroups.cn (cdn.amegroups.cn)|192.169.122.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1508419 (1.4M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_Chen_2020_6A.png’
#
# tmp/pocus_images/co 100%[===================>]   1.44M  --.-KB/s    in 0.03s
#
# 2024-05-23 08:09:52 (48.0 MB/s) - ‘tmp/pocus_images/convex/Reg_Chen_2020_6A.png’ saved [1508419/1508419]
#
# --2024-05-23 08:09:52--  https://ars.els-cdn.com/content/image/1-s2.0-S0012369212605662-gr2.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117836 (115K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg’
#
# tmp/pocus_images/co 100%[===================>] 115.07K  --.-KB/s    in 0.008s
#
# 2024-05-23 08:09:52 (13.8 MB/s) - ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg’ saved [117836/117836]
#
# --2024-05-23 08:09:52--  https://ars.els-cdn.com/content/image/1-s2.0-S0012369212605662-gr2.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::ac40:9bd6, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117836 (115K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg’
#
# tmp/pocus_images/co 100%[===================>] 115.07K  --.-KB/s    in 0.009s
#
# 2024-05-23 08:09:52 (12.7 MB/s) - ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg’ saved [117836/117836]
#
# --2024-05-23 08:09:52--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_a.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   248KB/s    in 5.8s
#
# 2024-05-23 08:09:59 (226 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_a.jpg’ saved [1352950/1352950]
#
# --2024-05-23 08:09:59--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_b.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   388KB/s    in 3.4s
#
# 2024-05-23 08:10:03 (388 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_b.jpg’ saved [1352950/1352950]
#
# --2024-05-23 08:10:03--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_c.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   432KB/s    in 3.1s
#
# 2024-05-23 08:10:07 (432 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_c.jpg’ saved [1352950/1352950]
#
# --2024-05-23 08:10:07--  https://www.medrxiv.org/content/medrxiv/early/2020/10/22/2020.10.13.20212258/DC3/embed/media-3.mp4
# Resolving www.medrxiv.org (www.medrxiv.org)... 104.21.11.180, 172.67.166.236, 2606:4700:3031::ac43:a6ec, ...
# Connecting to www.medrxiv.org (www.medrxiv.org)|104.21.11.180|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464883 (454K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 453.99K  1.32MB/s    in 0.3s
#
# 2024-05-23 08:10:09 (1.32 MB/s) - ‘tmp/pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4’ saved [464883/464883]
#
# Data fetched. Postprocessing...
# Done, shutting down.

# %%
#how many files we get from web
# !ls -1 /content/tmp/pocus_images/convex | wc -l
# !ls -1 /content/tmp/pocus_images/linear | wc -l
# !ls -1 /content/tmp/pocus_videos/convex | wc -l
# !ls -1 /content/tmp/pocus_videos/linear | wc -l
# Out:
# 31
# 4
# 41
# 9

# %%
#crop web files and put into data folder
# !python3 /content/crop_processed_data.py
# Out:
# pocus_videos/convex/Reg-nephropocus.gif [[25, 90, 250], [0, 30.0]]
# (30, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-Youtube.mp4 [[40, 150, 280], [2299, 2429]]
# Problem reading file: tmp/pocus_videos/convex/Reg-Youtube.mp4
# pocus_videos/convex/pneu-everyday.gif [[30, 90, 340], [0, 61.0]]
# (61, 340, 340, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-clarius.gif [[30, 100, 350], [0, 103.0]]
# (103, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-bcpocus.gif [[0, 100, 400], [0, 59.0]]
# (59, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-clarius3.gif [[60, 100, 300], [0, 117.0]]
# (117, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Pneu-Youtube-start20sec.mp4 [[120, 650, 500], [667, 777]]
# Problem reading file: tmp/pocus_videos/linear/Pneu-Youtube-start20sec.mp4
# pocus_videos/linear/Reg-NormalLung.gif [[0, 30, 330], [0, 35.0]]
# (35, 330, 330, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-Youtube-Video_902_Lung_POCUS-left.mp4 [[70, 30, 190], [0, 96.0]]
# Problem reading file: tmp/pocus_videos/linear/Reg-Youtube-Video_902_Lung_POCUS-left.mp4
# pocus_videos/linear/Reg-Youtube-start20sec.mp4 [[125, 50, 500], [667, 777]]
# Problem reading file: tmp/pocus_videos/linear/Reg-Youtube-start20sec.mp4
# pocus_videos/linear/Reg-minimalmovement.gif [[0, 10, 350], [0, 45.0]]
# (45, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_images/convex/Pneu_clarius.jpg [[40, 200, 380], [0, 0.0]]
# [ERROR:0@2.058] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Pneu_clarius.jpg in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Pneu_clarius.jpg
# pocus_images/convex/Pneu_clarius2.png [[30, 200, 380], [0, 0.0]]
# Problem reading file: tmp/pocus_images/convex/Pneu_clarius2.png
# pocus_videos/convex/Reg-Grep-Normal.gif [[40, 60, 400], [0, 33.0]]
# (33, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Vir_blines_advancesVid9.mp4 [[30, 200, 300], [0, 240.0]]
# (240, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4 [[20, 150, 400], [0, 96.0]]
# (96, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7453.mp4 [[50, 150, 370], [0, 210.0]]
# (210, 370, 370, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov_new_pregnant_vid8.avi [[200, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid8.avi
# pocus_videos/convex/Cov-grep-7525.mp4 [[150, 150, 400], [0, 361.0]]
# (361, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4 [[180, 250, 500], [0, 300.0]]
# (300, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7543.mp4 [[50, 150, 350], [0, 70.0]]
# (70, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia4.mp4 [[0, 0, 410], [0, 151.0]]
# (151, 410, 410, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia1.mp4 [[100, 100, 300], [0, 151.0]]
# (151, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pulmonary-pneumonia.mp4 [[100, 250, 500], [0, 187.0]]
# (187, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/pneu-gred-7.gif [[15, 50, 150], [0, 48.0]]
# (48, 150, 150, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia3.mp4 [[50, 100, 300], [0, 114.0]]
# (114, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-Grep-Alines.mp4 [[80, 100, 420], [0, 85.0]]
# (85, 420, 420, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/pneu-gred-6.gif [[50, 150, 250], [0, 54.0]]
# (54, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu_consol_advancesVid10.mp4 [[20, 50, 350], [0, 450.0]]
# (450, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg_clinicalreview_mov1.mp4 [[20, 100, 400], [0, 197.0]]
# (197, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4 [[200, 320, 450], [0, 225.0]]
# (225, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grepmed2.mp4 [[50, 100, 280], [0, 298.0]]
# (298, 280, 280, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7507.mp4 [[80, 150, 300], [0, 159.0]]
# (159, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov_new_pregnant_vid3.avi [[220, 600, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid3.avi
# pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4 [[100, 250, 400], [0, 300.0]]
# (300, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7511.mp4 [[180, 220, 500], [0, 269.0]]
# (269, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7505.mp4 [[50, 100, 500], [0, 365.0]]
# (365, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg_alines_advancesVid4.mp4 [[60, 100, 450], [0, 177.0]]
# (177, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7510.mp4 [[170, 250, 450], [0, 267.0]]
# (267, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4 [[100, 250, 400], [0, 458.0]]
# (458, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-nephropocus.gif [[0, 125, 350], [0, 150.0]]
# (150, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7431.mp4 [[180, 380, 400], [0, 116.0]]
# (116, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7432.mp4 [[120, 500, 550], [0, 280.0]]
# (280, 550, 550, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7500.mp4 [[20, 80, 300], [0, 75.0]]
# (75, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-grep-normal-alines-original.mp4 [[0, 180, 250], [0, 165.0]]
# (165, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_images/convex/Cov_ablines_covidmanifestations_paper1.png [[200, 300, 1000], [0, 1.0]]
# pocus_images/convex/Cov_pregnantPublication1.png [[25, 320, 250], [0, 1.0]]
# pocus_images/convex/Cov_blines_covidmanifestation_paper2.png [[120, 220, 500], [0, 1.0]]
# pocus_images/convex/Reg_com_acquired_paper.png [[10, 360, 150], [0, 1.0]]
# [ERROR:0@24.320] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Reg_com_acquired_paper.png in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Reg_com_acquired_paper.png
# pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png [[0, 0, 160], [0, 1.0]]
# [ERROR:0@24.321] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png
# pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png [[330, 10, 240], [0, 1.0]]
# pocus_images/linear/Cov_irregularpleural_covidmanifestations_paper3.png [[120, 200, 800], [0, 1.0]]
# pocus_images/linear/Pneu_leftbasal_pedriatic_pneumonia.png [[10, 30, 230], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig2.png [[40, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig3.png [[50, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig1.png [[80, 200, 800], [0, 1.0]]
# pocus_videos/linear/Cov_linear_abrams_2020_v1.mp4 [[40, 100, 400], [0, 64.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x575a8d7481c0] moov atom not found
# Problem reading file: tmp/pocus_videos/linear/Cov_linear_abrams_2020_v1.mp4
# pocus_images/convex/Pneu_sonographiebilder2.jpg [[60, 100, 400], [0, 1.0]]
# pocus_images/convex/Reg_efsumb2.png [[100, 250, 500], [0, -9.223372036854776e+18]]
# pocus_images/convex/Pneu_sonographiebilder1.jpg [[80, 200, 400], [0, 1.0]]
# pocus_images/convex/Reg_publication1.png [[20, 30, 250], [0, -9.223372036854776e+18]]
# [png @ 0x575a8d6fa540] Invalid PNG signature 0xA0A3C21444F4354.
# [png @ 0x575a8d73b400] Invalid PNG signature 0xA0A3C21444F4354.
# Problem reading file: tmp/pocus_images/convex/Reg_publication1.png
# pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png [[50, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png [[90, 200, 350], [0, 1.0]]
# pocus_images/convex/Cov_efsumb3.png [[50, 200, 600], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_efsumb1.png [[30, 50, 200], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png [[30, 150, 450], [0, 1.0]]
# pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png [[40, 150, 400], [0, 1.0]]
# pocus_videos/convex/Pneu_AIR BRONC2.mov [[40, 150, 300], [0, 52.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x575a8d6e5d00] moov atom not found
# Problem reading file: tmp/pocus_videos/convex/Pneu_AIR BRONC2.mov
# pocus_videos/convex/Reg_Alines-1-90.mov [[20, 150, 350], [0, 78.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x575a8d7481c0] moov atom not found
# Problem reading file: tmp/pocus_videos/convex/Reg_Alines-1-90.mov
# pocus_images/convex/Cov_efsumb1_2.png [[20, 400, 200], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_pregnantPublication2.png [[140, 630, 115], [0, 1.0]]
# pocus_images/convex/Cov_siemens_1.png [[180, 500, 800], [0, 1.0]]
# Problem reading file: tmp/pocus_images/convex/Cov_siemens_1.png
# pocus_images/convex/Cov_siemens_2.png [[180, 500, 750], [0, 1.0]]
# Problem reading file: tmp/pocus_images/convex/Cov_siemens_2.png
# pocus_images/linear/Cov_siemens_3.png [[20, 500, 950], [0, 1.0]]
# Problem reading file: tmp/pocus_images/linear/Cov_siemens_3.png
# pocus_videos/linear/Reg_siemens_vid_3.mp4 [[120, 400, 500], [0, 269.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x575a8d7befc0] moov atom not found
# Problem reading file: tmp/pocus_videos/linear/Reg_siemens_vid_3.mp4
# pocus_videos/convex/Cov_new_pregnant_vid4.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid4.avi
# pocus_videos/convex/Cov_new_pregnant_vid5.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid5.avi
# pocus_videos/convex/Cov_new_pregnant_vid7.avi [[200, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid7.avi
# pocus_videos/convex/Cov_new_pregnant_vid6.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid6.avi
# pocus_videos/convex/Cov_new_pregnant_vid2.avi [[250, 700, 800], [0, 142.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid2.avi
# pocus_videos/convex/Cov_new_pregnant_vid1.avi [[250, 700, 800], [0, 144.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid1.avi
# pocus_videos/convex/Pneu_Youtube_case.mp4 [[40, 100, 270], [0, 164.0]]
# Problem reading file: tmp/pocus_videos/convex/Pneu_Youtube_case.mp4
# pocus_images/convex/Reg_Chen_2020_3A.png [[20, 50, 230], [0, -9.223372036854776e+18]]
# pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg [[25, 20, 220], [0, 1.0]]
# pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg [[25, 300, 230], [0, 1.0]]
# pocus_images/convex/Reg_Chen_2020_6A.png [[20, 50, 200], [0, -9.223372036854776e+18]]
# pocus_videos/convex/Cov_wfumb_case_dez.mp4 [[20, 75, 300], [0, 91.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_wfumb_case_dez.mp4
# pocus_images/convex/Cov_wfumb_case_dez_a.jpg [[70, 250, 400], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_wfumb_case_dez_c.jpg [[580, 200, 480], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_wfumb_case_dez_b.jpg [[70, 1150, 430], [0, -9.223372036854776e+18]]
# pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4 [[100, 250, 450], [0, 120.0]]
# (120, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
# check if new files appear in the folders
# !ls -1 /content/data/pocus_images/convex | wc -l
# !ls -1 /content/data/pocus_images/linear | wc -l
# !ls -1 /content/data/pocus_videos/convex | wc -l
# !ls -1 /content/data/pocus_videos/linear | wc -l
# Out:
# 53
# 6
# 155
# 18

# %%
#temp delete
#!rm -rf tmp

# %%
#crop videos files, images, put into image_dataset folder
# !python3 /content/build_image_dataset.py
# Out:
# Reg_pat4Image_140024.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 436.0
# --> taking every  8 th image
# Pneu_consol_advancesVid10.mp4 framerate 29.97 width 350.0 height 350.0 number frames: 450.0
# --> taking every  9 th image
# Reg_Avi_Image002.mp4 framerate 50.261259019656634 width 568.0 height 568.0 number frames: 202.0
# --> taking every  16 th image
# Pneu_northumbria_0409_set6_vid7.avi framerate 22.25 width 510.0 height 510.0 number frames: 91.0
# --> taking every  7 th image
# Reg_Avi_Video_002.mp4 framerate 50.79365079365079 width 608.0 height 608.0 number frames: 64.0
# --> taking every  16 th image
# Reg_pat1Image_133138.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 260.0
# --> taking every  8 th image
# Cov-grep-7507.mp4 framerate 30.0 width 300.0 height 300.0 number frames: 159.0
# --> taking every  10 th image
# Reg_Image_181739_trimmed_crop.mp4 framerate 29.028603794958936 width 386.0 height 386.0 number frames: 104.0
# --> taking every  9 th image
# Pneu-grep-pneumonia3.mp4 framerate 33.333 width 300.0 height 300.0 number frames: 114.0
# --> taking every  11 th image
# Cov_combatting_Image5.mp4 framerate 30.333333333333332 width 394.0 height 394.0 number frames: 182.0
# --> taking every  10 th image
# Reg_Avi_Video_001.mp4 framerate 22.243713733075435 width 609.0 height 609.0 number frames: 92.0
# --> taking every  7 th image
# Reg_northumbria_0409_set5_vid2.avi framerate 29.97002997002997 width 864.0 height 864.0 number frames: 98.0
# --> taking every  9 th image
# Reg_pat3Image_135026.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 278.0
# --> taking every  8 th image
# Reg_Avi_Image008.mp4 framerate 50.25252525252525 width 574.0 height 574.0 number frames: 199.0
# --> taking every  16 th image
# Reg_pat2Image_134240.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 254.0
# --> taking every  8 th image
# Reg_Image_182106_crop.mp4 framerate 31.15547489413188 width 382.0 height 382.0 number frames: 206.0
# --> taking every  10 th image
# Pneu_Avi_Video_002.mp4 framerate 22.243482420473573 width 609.0 height 609.0 number frames: 93.0
# --> taking every  7 th image
# Reg_Avi_Image003.mp4 framerate 50.261259019656634 width 520.0 height 520.0 number frames: 202.0
# --> taking every  16 th image
# Cov_Arnthfield_2020_Vid3.mp4 framerate 30.0 width 450.0 height 450.0 number frames: 120.0
# --> taking every  10 th image
# Reg-NormalLungs.mp4 framerate 25.0 width 148.0 height 141.0 number frames: 131.0
# --> taking every  8 th image
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5bd786359240] Slice parameters 0, 141 are invalid
# Cov-grep-7505.mp4 framerate 60.0 width 500.0 height 500.0 number frames: 365.0
# --> taking every  20 th image
# Reg_pat2Image_134348.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 207.0
# --> taking every  8 th image
# Reg_clinicalreview_mov1.mp4 framerate 50.0 width 400.0 height 400.0 number frames: 197.0
# --> taking every  16 th image
# Pneu_Avi_Video_005.mp4 framerate 22.249388753056234 width 607.0 height 607.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set1_vid2.avi framerate 22.25 width 520.0 height 520.0 number frames: 93.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set2_vid4.avi framerate 22.25 width 523.0 height 523.0 number frames: 79.0
# --> taking every  7 th image
# Cov_combatting_Image1.mp4 framerate 28.25 width 440.0 height 440.0 number frames: 113.0
# --> taking every  9 th image
# pneu-gred-6.mp4 framerate 10.0 width 250.0 height 250.0 number frames: 54.0
# --> taking every  3 th image
# Pneu-Atlas-pneumonia.gif framerate 10.0 width 208.0 height 208.0 number frames: 59.0
# --> taking every  3 th image
# Pneu_Basal-pneumonia-RUQ_crop.mp4 framerate 15.0 width 268.0 height 268.0 number frames: 27.0
# --> taking every  5 th image
# Pneu_Avi_Video_004.mp4 framerate 22.743947175348495 width 606.0 height 606.0 number frames: 31.0
# --> taking every  7 th image
# Cov_recommendations_lightbeam_mov6.mov framerate 29.97002997002997 width 538.0 height 538.0 number frames: 309.0
# --> taking every  9 th image
# Reg_northumbria_1009_vid6.avi framerate 22.243482420473573 width 484.0 height 484.0 number frames: 93.0
# --> taking every  7 th image
# Reg_Avi_lung-sliding-2.MP4 framerate 18.0 width 528.0 height 528.0 number frames: 56.0
# --> taking every  6 th image
# Pneu-grep-pneumonia4.mp4 framerate 33.333 width 410.0 height 410.0 number frames: 151.0
# --> taking every  11 th image
# Cov-grep-7525.mp4 framerate 20.833 width 400.0 height 400.0 number frames: 361.0
# --> taking every  6 th image
# Cov-clarius3.mp4 framerate 10.0 width 300.0 height 300.0 number frames: 117.0
# --> taking every  3 th image
# Pneu_northumbria_1009_vid1.avi framerate 22.25 width 501.0 height 501.0 number frames: 93.0
# --> taking every  7 th image
# Cov_denault_proposedUS_vid12.mov framerate 60.0 width 852.0 height 852.0 number frames: 161.0
# --> taking every  20 th image
# Reg_northumbria_1009_vid7.avi framerate 22.243713733075435 width 511.0 height 511.0 number frames: 92.0
# --> taking every  7 th image
# Cov-grep-7511.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 269.0
# --> taking every  10 th image
# Reg_pat4Image_140238.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 215.0
# --> taking every  8 th image
# Cov_recommendations_likebutterfly_mov5.mov framerate 22.666666666666668 width 370.0 height 370.0 number frames: 138.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set4_vid2.avi framerate 22.25 width 494.0 height 494.0 number frames: 91.0
# --> taking every  7 th image
# Cov-Atlas-suspectedCovid.mp4 framerate 25.0 width 1080.0 height 1080.0 number frames: 100.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set2_vid2.avi framerate 22.25 width 524.0 height 524.0 number frames: 93.0
# --> taking every  7 th image
# Cov_convex_volpecelli_sonographic_v2.mov framerate 39.0 width 432.0 height 432.0 number frames: 402.0
# --> taking every  13 th image
# Cov-Atlas-+(43).gif framerate 10.0 width 163.0 height 163.0 number frames: 39.0
# --> taking every  3 th image
# Cov-Atlas-Day+4.gif framerate 10.0 width 230.0 height 230.0 number frames: 40.0
# --> taking every  3 th image
# pneu-everyday.mp4 framerate 10.0 width 340.0 height 340.0 number frames: 61.0
# --> taking every  3 th image
# Pneu_liftl_pneu_case3_clip4.mp4 framerate 15.0 width 306.0 height 306.0 number frames: 41.0
# --> taking every  5 th image
# Pneu_northumbria_0409_set6_vid5.avi framerate 22.243482420473573 width 509.0 height 509.0 number frames: 93.0
# --> taking every  7 th image
# Reg_northumbria_1009_vid5.avi framerate 22.243482420473573 width 475.0 height 475.0 number frames: 93.0
# --> taking every  7 th image
# Reg_pat4Image_140606.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 218.0
# --> taking every  8 th image
# Reg_Avi_Video_004.mp4 framerate 50.261259019656634 width 597.0 height 597.0 number frames: 202.0
# --> taking every  16 th image
# pneu-radiopaeda.mp4 framerate 30.0 width 221.0 height 236.0 number frames: 223.0
# --> taking every  10 th image
# Pneu_from_article_rippey.mp4 framerate 15.0 width 272.0 height 272.0 number frames: 42.0
# --> taking every  5 th image
# Reg_pat3Image_134904.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 245.0
# --> taking every  8 th image
# Reg-Atlas-alines.gif framerate 10.0 width 165.0 height 165.0 number frames: 60.0
# --> taking every  3 th image
# Reg_pat3Image_135128.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 208.0
# --> taking every  8 th image
# Reg_pat2Image_133824.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 271.0
# --> taking every  8 th image
# Reg_northumbria_1009_vid1.avi framerate 22.25 width 478.0 height 478.0 number frames: 92.0
# --> taking every  7 th image
# Cov_denault_proposedUS_vid1.mov framerate 60.0 width 702.0 height 702.0 number frames: 145.0
# --> taking every  20 th image
# Cov_convex_volpecelli_sonographic_v4.mov framerate 39.0 width 414.0 height 414.0 number frames: 405.0
# --> taking every  13 th image
# Reg_northumbria_0409_set3_vid2.avi framerate 22.25 width 502.0 height 502.0 number frames: 94.0
# --> taking every  7 th image
# Cov-Atlas+(45).gif framerate 10.0 width 174.0 height 174.0 number frames: 21.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set3_vid1.avi framerate 22.25 width 481.0 height 481.0 number frames: 90.0
# --> taking every  7 th image
# Cov_convex_volpecelli_sonographic_v3.mov framerate 39.0 width 416.0 height 416.0 number frames: 399.0
# --> taking every  13 th image
# Reg_pat1Image_133232.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 199.0
# --> taking every  8 th image
# Cov-grep-7510.mp4 framerate 30.0 width 450.0 height 450.0 number frames: 267.0
# --> taking every  10 th image
# Reg_recommendations_alines_mov1.mov framerate 18.0 width 322.0 height 322.0 number frames: 180.0
# --> taking every  6 th image
# Pneu_liftl_pneu_case3_clip5.mp4 framerate 15.0 width 272.0 height 272.0 number frames: 26.0
# --> taking every  5 th image
# Reg_northumbria_0409_set5_vid1.avi framerate 50.0 width 605.0 height 497.0 number frames: 200.0
# --> taking every  16 th image
# Cov_denault_proposedUS_vid13.mov framerate 60.0 width 852.0 height 852.0 number frames: 174.0
# --> taking every  20 th image
# Cov_convex_volpecelli_sonographic_v5.mov framerate 39.0 width 444.0 height 444.0 number frames: 401.0
# --> taking every  13 th image
# Cov_denault_proposedUS_vid14.mov framerate 60.0 width 852.0 height 852.0 number frames: 137.0
# --> taking every  20 th image
# Reg_pat3Image_135215.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 317.0
# --> taking every  8 th image
# Cov_denault_proposedUS_vid10.mov framerate 60.0 width 852.0 height 852.0 number frames: 141.0
# --> taking every  20 th image
# Pneu_Avi_Video_006.mp4 framerate 22.243713733075435 width 609.0 height 609.0 number frames: 92.0
# --> taking every  7 th image
# Reg-bcpocus.mp4 framerate 10.0 width 400.0 height 400.0 number frames: 59.0
# --> taking every  3 th image
# Reg_pat4Image_140705.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 266.0
# --> taking every  8 th image
# Cov-Atlas-Day+1.gif framerate 10.0 width 408.0 height 408.0 number frames: 33.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set5_vid1.avi framerate 22.25 width 509.0 height 509.0 number frames: 92.0
# --> taking every  7 th image
# Reg_pat1Image_133043.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 245.0
# --> taking every  8 th image
# Pneu_Avi_Video_003.mp4 framerate 22.243482420473573 width 607.0 height 607.0 number frames: 93.0
# --> taking every  7 th image
# Cov-grep-7453.mp4 framerate 20.833 width 370.0 height 370.0 number frames: 210.0
# --> taking every  6 th image
# Pneu-grep-pneumonia2_1.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 300.0
# --> taking every  10 th image
# Reg_pat2Image_133952.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 254.0
# --> taking every  8 th image
# Reg_Avi_lung-sliding.MP4 framerate 18.0 width 528.0 height 528.0 number frames: 56.0
# --> taking every  6 th image
# Pneu_northumbria_0409_set6_vid1.avi framerate 22.25 width 514.0 height 514.0 number frames: 92.0
# --> taking every  7 th image
# Pneu-grep-bacterial-hepatization-clinical.mp4 framerate 30.0 width 400.0 height 400.0 number frames: 300.0
# --> taking every  10 th image
# Pneu_northumbria_0409_set1_vid1.avi framerate 22.25 width 516.0 height 516.0 number frames: 90.0
# --> taking every  7 th image
# Cov_denault_proposedUS_vid2.mov framerate 60.0 width 842.0 height 842.0 number frames: 459.0
# --> taking every  20 th image
# Reg_Image_181602_trimmed_crop.mp4 framerate 29.03790956871808 width 386.0 height 386.0 number frames: 374.0
# --> taking every  9 th image
# Reg-Grep-Normal.mp4 framerate 10.0 width 400.0 height 400.0 number frames: 33.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set6_vid2.avi framerate 22.25 width 517.0 height 517.0 number frames: 92.0
# --> taking every  7 th image
# Reg_northumbria_0409_set3_vid1.avi framerate 22.25 width 470.0 height 470.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid3.avi framerate 22.25 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Reg_Image_182340_crop.mp4 framerate 37.109587550331916 width 400.0 height 400.0 number frames: 309.0
# --> taking every  12 th image
# Reg-Grep-Alines.mp4 framerate 25.0 width 420.0 height 420.0 number frames: 85.0
# --> taking every  8 th image
# Cov_combatting_image4.mp4 framerate 27.4 width 476.0 height 476.0 number frames: 137.0
# --> taking every  9 th image
# Pneu_liftl_pneu_case3_clip3.mp4 framerate 15.0 width 280.0 height 280.0 number frames: 25.0
# --> taking every  5 th image
# Cov-Atlas+(44).gif framerate 10.0 width 139.0 height 139.0 number frames: 41.0
# --> taking every  3 th image
# Reg-nephropocus.mp4 framerate 10.0 width 250.0 height 250.0 number frames: 30.0
# --> taking every  3 th image
# Reg_pat3Image_134811.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 206.0
# --> taking every  8 th image
# Pneu-grep-shredsign-consolidation.mp4 framerate 46.0 width 400.0 height 400.0 number frames: 458.0
# --> taking every  15 th image
# Cov_denault_proposedUS_vid5.mov framerate 60.0 width 706.0 height 706.0 number frames: 210.0
# --> taking every  20 th image
# pneu-gred-7.mp4 framerate 16.667 width 150.0 height 150.0 number frames: 48.0
# --> taking every  5 th image
# Cov_emdocs_vid1.gif framerate 22.0 width 353.0 height 353.0 number frames: 134.0
# --> taking every  7 th image
# Cov_emdocs_vid3.gif framerate 21.083333333333332 width 748.0 height 748.0 number frames: 75.0
# --> taking every  7 th image
# Pneu-Atlas-pneumonia2.gif framerate 10.0 width 327.0 height 327.0 number frames: 40.0
# --> taking every  3 th image
# Reg_liftl_case3_clip2.mp4 framerate 15.0 width 264.0 height 264.0 number frames: 32.0
# --> taking every  5 th image
# Cov_combatting_Image2.mp4 framerate 31.833333333333332 width 440.0 height 440.0 number frames: 191.0
# --> taking every  10 th image
# Reg_pat2Image_134441.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 214.0
# --> taking every  8 th image
# Reg_Avi_Image004.mp4 framerate 50.261259019656634 width 586.0 height 586.0 number frames: 202.0
# --> taking every  16 th image
# Cov_combatting_Image3.mp4 framerate 29.0 width 440.0 height 440.0 number frames: 174.0
# --> taking every  9 th image
# Pneu-grep-pneumonia1.mp4 framerate 25.0 width 300.0 height 300.0 number frames: 151.0
# --> taking every  8 th image
# Pneu_basalpneumonia_liftle_case1.mp4 framerate 15.0 width 340.0 height 340.0 number frames: 42.0
# --> taking every  5 th image
# Pneu_northumbria_0409_set5_vid2.avi framerate 22.25 width 516.0 height 516.0 number frames: 92.0
# --> taking every  7 th image
# Cov-grepmed-blines-pocus-.mp4 framerate 20.0 width 450.0 height 450.0 number frames: 225.0
# --> taking every  6 th image
# Reg-Atlas-lungcurtain.gif framerate 10.0 width 212.0 height 212.0 number frames: 60.0
# --> taking every  3 th image
# Reg_pat2Image_134138.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 236.0
# --> taking every  8 th image
# Reg_alines_advancesVid4.mp4 framerate 29.97 width 450.0 height 450.0 number frames: 177.0
# --> taking every  9 th image
# Reg_pat4Image_140434.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 323.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set2_vid1.avi framerate 22.25 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Cov-Atlas-Day+3.gif framerate 10.0 width 240.0 height 240.0 number frames: 40.0
# --> taking every  3 th image
# Reg_Avi_lung-sliding-3.MP4 framerate 18.0 width 512.0 height 512.0 number frames: 55.0
# --> taking every  6 th image
# Reg_pat4Image_135904.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 266.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set4_vid1.avi framerate 22.25 width 500.0 height 500.0 number frames: 90.0
# --> taking every  7 th image
# Cov-grep-7543.mp4 framerate 20.833 width 350.0 height 350.0 number frames: 70.0
# --> taking every  6 th image
# Cov_denault_proposedUS_vid11.mov framerate 60.0 width 852.0 height 852.0 number frames: 143.0
# --> taking every  20 th image
# Reg_pat3Image_134711.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 216.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set3_vid2.avi framerate 22.25 width 528.0 height 528.0 number frames: 92.0
# --> taking every  7 th image
# Cov-clarius.mp4 framerate 10.0 width 350.0 height 350.0 number frames: 103.0
# --> taking every  3 th image
# Reg_northumbria_1009_vid3.avi framerate 22.249388753056234 width 441.0 height 441.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_Pneumonia-LITFL-Ultrasound_crop.mp4 framerate 15.0 width 316.0 height 316.0 number frames: 27.0
# --> taking every  5 th image
# Reg_pat1Image_132943.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 280.0
# --> taking every  8 th image
# Reg_Avi_Video_003.mp4 framerate 22.26935312831389 width 608.0 height 608.0 number frames: 84.0
# --> taking every  7 th image
# Reg_pat1Image_133410.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 182.0
# --> taking every  8 th image
# Pneu-grep-pulmonary-pneumonia.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 187.0
# --> taking every  10 th image
# Cov-grepmed2.mp4 framerate 33.333 width 280.0 height 280.0 number frames: 298.0
# --> taking every  11 th image
# Reg_northumbria_1009_vid2.avi framerate 22.25 width 476.0 height 476.0 number frames: 92.0
# --> taking every  7 th image
# Reg_liftl_pneucase3_clip1.mp4 framerate 15.0 width 286.0 height 286.0 number frames: 24.0
# --> taking every  5 th image
# Cov-Atlas-Day+2.gif framerate 10.0 width 142.0 height 142.0 number frames: 83.0
# --> taking every  3 th image
# Cov_convex_volpecelli_sonographic_v1.mov framerate 39.0 width 450.0 height 450.0 number frames: 403.0
# --> taking every  13 th image
# Reg_pat1Image_133327.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 218.0
# --> taking every  8 th image
# Pneu_Avi_Video_001.mp4 framerate 22.249388753056234 width 608.0 height 608.0 number frames: 91.0
# --> taking every  7 th image
# Reg-Atlas.gif framerate 10.0 width 250.0 height 250.0 number frames: 59.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set2_vid3.avi framerate 22.25 width 503.0 height 503.0 number frames: 92.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid8.avi framerate 22.249388753056234 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid4.avi framerate 22.249388753056234 width 519.0 height 519.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_clinicalreview_MOV4.mp4 framerate 50.0 width 400.0 height 400.0 number frames: 96.0
# --> taking every  16 th image
# Cov-Atlas-pleural2.mp4 framerate 25.0 width 414.0 height 414.0 number frames: 75.0
# --> taking every  8 th image
# Reg-NormalLung.mp4 framerate 12.0 width 330.0 height 330.0 number frames: 35.0
# --> taking every  4 th image
# Cov_emdocs_vid2.gif framerate 20.0 width 388.0 height 388.0 number frames: 106.0
# --> taking every  6 th image
# Reg_Image_18122_crop.mp4 framerate 19.10307487996731 width 208.0 height 208.0 number frames: 187.0
# --> taking every  6 th image
# Cov-grep-7431.mp4 framerate 39.0 width 400.0 height 400.0 number frames: 116.0
# --> taking every  13 th image
# Cov-Atlas-pleural.mp4 framerate 23.976023976023978 width 364.0 height 364.0 number frames: 77.0
# --> taking every  7 th image
# Reg-grep-normal-alines-original.mp4 framerate 60.0 width 250.0 height 250.0 number frames: 165.0
# --> taking every  20 th image
# Pneu_prospective_file3.mp4 framerate 25.0 width 260.0 height 260.0 number frames: 151.0
# --> taking every  8 th image
# Cov-grep-7432.mp4 framerate 29.97 width 550.0 height 550.0 number frames: 280.0
# --> taking every  9 th image
# Cov-grep-7500.mp4 framerate 25.0 width 300.0 height 300.0 number frames: 75.0
# --> taking every  8 th image
# Reg-nephropocus.mp4 framerate 10.0 width 350.0 height 350.0 number frames: 150.0
# --> taking every  3 th image
# Reg_Image_181206_crop.mp4 framerate 19.03846153846154 width 234.0 height 234.0 number frames: 495.0
# --> taking every  6 th image
# Reg-minimalmovement.mp4 framerate 15.0 width 350.0 height 350.0 number frames: 45.0
# --> taking every  5 th image
# Reg_Image_181432_crop.mp4 framerate 19.142098644683525 width 242.0 height 242.0 number frames: 137.0
# --> taking every  6 th image

# %%
#check how many files we have (here are the images, no video files left)
# !ls -1 /content/image_dataset/covid | wc -l
# !ls -1 /content/image_dataset/pneumonia | wc -l
# !ls -1 /content/image_dataset/regular | wc -l
# Out:
# 918
# 726
# 1380

# %%
#create splits for 5 fold cross validation
#for another method in "make folders to be ready for train and test"
#!python3 /content/cross_val_splitter.py --splits 5

# %% [markdown]
# #Make folders to be ready for train and test

# %% [markdown]
# **Using POCUS cropped images (image-dataset)**
#
# Making folders fold0 - fold5, where each folder has test, validation and train folders.
#
# First, we let kfold divide the data into 5 splits, which contain train and test data. Then we take a part of the train data, which we will use for validation (for early stopping)

# %%
import os
import shutil
from sklearn.model_selection import KFold, train_test_split
import numpy as np

data_dir = '/content/image_dataset'
classes = ['covid', 'pneumonia', 'regular']

data = []
labels = []

for class_name in classes:
    class_dir = os.path.join(data_dir, class_name)
    for image_name in os.listdir(class_dir):
        data.append(os.path.join(class_dir, image_name))
        labels.append(class_name)

data = np.array(data)
labels = np.array(labels)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
split_dir = os.path.join(data_dir, 'splits')
os.makedirs(split_dir, exist_ok=True)

for fold, (train_idx, test_idx) in enumerate(kf.split(data)):
    fold_dir = os.path.join(split_dir, f'fold_{fold}')
    os.makedirs(fold_dir, exist_ok=True)

    train_dir = os.path.join(fold_dir, 'train')
    val_dir = os.path.join(fold_dir, 'val')
    test_dir = os.path.join(fold_dir, 'test')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    train_data, val_data = train_test_split(train_idx, test_size=0.2, random_state=42)

    for idx in train_data:
        class_name = labels[idx]
        dest_folder = os.path.join(train_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

    for idx in val_data:
        class_name = labels[idx]
        dest_folder = os.path.join(val_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

    for idx in test_idx:
        class_name = labels[idx]
        dest_folder = os.path.join(test_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

# %%
import os

def count_files(directory):
    """Funkcija skaičiuoja failus kiekvienoje direktorijoje ir jos subdirektorijose."""
    total_files = 0
    for root, dirs, files in os.walk(directory):
        total_files += len(files)
    return total_files

data_dir = '/content/image_dataset/splits'  # Čia nurodykite savo splits katalogą

# Eiti per kiekvieną fold direktoriją
for fold in os.listdir(data_dir):
    fold_dir = os.path.join(data_dir, fold)
    train_dir = os.path.join(fold_dir, 'train')
    val_dir = os.path.join(fold_dir, 'val')
    test_dir = os.path.join(fold_dir, 'test')

    # Skaičiuojame failus kiekvienoje direktorijoje
    train_count = count_files(train_dir)
    val_count = count_files(val_dir)
    test_count = count_files(test_dir)

    print(f'{fold}:')
    print(f'  Training data: {train_count} files')
    print(f'  Validation data: {val_count} files')
    print(f'  Testing data: {test_count} files')
# Out:
# fold_1:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_4:
#   Training data: 1936 files
#   Validation data: 484 files
#   Testing data: 604 files
# fold_2:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_0:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_3:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files

# %% [markdown]
# **Using POCUS cross validation splits**
# (old method)
#
# Making folders fold0 - fold5, where each folder has test and train folders.
#
# In each fold, it will combine previous splits images (what are in cross_validation folder) as indicated:
#
# fold0:
# *   test -> images from folder split0;
# *   train -> images from folders split1-4
#
# other folders are generated in the same way

# %%
# import os

# base_dir = "/content/"
# crossval_dir = os.path.join(base_dir, "mySplits")

# # Base folders
# for i in range(0, 5):
#     fold_dir = os.path.join(crossval_dir, f"fold{i}")
#     train_dir = os.path.join(fold_dir, "train")
#     test_dir = os.path.join(fold_dir, "test")

#     # test and train folders
#     os.makedirs(train_dir, exist_ok=True)
#     os.makedirs(test_dir, exist_ok=True)

#     # classes folders
#     for class_name in ['covid', 'pneumonia', 'regular']:
#         os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
#         os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

# %%
# classes_names = ['covid', 'pneumonia', 'regular']  # classes names

# src_dir = '/content/cross_validation/'
# dest_dir = '/content/mySplits/'

# for i in range(0, 5):
#     test_index = i  # Test split
#     train_indices = [j for j in range(0, 5) if j != i]  # The remaining splits will be used for training
#     print(test_index)
#     print(train_indices)

#     # Copy test images
#     for cls in classes_names:
#         src_folder = os.path.join(src_dir, f"split{test_index}", cls)
#         dst_folder = os.path.join(dest_dir, f"fold{i}", "test", cls)

#         for filename in os.listdir(src_folder):
#             src_file = os.path.join(src_folder, filename)
#             dst_file = os.path.join(dst_folder, filename)
#             shutil.copy(src_file, dst_file)

#     # Copy train images
#     for train_index in train_indices:
#         for cls in classes_names:
#             src_folder = os.path.join(src_dir, f"split{train_index}", cls)
#             dst_folder = os.path.join(dest_dir, f"fold{i}", "train", cls)
#             for filename in os.listdir(src_folder):
#                 src_file = os.path.join(src_folder, filename)
#                 dst_file = os.path.join(dst_folder, filename)
#                 shutil.copy(src_file, dst_file)

# %% [markdown]
# #Trying and evaluating with Keras

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
import numpy as np
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
import itertools
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Data generators with augmentation for the training set
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,  # Added vertical flip
    brightness_range=[0.8,1.2],  # Adjust brightness
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input
)


# Specify image dimensions, batch size
img_height = 224
img_width = 224
batch_size = 32

# %%
#functions
# Plot the training graph
def plot_training(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Training accuracy in red
    plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
    # Validation accuracy in blue
    plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
    plt.title('Treniravimo ir validacijos tikslumas')
    plt.legend()

    plt.figure()

    # Training loss in red
    plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
    # Validation loss in blue
    plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
    plt.title('Treniravimo ir validacijos nuostoliai')
    plt.legend()

    plt.show()

# Function to calculate specificity for each class
def calculate_specificity(conf_matrix, class_index):
    tn = np.sum(conf_matrix) - np.sum(conf_matrix[class_index, :]) - np.sum(conf_matrix[:, class_index]) + conf_matrix[class_index, class_index]
    fp = np.sum(conf_matrix[:, class_index]) - conf_matrix[class_index, class_index]
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    return specificity

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Klasifikavimo lentelė',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Tikra klasė')
    plt.xlabel('Spėjama klasė')

# Focal Loss
def focal_loss(gamma=2., alpha=4.):
    gamma = float(gamma)
    alpha = float(alpha)
    def focal_loss_fixed(y_true, y_pred):
        epsilon = 1.e-9
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        y_true = tf.cast(y_true, tf.float32)
        loss = -y_true * alpha * tf.pow((1 - y_pred), gamma) * tf.math.log(y_pred)
        loss = tf.reduce_sum(loss, axis=1)
        return loss
    return focal_loss_fixed

# %% [markdown]
# ## Cross entropy + RMSProp + 0.001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = RMSprop(learning_rate=0.001)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 58s 647ms/step - loss: 0.6865 - accuracy: 0.7282 - auc: 0.8878 - val_loss: 0.6657 - val_accuracy: 0.6508 - val_auc: 0.8736
# Epoch 2/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.4427 - accuracy: 0.8372 - auc: 0.9501 - val_loss: 0.3863 - val_accuracy: 0.8595 - val_auc: 0.9593
# Epoch 3/30
# 61/61 [==============================] - 35s 565ms/step - loss: 0.3185 - accuracy: 0.8842 - auc: 0.9735 - val_loss: 0.4805 - val_accuracy: 0.8099 - val_auc: 0.9478
# Epoch 4/30
# 61/61 [==============================] - 35s 570ms/step - loss: 0.2933 - accuracy: 0.8961 - auc: 0.9777 - val_loss: 0.1967 - val_accuracy: 0.9215 - val_auc: 0.9895
# Epoch 5/30
# 61/61 [==============================] - 34s 560ms/step - loss: 0.2464 - accuracy: 0.9152 - auc: 0.9835 - val_loss: 0.2538 - val_accuracy: 0.9132 - val_auc: 0.9826
# Epoch 6/30
# 61/61 [==============================] - 34s 562ms/step - loss: 0.2055 - accuracy: 0.9230 - auc: 0.9872 - val_loss: 0.1579 - val_accuracy: 0.9318 - val_auc: 0.9934
# Epoch 7/30
# 61/61 [==============================] - 37s 609ms/step - loss: 0.2007 - accuracy: 0.9271 - auc: 0.9886 - val_loss: 0.1337 - val_accuracy: 0.9421 - val_auc: 0.9950
# Epoch 8/30
# 61/61 [==============================] - 35s 566ms/step - loss: 0.1788 - accuracy: 0.9421 - auc: 0.9901 - val_loss: 0.1808 - val_accuracy: 0.9339 - val_auc: 0.9923
# Epoch 9/30
# 61/61 [==============================] - 34s 560ms/step - loss: 0.2007 - accuracy: 0.9349 - auc: 0.9883 - val_loss: 0.2281 - val_accuracy: 0.9070 - val_auc: 0.9860
# Epoch 10/30
# 61/61 [==============================] - 35s 566ms/step - loss: 0.1741 - accuracy: 0.9406 - auc: 0.9901 - val_loss: 0.1325 - val_accuracy: 0.9525 - val_auc: 0.9936
# Epoch 11/30
# 61/61 [==============================] - 35s 565ms/step - loss: 0.1483 - accuracy: 0.9509 - auc: 0.9929 - val_loss: 0.1616 - val_accuracy: 0.9483 - val_auc: 0.9913
# Epoch 12/30
# 61/61 [==============================] - 36s 594ms/step - loss: 0.1431 - accuracy: 0.9447 - auc: 0.9926 - val_loss: 0.1899 - val_accuracy: 0.9360 - val_auc: 0.9918
# Epoch 13/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.1186 - accuracy: 0.9633 - auc: 0.9949 - val_loss: 0.0864 - val_accuracy: 0.9773 - val_auc: 0.9970
# Epoch 14/30
# 61/61 [==============================] - 36s 591ms/step - loss: 0.1354 - accuracy: 0.9576 - auc: 0.9930 - val_loss: 0.4163 - val_accuracy: 0.8636 - val_auc: 0.9688
# Epoch 15/30
# 61/61 [==============================] - 35s 574ms/step - loss: 0.1206 - accuracy: 0.9556 - auc: 0.9948 - val_loss: 0.1204 - val_accuracy: 0.9587 - val_auc: 0.9962
# Epoch 16/30
# 61/61 [==============================] - 36s 576ms/step - loss: 0.1225 - accuracy: 0.9597 - auc: 0.9946 - val_loss: 0.2806 - val_accuracy: 0.9215 - val_auc: 0.9800
# Epoch 17/30
# 61/61 [==============================] - 37s 597ms/step - loss: 0.1116 - accuracy: 0.9623 - auc: 0.9957 - val_loss: 0.0980 - val_accuracy: 0.9628 - val_auc: 0.9973
# Epoch 18/30
# 61/61 [==============================] - 35s 570ms/step - loss: 0.1055 - accuracy: 0.9654 - auc: 0.9958 - val_loss: 0.2406 - val_accuracy: 0.9339 - val_auc: 0.9829
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_0.h5
# <ipython-input-23-c6f8e5b77fca>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 156ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.99      0.98      0.98       203
#    pneumonia       0.96      0.93      0.95       139
#      regular       0.96      0.98      0.97       263
#
#     accuracy                           0.97       605
#    macro avg       0.97      0.96      0.96       605
# weighted avg       0.97      0.97      0.97       605
#
# Accuracy: 0.9669421487603306
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.96
# Macro-average Specificity: 0.98
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 1
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 50s 617ms/step - loss: 0.7618 - accuracy: 0.6987 - auc_1: 0.8646 - val_loss: 0.6462 - val_accuracy: 0.6570 - val_auc_1: 0.8844
# Epoch 2/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.4721 - accuracy: 0.8227 - auc_1: 0.9427 - val_loss: 0.4680 - val_accuracy: 0.7934 - val_auc_1: 0.9404
# Epoch 3/30
# 61/61 [==============================] - 36s 588ms/step - loss: 0.3535 - accuracy: 0.8672 - auc_1: 0.9687 - val_loss: 0.2651 - val_accuracy: 0.9050 - val_auc_1: 0.9819
# Epoch 4/30
# 61/61 [==============================] - 36s 593ms/step - loss: 0.3258 - accuracy: 0.8755 - auc_1: 0.9718 - val_loss: 0.6431 - val_accuracy: 0.7149 - val_auc_1: 0.9190
# Epoch 5/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.3054 - accuracy: 0.8910 - auc_1: 0.9749 - val_loss: 0.2372 - val_accuracy: 0.9112 - val_auc_1: 0.9843
# Epoch 6/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.2386 - accuracy: 0.9147 - auc_1: 0.9841 - val_loss: 0.3722 - val_accuracy: 0.8657 - val_auc_1: 0.9676
# Epoch 7/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.2461 - accuracy: 0.9106 - auc_1: 0.9820 - val_loss: 0.1799 - val_accuracy: 0.9318 - val_auc_1: 0.9913
# Epoch 8/30
# 61/61 [==============================] - 36s 580ms/step - loss: 0.2145 - accuracy: 0.9209 - auc_1: 0.9866 - val_loss: 0.1387 - val_accuracy: 0.9483 - val_auc_1: 0.9930
# Epoch 9/30
# 61/61 [==============================] - 34s 561ms/step - loss: 0.2068 - accuracy: 0.9282 - auc_1: 0.9879 - val_loss: 0.2176 - val_accuracy: 0.9215 - val_auc_1: 0.9887
# Epoch 10/30
# 61/61 [==============================] - 35s 566ms/step - loss: 0.2093 - accuracy: 0.9266 - auc_1: 0.9861 - val_loss: 0.2154 - val_accuracy: 0.9215 - val_auc_1: 0.9883
# Epoch 11/30
# 61/61 [==============================] - 36s 593ms/step - loss: 0.1608 - accuracy: 0.9432 - auc_1: 0.9920 - val_loss: 0.2540 - val_accuracy: 0.9153 - val_auc_1: 0.9845
UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_1.h5
# <ipython-input-23-c6f8e5b77fca>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 74ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       1.00      0.91      0.95       175
#    pneumonia       0.98      0.96      0.97       152
#      regular       0.93      0.99      0.96       278
#
#     accuracy                           0.96       605
#    macro avg       0.97      0.95      0.96       605
# weighted avg       0.96      0.96      0.96       605
#
# Accuracy: 0.9603305785123967
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.94
# Macro-average Specificity: 0.98
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 50s 590ms/step - loss: 0.7393 - accuracy: 0.7225 - auc_2: 0.8732 - val_loss: 0.6548 - val_accuracy: 0.7231 - val_auc_2: 0.8883
# Epoch 2/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.4099 - accuracy: 0.8398 - auc_2: 0.9561 - val_loss: 0.6381 - val_accuracy: 0.7789 - val_auc_2: 0.9077
# Epoch 3/30
# 61/61 [==============================] - 37s 610ms/step - loss: 0.3451 - accuracy: 0.8651 - auc_2: 0.9690 - val_loss: 0.3853 - val_accuracy: 0.8533 - val_auc_2: 0.9607
# Epoch 4/30
# 61/61 [==============================] - 35s 573ms/step - loss: 0.3390 - accuracy: 0.8858 - auc_2: 0.9695 - val_loss: 0.2944 - val_accuracy: 0.8864 - val_auc_2: 0.9773
# Epoch 5/30
# 61/61 [==============================] - 35s 569ms/step - loss: 0.2799 - accuracy: 0.8904 - auc_2: 0.9771 - val_loss: 0.3290 - val_accuracy: 0.8698 - val_auc_2: 0.9713
# Epoch 6/30
# 61/61 [==============================] - 35s 564ms/step - loss: 0.2569 - accuracy: 0.9044 - auc_2: 0.9808 - val_loss: 0.4901 - val_accuracy: 0.8430 - val_auc_2: 0.9543
# Epoch 7/30
# 61/61 [==============================] - 36s 597ms/step - loss: 0.2143 - accuracy: 0.9194 - auc_2: 0.9871 - val_loss: 0.3760 - val_accuracy: 0.8678 - val_auc_2: 0.9691
# Epoch 8/30
# 61/61 [==============================] - 34s 559ms/step - loss: 0.2159 - accuracy: 0.9251 - auc_2: 0.9868 - val_loss: 0.3226 - val_accuracy: 0.8884 - val_auc_2: 0.9752
# Epoch 9/30
# 61/61 [==============================] - 36s 596ms/step - loss: 0.1907 - accuracy: 0.9266 - auc_2: 0.9889 - val_loss: 0.2060 - val_accuracy: 0.9194 - val_auc_2: 0.9882
# Epoch 10/30
# 61/61 [==============================] - 36s 585ms/step - loss: 0.2010 - accuracy: 0.9282 - auc_2: 0.9876 - val_loss: 0.2474 - val_accuracy: 0.9215 - val_auc_2: 0.9855
# Epoch 11/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.1801 - accuracy: 0.9375 - auc_2: 0.9903 - val_loss: 0.3593 - val_accuracy: 0.9008 - val_auc_2: 0.9713
# Epoch 12/30
# 61/61 [==============================] - 36s 586ms/step - loss: 0.1773 - accuracy: 0.9437 - auc_2: 0.9895 - val_loss: 0.2325 - val_accuracy: 0.9132 - val_auc_2: 0.9864
# Epoch 13/30
# 61/61 [==============================] - 38s 625ms/step - loss: 0.1303 - accuracy: 0.9561 - auc_2: 0.9935 - val_loss: 0.3508 - val_accuracy: 0.9029 - val_auc_2: 0.9749
# Epoch 14/30
# 61/61 [==============================] - 37s 605ms/step - loss: 0.1434 - accuracy: 0.9463 - auc_2: 0.9935 - val_loss: 0.3612 - val_accuracy: 0.8905 - val_auc_2: 0.9773
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_2.h5
# <ipython-input-23-c6f8e5b77fca>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 78ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.98      0.88      0.93       180
#    pneumonia       0.95      0.96      0.95       136
#      regular       0.93      0.99      0.96       289
#
#     accuracy                           0.95       605
#    macro avg       0.96      0.94      0.95       605
# weighted avg       0.95      0.95      0.95       605
#
# Accuracy: 0.9504132231404959
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.94
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 50s 597ms/step - loss: 0.7137 - accuracy: 0.7302 - auc_3: 0.8807 - val_loss: 0.5248 - val_accuracy: 0.8037 - val_auc_3: 0.9235
# Epoch 2/30
# 61/61 [==============================] - 35s 573ms/step - loss: 0.4049 - accuracy: 0.8496 - auc_3: 0.9576 - val_loss: 0.3148 - val_accuracy: 0.8740 - val_auc_3: 0.9717
# Epoch 3/30
# 61/61 [==============================] - 35s 581ms/step - loss: 0.3725 - accuracy: 0.8672 - auc_3: 0.9649 - val_loss: 0.3212 - val_accuracy: 0.8864 - val_auc_3: 0.9701
# Epoch 4/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.3154 - accuracy: 0.8837 - auc_3: 0.9741 - val_loss: 0.1587 - val_accuracy: 0.9256 - val_auc_3: 0.9934
# Epoch 5/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.2667 - accuracy: 0.9039 - auc_3: 0.9805 - val_loss: 0.1479 - val_accuracy: 0.9483 - val_auc_3: 0.9935
# Epoch 6/30
# 61/61 [==============================] - 35s 570ms/step - loss: 0.2361 - accuracy: 0.9059 - auc_3: 0.9848 - val_loss: 0.1448 - val_accuracy: 0.9442 - val_auc_3: 0.9946
# Epoch 7/30
# 61/61 [==============================] - 36s 591ms/step - loss: 0.2194 - accuracy: 0.9209 - auc_3: 0.9874 - val_loss: 0.1705 - val_accuracy: 0.9298 - val_auc_3: 0.9920
# Epoch 8/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.2096 - accuracy: 0.9168 - auc_3: 0.9873 - val_loss: 0.1825 - val_accuracy: 0.9256 - val_auc_3: 0.9911
# Epoch 9/30
# 61/61 [==============================] - 36s 592ms/step - loss: 0.1948 - accuracy: 0.9307 - auc_3: 0.9888 - val_loss: 0.0983 - val_accuracy: 0.9628 - val_auc_3: 0.9973
# Epoch 10/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.1804 - accuracy: 0.9282 - auc_3: 0.9909 - val_loss: 0.1945 - val_accuracy: 0.9256 - val_auc_3: 0.9904
# Epoch 11/30
# 61/61 [==============================] - 35s 568ms/step - loss: 0.1825 - accuracy: 0.9339 - auc_3: 0.9911 - val_loss: 0.0867 - val_accuracy: 0.9711 - val_auc_3: 0.9976
# Epoch 12/30
# 61/61 [==============================] - 38s 615ms/step - loss: 0.1693 - accuracy: 0.9370 - auc_3: 0.9924 - val_loss: 0.0780 - val_accuracy: 0.9711 - val_auc_3: 0.9980
# Epoch 13/30
# 61/61 [==============================] - 36s 590ms/step - loss: 0.1590 - accuracy: 0.9488 - auc_3: 0.9918 - val_loss: 0.1009 - val_accuracy: 0.9731 - val_auc_3: 0.9971
# Epoch 14/30
# 61/61 [==============================] - 34s 563ms/step - loss: 0.1828 - accuracy: 0.9380 - auc_3: 0.9903 - val_loss: 0.1057 - val_accuracy: 0.9587 - val_auc_3: 0.9956
# Epoch 15/30
# 61/61 [==============================] - 35s 572ms/step - loss: 0.1546 - accuracy: 0.9509 - auc_3: 0.9929 - val_loss: 0.1810 - val_accuracy: 0.9360 - val_auc_3: 0.9900
# Epoch 16/30
# 61/61 [==============================] - 36s 591ms/step - loss: 0.1469 - accuracy: 0.9468 - auc_3: 0.9933 - val_loss: 0.0887 - val_accuracy: 0.9752 - val_auc_3: 0.9975
# Epoch 17/30
# 61/61 [==============================] - 35s 579ms/step - loss: 0.1472 - accuracy: 0.9504 - auc_3: 0.9934 - val_loss: 0.1410 - val_accuracy: 0.9504 - val_auc_3: 0.9934
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_3.h5
# <ipython-input-23-c6f8e5b77fca>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 84ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.95      0.98      0.96       187
#    pneumonia       0.93      0.97      0.95       145
#      regular       0.98      0.94      0.96       273
#
#     accuracy                           0.96       605
#    macro avg       0.95      0.96      0.96       605
# weighted avg       0.96      0.96      0.96       605
#
# Accuracy: 0.9586776859504132
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.98
# Macro-average Specificity: 0.98
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 51s 625ms/step - loss: 0.7313 - accuracy: 0.7180 - auc_4: 0.8767 - val_loss: 0.6971 - val_accuracy: 0.7025 - val_auc_4: 0.8688
UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_fold_4.h5
# <ipython-input-23-c6f8e5b77fca>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 5s 159ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.93      0.91      0.92       173
#    pneumonia       0.97      0.86      0.91       154
#      regular       0.91      0.98      0.94       277
#
#     accuracy                           0.93       604
#    macro avg       0.94      0.92      0.93       604
# weighted avg       0.93      0.93      0.93       604
#
# Accuracy: 0.9288079470198676
# Specificity for covid: 0.97
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.91
# Macro-average Specificity: 0.96
# Final Metrics Across All Folds:
# Average Accuracy: 0.95 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.97 ± 0.02
# Class covid - Average Recall: 0.93 ± 0.04
# Class covid - Average F1 Score: 0.95 ± 0.02
# Class pneumonia - Average Precision: 0.96 ± 0.02
# Class pneumonia - Average Recall: 0.93 ± 0.04
# Class pneumonia - Average F1 Score: 0.95 ± 0.02
# Class regular - Average Precision: 0.94 ± 0.03
# Class regular - Average Recall: 0.98 ± 0.02
# Class regular - Average F1 Score: 0.96 ± 0.01

# %% [markdown]
# ## Cross entropy + RMSProp + 0.0001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = RMSprop(learning_rate=0.0001)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 62s 677ms/step - loss: 0.9381 - accuracy: 0.5561 - auc: 0.7489 - val_loss: 0.8961 - val_accuracy: 0.5331 - val_auc: 0.7679
# Epoch 2/30
# 61/61 [==============================] - 40s 663ms/step - loss: 0.6995 - accuracy: 0.7168 - auc: 0.8723 - val_loss: 0.7048 - val_accuracy: 0.6384 - val_auc: 0.8620
# Epoch 3/30
# 61/61 [==============================] - 38s 619ms/step - loss: 0.5889 - accuracy: 0.7602 - auc: 0.9090 - val_loss: 0.5003 - val_accuracy: 0.7934 - val_auc: 0.9370
# Epoch 4/30
# 61/61 [==============================] - 40s 658ms/step - loss: 0.5237 - accuracy: 0.7928 - auc: 0.9268 - val_loss: 0.4468 - val_accuracy: 0.7913 - val_auc: 0.9462
# Epoch 5/30
# 61/61 [==============================] - 40s 656ms/step - loss: 0.4805 - accuracy: 0.8114 - auc: 0.9380 - val_loss: 0.3887 - val_accuracy: 0.8326 - val_auc: 0.9600
# Epoch 6/30
# 61/61 [==============================] - 38s 621ms/step - loss: 0.3978 - accuracy: 0.8496 - auc: 0.9560 - val_loss: 0.3566 - val_accuracy: 0.8657 - val_auc: 0.9671
# Epoch 7/30
# 61/61 [==============================] - 40s 647ms/step - loss: 0.3865 - accuracy: 0.8491 - auc: 0.9588 - val_loss: 0.3036 - val_accuracy: 0.8905 - val_auc: 0.9759
# Epoch 8/30
# Epoch 24/30
# 61/61 [==============================] - 40s 654ms/step - loss: 0.1922 - accuracy: 0.9266 - auc: 0.9883 - val_loss: 0.1413 - val_accuracy: 0.9463 - val_auc: 0.9943
# Epoch 25/30
# 61/61 [==============================] - 40s 656ms/step - loss: 0.1866 - accuracy: 0.9318 - auc: 0.9901 - val_loss: 0.1189 - val_accuracy: 0.9504 - val_auc: 0.9959
# Epoch 26/30
# 61/61 [==============================] - 38s 622ms/step - loss: 0.1787 - accuracy: 0.9354 - auc: 0.9903 - val_loss: 0.1291 - val_accuracy: 0.9483 - val_auc: 0.9944
# Epoch 27/30
# 61/61 [==============================] - 40s 647ms/step - loss: 0.2098 - accuracy: 0.9240 - auc: 0.9872 - val_loss: 0.1394 - val_accuracy: 0.9483 - val_auc: 0.9944
# Epoch 28/30
# 61/61 [==============================] - 40s 663ms/step - loss: 0.1774 - accuracy: 0.9282 - auc: 0.9901 - val_loss: 0.1349 - val_accuracy: 0.9442 - val_auc: 0.9947
# Epoch 29/30
# 61/61 [==============================] - 39s 640ms/step - loss: 0.1572 - accuracy: 0.9380 - auc: 0.9922 - val_loss: 0.1344 - val_accuracy: 0.9504 - val_auc: 0.9948
# Epoch 30/30
# 61/61 [==============================] - 38s 623ms/step - loss: 0.1616 - accuracy: 0.9401 - auc: 0.9918 - val_loss: 0.1562 - val_accuracy: 0.9339 - val_auc: 0.9932
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_0.h5
# <ipython-input-22-0098ee0b188d>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 5s 176ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.99      0.88      0.93       203
#    pneumonia       0.97      0.96      0.96       139
#      regular       0.90      0.98      0.94       263
#
#     accuracy                           0.94       605
#    macro avg       0.95      0.94      0.95       605
# weighted avg       0.95      0.94      0.94       605
#
# Accuracy: 0.943801652892562
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.92
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# 61/61 [==============================] - 39s 646ms/step - loss: 0.1976 - accuracy: 0.9230 - auc_1: 0.9884 - val_loss: 0.1559 - val_accuracy: 0.9318 - val_auc_1: 0.9932
# Epoch 30/30
# 61/61 [==============================] - 40s 649ms/step - loss: 0.1640 - accuracy: 0.9333 - auc_1: 0.9918 - val_loss: 0.1782 - val_accuracy: 0.9277 - val_auc_1: 0.9915
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_1.h5
# <ipython-input-22-0098ee0b188d>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 84ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       0.98      0.87      0.92       175
#    pneumonia       0.92      0.97      0.95       152
#      regular       0.92      0.96      0.94       278
#
#     accuracy                           0.94       605
#    macro avg       0.94      0.93      0.94       605
# weighted avg       0.94      0.94      0.94       605
#
# Accuracy: 0.9355371900826446
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.97
# Specificity for regular: 0.93
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 54s 648ms/step - loss: 0.9073 - accuracy: 0.5912 - auc_2: 0.7652 - val_loss: 0.8737 - val_accuracy: 0.5579 - val_auc_2: 0.7811
# Epoch 2/30
# 61/61 [==============================] - 40s 650ms/step - loss: 0.6812 - accuracy: 0.7297 - auc_2: 0.8782 - val_loss: 0.7349 - val_accuracy: 0.6198 - val_auc_2: 0.8449
# Epoch 3/30
# 61/61 [==============================] - 38s 619ms/step - loss: 0.5695 - accuracy: 0.7747 - auc_2: 0.9152 - val_loss: 0.6279 - val_accuracy: 0.7087 - val_auc_2: 0.8904
# Epoch 4/30
# 61/61 [==============================] - 37s 613ms/step - loss: 0.4894 - accuracy: 0.8124 - auc_2: 0.9370 - val_loss: 0.5296 - val_accuracy: 0.7748 - val_auc_2: 0.9242
# Epoch 5/30
# Epoch 20/30
# 61/61 [==============================] - 40s 658ms/step - loss: 0.2215 - accuracy: 0.9178 - auc_2: 0.9858 - val_loss: 0.2434 - val_accuracy: 0.9194 - val_auc_2: 0.9807
# Epoch 21/30
# 61/61 [==============================] - 39s 643ms/step - loss: 0.2046 - accuracy: 0.9235 - auc_2: 0.9880 - val_loss: 0.2426 - val_accuracy: 0.9194 - val_auc_2: 0.9811
# Epoch 22/30
# 61/61 [==============================] - 38s 619ms/step - loss: 0.1982 - accuracy: 0.9261 - auc_2: 0.9882 - val_loss: 0.2341 - val_accuracy: 0.9174 - val_auc_2: 0.9823
# Epoch 23/30
# 61/61 [==============================] - 39s 628ms/step - loss: 0.2095 - accuracy: 0.9214 - auc_2: 0.9873 - val_loss: 0.2482 - val_accuracy: 0.9132 - val_auc_2: 0.9805
# Epoch 24/30
# 61/61 [==============================] - 40s 650ms/step - loss: 0.1954 - accuracy: 0.9287 - auc_2: 0.9889 - val_loss: 0.1895 - val_accuracy: 0.9360 - val_auc_2: 0.9891
# Epoch 25/30
# 61/61 [==============================] - 38s 615ms/step - loss: 0.1864 - accuracy: 0.9276 - auc_2: 0.9895 - val_loss: 0.2011 - val_accuracy: 0.9339 - val_auc_2: 0.9869
# Epoch 26/30
# 61/61 [==============================] - 39s 628ms/step - loss: 0.1820 - accuracy: 0.9302 - auc_2: 0.9901 - val_loss: 0.1937 - val_accuracy: 0.9339 - val_auc_2: 0.9878
# Epoch 27/30
# 61/61 [==============================] - 40s 653ms/step - loss: 0.1757 - accuracy: 0.9313 - auc_2: 0.9910 - val_loss: 0.2219 - val_accuracy: 0.9194 - val_auc_2: 0.9845
# Epoch 28/30
# 61/61 [==============================] - 38s 627ms/step - loss: 0.1791 - accuracy: 0.9333 - auc_2: 0.9903 - val_loss: 0.2297 - val_accuracy: 0.9256 - val_auc_2: 0.9830
# Epoch 29/30
# 61/61 [==============================] - 39s 627ms/step - loss: 0.1724 - accuracy: 0.9349 - auc_2: 0.9913 - val_loss: 0.1966 - val_accuracy: 0.9298 - val_auc_2: 0.9868
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_2.h5
# <ipython-input-22-0098ee0b188d>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 112ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.97      0.91      0.94       180
#    pneumonia       0.96      0.93      0.95       136
#      regular       0.93      0.98      0.95       289
#
#     accuracy                           0.95       605
#    macro avg       0.95      0.94      0.95       605
# weighted avg       0.95      0.95      0.95       605
#
# Accuracy: 0.947107438016529
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.93
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 52s 614ms/step - loss: 0.9555 - accuracy: 0.5540 - auc_3: 0.7401 - val_loss: 0.9048 - val_accuracy: 0.5165 - val_auc_3: 0.7624
# Epoch 2/30
# 61/61 [==============================] - 39s 631ms/step - loss: 0.7094 - accuracy: 0.7070 - auc_3: 0.8699 - val_loss: 0.7780 - val_accuracy: 0.5847 - val_auc_3: 0.8246
# Epoch 3/30
# 61/61 [==============================] - 38s 622ms/step - loss: 0.5918 - accuracy: 0.7576 - auc_3: 0.9070 - val_loss: 0.6086 - val_accuracy: 0.7231 - val_auc_3: 0.8982
# Epoch 4/30
# 61/61 [==============================] - 39s 640ms/step - loss: 0.5135 - accuracy: 0.7948 - auc_3: 0.9301 - val_loss: 0.4845 - val_accuracy: 0.7913 - val_auc_3: 0.9387
# Epoch 5/30
# 61/61 [==============================] - 37s 612ms/step - loss: 0.4650 - accuracy: 0.8155 - auc_3: 0.9424 - val_loss: 0.4321 - val_accuracy: 0.7975 - val_auc_3: 0.9494
# Epoch 6/30
# 61/61 [==============================] - 39s 642ms/step - loss: 0.4246 - accuracy: 0.8341 - auc_3: 0.9528 - val_loss: 0.3638 - val_accuracy: 0.8285 - val_auc_3: 0.9659
# Epoch 7/30
# 61/61 [==============================] - 39s 645ms/step - loss: 0.3993 - accuracy: 0.8496 - auc_3: 0.9570 - val_loss: 0.3317 - val_accuracy: 0.8512 - val_auc_3: 0.9716
# Epoch 8/30
# 61/61 [==============================] - 37s 613ms/step - loss: 0.3808 - accuracy: 0.8563 - auc_3: 0.9607 - val_loss: 0.2695 - val_accuracy: 0.8967 - val_auc_3: 0.9818
# Epoch 9/30
# 61/61 [==============================] - 38s 614ms/step - loss: 0.3650 - accuracy: 0.8543 - auc_3: 0.9639 - val_loss: 0.2410 - val_accuracy: 0.8946 - val_auc_3: 0.9855
# Epoch 10/30
# 61/61 [==============================] - 37s 611ms/step - loss: 0.3357 - accuracy: 0.8682 - auc_3: 0.9696 - val_loss: 0.2169 - val_accuracy: 0.9194 - val_auc_3: 0.9879
# Epoch 11/30
# 61/61 [==============================] - 38s 616ms/step - loss: 0.3264 - accuracy: 0.8749 - auc_3: 0.9716 - val_loss: 0.1920 - val_accuracy: 0.9277 - val_auc_3: 0.9910
UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_3.h5
# <ipython-input-22-0098ee0b188d>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 122ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.96      0.93      0.95       187
#    pneumonia       0.97      0.92      0.95       145
#      regular       0.92      0.97      0.94       273
#
#     accuracy                           0.95       605
#    macro avg       0.95      0.94      0.95       605
# weighted avg       0.95      0.95      0.95       605
#
# Accuracy: 0.9454545454545454
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.93
# Macro-average Specificity: 0.97
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 53s 639ms/step - loss: 0.9150 - accuracy: 0.5945 - auc_4: 0.7657 - val_loss: 0.8412 - val_accuracy: 0.5888 - val_auc_4: 0.8010
# Epoch 2/30
# 61/61 [==============================] - 38s 621ms/step - loss: 0.6487 - accuracy: 0.7438 - auc_4: 0.8907 - val_loss: 0.6905 - val_accuracy: 0.6777 - val_auc_4: 0.8671
# Epoch 3/30
# 61/61 [==============================] - 39s 636ms/step - loss: 0.5740 - accuracy: 0.7707 - auc_4: 0.9112 - val_loss: 0.5490 - val_accuracy: 0.7748 - val_auc_4: 0.9191
# Epoch 4/30
# 61/61 [==============================] - 39s 644ms/step - loss: 0.4989 - accuracy: 0.8084 - auc_4: 0.9360 - val_loss: 0.4496 - val_accuracy: 0.8223 - val_auc_4: 0.9456
# Epoch 5/30
# 61/61 [==============================] - 37s 609ms/step - loss: 0.4601 - accuracy: 0.8275 - auc_4: 0.9446 - val_loss: 0.4532 - val_accuracy: 0.7996 - val_auc_4: 0.9448
# Epoch 6/30
# Epoch 21/30
# 61/61 [==============================] - 36s 596ms/step - loss: 0.1973 - accuracy: 0.9241 - auc_4: 0.9885 - val_loss: 0.2466 - val_accuracy: 0.9215 - val_auc_4: 0.9798
# Epoch 22/30
# 61/61 [==============================] - 36s 594ms/step - loss: 0.2090 - accuracy: 0.9199 - auc_4: 0.9872 - val_loss: 0.2454 - val_accuracy: 0.9153 - val_auc_4: 0.9828
# Epoch 23/30
# 61/61 [==============================] - 36s 595ms/step - loss: 0.1993 - accuracy: 0.9272 - auc_4: 0.9886 - val_loss: 0.2266 - val_accuracy: 0.9380 - val_auc_4: 0.9843
# Epoch 24/30
# 61/61 [==============================] - 39s 645ms/step - loss: 0.1945 - accuracy: 0.9230 - auc_4: 0.9886 - val_loss: 0.2577 - val_accuracy: 0.9194 - val_auc_4: 0.9790
# Epoch 25/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.1815 - accuracy: 0.9272 - auc_4: 0.9900 - val_loss: 0.2256 - val_accuracy: 0.9421 - val_auc_4: 0.9856
# Epoch 26/30
# 61/61 [==============================] - 38s 623ms/step - loss: 0.1940 - accuracy: 0.9298 - auc_4: 0.9881 - val_loss: 0.2097 - val_accuracy: 0.9360 - val_auc_4: 0.9860
# Epoch 27/30
# 61/61 [==============================] - 37s 606ms/step - loss: 0.1685 - accuracy: 0.9334 - auc_4: 0.9920 - val_loss: 0.2117 - val_accuracy: 0.9360 - val_auc_4: 0.9860
# Epoch 28/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.1960 - accuracy: 0.9303 - auc_4: 0.9879 - val_loss: 0.2244 - val_accuracy: 0.9318 - val_auc_4: 0.9839
# Epoch 29/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.1820 - accuracy: 0.9380 - auc_4: 0.9892 - val_loss: 0.2266 - val_accuracy: 0.9318 - val_auc_4: 0.9832
# Epoch 30/30
# 61/61 [==============================] - 36s 592ms/step - loss: 0.1853 - accuracy: 0.9390 - auc_4: 0.9898 - val_loss: 0.2626 - val_accuracy: 0.9277 - val_auc_4: 0.9775
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_rmsprop_0.0001_fold_4.h5
# <ipython-input-22-0098ee0b188d>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 5s 161ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.99      0.82      0.90       173
#    pneumonia       0.95      0.95      0.95       154
#      regular       0.88      0.98      0.93       277
#
#     accuracy                           0.93       604
#    macro avg       0.94      0.92      0.93       604
# weighted avg       0.93      0.93      0.92       604
#
# Accuracy: 0.9254966887417219
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.89
# Macro-average Specificity: 0.96
# Final Metrics Across All Folds:
# Average Accuracy: 0.94 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.98 ± 0.01
# Class covid - Average Recall: 0.88 ± 0.04
# Class covid - Average F1 Score: 0.93 ± 0.02
# Class pneumonia - Average Precision: 0.96 ± 0.02
# Class pneumonia - Average Recall: 0.95 ± 0.02
# Class pneumonia - Average F1 Score: 0.95 ± 0.01
# Class regular - Average Precision: 0.91 ± 0.02
# Class regular - Average Recall: 0.97 ± 0.01
# Class regular - Average F1 Score: 0.94 ± 0.01

# %% [markdown]
# ## Focal + RMSProp + 0.0001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = RMSprop(learning_rate=0.0001)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
# 61/61 [==============================] - 35s 565ms/step - loss: 0.3430 - accuracy: 0.9127 - auc_5: 0.9847 - val_loss: 0.1753 - val_accuracy: 0.9421 - val_auc_5: 0.9945
# Epoch 29/30
# 61/61 [==============================] - 35s 578ms/step - loss: 0.3182 - accuracy: 0.9240 - auc_5: 0.9863 - val_loss: 0.2394 - val_accuracy: 0.9298 - val_auc_5: 0.9909
# Epoch 30/30
# 61/61 [==============================] - 35s 570ms/step - loss: 0.3159 - accuracy: 0.9225 - auc_5: 0.9862 - val_loss: 0.1862 - val_accuracy: 0.9401 - val_auc_5: 0.9939
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_0.h5
# <ipython-input-23-ec73bca6c70a>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 81ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.99      0.83      0.91       203
#    pneumonia       0.95      0.96      0.96       139
#      regular       0.89      0.99      0.94       263
#
#     accuracy                           0.93       605
#    macro avg       0.94      0.93      0.93       605
# weighted avg       0.94      0.93      0.93       605
#
# Accuracy: 0.9322314049586777
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.90
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 1
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 47s 568ms/step - loss: 1.9476 - accuracy: 0.5339 - auc_6: 0.7196 - val_loss: 1.6828 - val_accuracy: 0.5041 - val_auc_6: 0.7483
# Epoch 2/30
# 61/61 [==============================] - 35s 572ms/step - loss: 1.3318 - accuracy: 0.6811 - auc_6: 0.8518 - val_loss: 1.3370 - val_accuracy: 0.5930 - val_auc_6: 0.8240
# Epoch 3/30
# 61/61 [==============================] - 36s 591ms/step - loss: 1.1212 - accuracy: 0.7571 - auc_6: 0.8923 - val_loss: 1.0194 - val_accuracy: 0.7045 - val_auc_6: 0.8915
# Epoch 19/30
# 61/61 [==============================] - 36s 595ms/step - loss: 0.4355 - accuracy: 0.8863 - auc_6: 0.9768 - val_loss: 0.3573 - val_accuracy: 0.8988 - val_auc_6: 0.9831
# Epoch 20/30
# 61/61 [==============================] - 36s 583ms/step - loss: 0.4254 - accuracy: 0.8987 - auc_6: 0.9789 - val_loss: 0.2686 - val_accuracy: 0.9236 - val_auc_6: 0.9892
# Epoch 21/30
# 61/61 [==============================] - 36s 579ms/step - loss: 0.3940 - accuracy: 0.9028 - auc_6: 0.9810 - val_loss: 0.2896 - val_accuracy: 0.9112 - val_auc_6: 0.9878
# Epoch 22/30
# 61/61 [==============================] - 36s 595ms/step - loss: 0.3640 - accuracy: 0.9028 - auc_6: 0.9832 - val_loss: 0.2974 - val_accuracy: 0.9277 - val_auc_6: 0.9881
# Epoch 23/30
# 61/61 [==============================] - 36s 576ms/step - loss: 0.3758 - accuracy: 0.9075 - auc_6: 0.9826 - val_loss: 0.2185 - val_accuracy: 0.9380 - val_auc_6: 0.9927
# Epoch 24/30
# 61/61 [==============================] - 36s 588ms/step - loss: 0.3224 - accuracy: 0.9178 - auc_6: 0.9858 - val_loss: 0.2950 - val_accuracy: 0.9174 - val_auc_6: 0.9883
# Epoch 25/30
# 61/61 [==============================] - 35s 574ms/step - loss: 0.3737 - accuracy: 0.9034 - auc_6: 0.9835 - val_loss: 0.2677 - val_accuracy: 0.9256 - val_auc_6: 0.9898
# Epoch 26/30
# 61/61 [==============================] - 36s 584ms/step - loss: 0.3497 - accuracy: 0.9142 - auc_6: 0.9848 - val_loss: 0.2466 - val_accuracy: 0.9298 - val_auc_6: 0.9910
# Epoch 27/30
# 61/61 [==============================] - 36s 592ms/step - loss: 0.2984 - accuracy: 0.9173 - auc_6: 0.9878 - val_loss: 0.2756 - val_accuracy: 0.9236 - val_auc_6: 0.9894
# Epoch 28/30
# 61/61 [==============================] - 35s 564ms/step - loss: 0.3250 - accuracy: 0.9137 - auc_6: 0.9863 - val_loss: 0.2470 - val_accuracy: 0.9277 - val_auc_6: 0.9910
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_1.h5
# <ipython-input-23-ec73bca6c70a>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 95ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       0.96      0.91      0.94       175
#    pneumonia       0.99      0.93      0.96       152
#      regular       0.92      0.97      0.94       278
#
#     accuracy                           0.95       605
#    macro avg       0.95      0.94      0.95       605
# weighted avg       0.95      0.95      0.95       605
#
# Accuracy: 0.9454545454545454
# Specificity for covid: 0.98
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.93
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 49s 568ms/step - loss: 1.8451 - accuracy: 0.5576 - auc_7: 0.7437 - val_loss: 1.7070 - val_accuracy: 0.5041 - val_auc_7: 0.7349
# Epoch 2/30
# 61/61 [==============================] - 37s 611ms/step - loss: 1.2511 - accuracy: 0.7080 - auc_7: 0.8655 - val_loss: 1.4319 - val_accuracy: 0.5682 - val_auc_7: 0.8067
# Epoch 3/30
# 61/61 [==============================] - 35s 577ms/step - loss: 1.0820 - accuracy: 0.7380 - auc_7: 0.8950 - val_loss: 0.9759 - val_accuracy: 0.7293 - val_auc_7: 0.8973
# Epoch 4/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.9820 - accuracy: 0.7700 - auc_7: 0.9114 - val_loss: 0.7711 - val_accuracy: 0.7913 - val_auc_7: 0.9346
# Epoch 5/30
# 61/61 [==============================] - 36s 590ms/step - loss: 0.8683 - accuracy: 0.7990 - auc_7: 0.9288 - val_loss: 0.6603 - val_accuracy: 0.8306 - val_auc_7: 0.9509
# Epoch 6/30
# 61/61 [==============================] - 36s 581ms/step - loss: 0.7197 - accuracy: 0.8176 - auc_7: 0.9447 - val_loss: 0.7155 - val_accuracy: 0.8202 - val_auc_7: 0.9441
# Epoch 7/30
# 61/61 [==============================] - 36s 590ms/step - loss: 0.6759 - accuracy: 0.8351 - auc_7: 0.9536 - val_loss: 0.6140 - val_accuracy: 0.8492 - val_auc_7: 0.9578
# Epoch 8/30
# 61/61 [==============================] - 36s 582ms/step - loss: 0.6553 - accuracy: 0.8398 - auc_7: 0.9553 - val_loss: 0.5432 - val_accuracy: 0.8595 - val_auc_7: 0.9663
# Epoch 9/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.5627 - accuracy: 0.8594 - auc_7: 0.9647 - val_loss: 0.4767 - val_accuracy: 0.8843 - val_auc_7: 0.9726
# Epoch 10/30
# 61/61 [==============================] - 36s 587ms/step - loss: 0.6224 - accuracy: 0.8594 - auc_7: 0.9598 - val_loss: 0.4715 - val_accuracy: 0.8802 - val_auc_7: 0.9733
# Epoch 11/30
# Epoch 26/30
# 61/61 [==============================] - 36s 595ms/step - loss: 0.3169 - accuracy: 0.9245 - auc_7: 0.9873 - val_loss: 0.3846 - val_accuracy: 0.9194 - val_auc_7: 0.9844
# Epoch 27/30
# 61/61 [==============================] - 36s 580ms/step - loss: 0.2727 - accuracy: 0.9297 - auc_7: 0.9901 - val_loss: 0.2864 - val_accuracy: 0.9380 - val_auc_7: 0.9905
# Epoch 28/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.3314 - accuracy: 0.9230 - auc_7: 0.9874 - val_loss: 0.3325 - val_accuracy: 0.9256 - val_auc_7: 0.9882
# Epoch 29/30
# 61/61 [==============================] - 35s 573ms/step - loss: 0.2728 - accuracy: 0.9287 - auc_7: 0.9894 - val_loss: 0.2623 - val_accuracy: 0.9318 - val_auc_7: 0.9919
# Epoch 30/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.3232 - accuracy: 0.9220 - auc_7: 0.9877 - val_loss: 0.2800 - val_accuracy: 0.9318 - val_auc_7: 0.9908
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_2.h5
# <ipython-input-23-ec73bca6c70a>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 81ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.98      0.88      0.93       180
#    pneumonia       0.97      0.93      0.95       136
#      regular       0.91      0.99      0.95       289
#
#     accuracy                           0.94       605
#    macro avg       0.95      0.93      0.94       605
# weighted avg       0.95      0.94      0.94       605
#
# Accuracy: 0.943801652892562
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.91
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 49s 583ms/step - loss: 1.9172 - accuracy: 0.5597 - auc_8: 0.7339 - val_loss: 1.2923 - val_accuracy: 0.6405 - val_auc_8: 0.8224
# Epoch 17/30
# 61/61 [==============================] - 37s 603ms/step - loss: 0.4508 - accuracy: 0.8889 - auc_8: 0.9756 - val_loss: 0.3060 - val_accuracy: 0.9132 - val_auc_8: 0.9857
# Epoch 18/30
# 61/61 [==============================] - 35s 579ms/step - loss: 0.4461 - accuracy: 0.8884 - auc_8: 0.9777 - val_loss: 0.3100 - val_accuracy: 0.9091 - val_auc_8: 0.9860
# Epoch 19/30
# 61/61 [==============================] - 36s 584ms/step - loss: 0.4178 - accuracy: 0.8997 - auc_8: 0.9790 - val_loss: 0.2519 - val_accuracy: 0.9318 - val_auc_8: 0.9908
# Epoch 20/30
# 61/61 [==============================] - 37s 608ms/step - loss: 0.4046 - accuracy: 0.8997 - auc_8: 0.9804 - val_loss: 0.2147 - val_accuracy: 0.9421 - val_auc_8: 0.9931
# Epoch 21/30
# 61/61 [==============================] - 37s 597ms/step - loss: 0.3839 - accuracy: 0.8997 - auc_8: 0.9810 - val_loss: 0.2116 - val_accuracy: 0.9483 - val_auc_8: 0.9936
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_3.h5
# <ipython-input-23-ec73bca6c70a>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 85ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.95      0.85      0.90       187
#    pneumonia       0.90      0.92      0.91       145
#      regular       0.88      0.93      0.91       273
#
#     accuracy                           0.91       605
#    macro avg       0.91      0.90      0.91       605
# weighted avg       0.91      0.91      0.91       605
#
# Accuracy: 0.9057851239669421
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.97
# Specificity for regular: 0.90
# Macro-average Specificity: 0.95
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_0.0001_fold_4.h5
# <ipython-input-23-ec73bca6c70a>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 88ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.99      0.86      0.92       173
#    pneumonia       0.94      0.97      0.96       154
#      regular       0.91      0.97      0.94       277
#
#     accuracy                           0.94       604
#    macro avg       0.95      0.93      0.94       604
# weighted avg       0.94      0.94      0.94       604
#
# Accuracy: 0.9387417218543046
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.92
# Macro-average Specificity: 0.97
# Final Metrics Across All Folds:
# Average Accuracy: 0.93 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.98 ± 0.02
# Class covid - Average Recall: 0.87 ± 0.03
# Class covid - Average F1 Score: 0.92 ± 0.01
# Class pneumonia - Average Precision: 0.95 ± 0.03
# Class pneumonia - Average Recall: 0.94 ± 0.02
# Class pneumonia - Average F1 Score: 0.95 ± 0.02
# Class regular - Average Precision: 0.90 ± 0.01
# Class regular - Average Recall: 0.97 ± 0.02
# Class regular - Average F1 Score: 0.94 ± 0.01

# %% [markdown]
# ## Focal loss + RMSProp + 0.001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = RMSprop(learning_rate=0.001)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 53s 660ms/step - loss: 1.7495 - accuracy: 0.7039 - auc_5: 0.8561 - val_loss: 0.7791 - val_accuracy: 0.8285 - val_auc_5: 0.9352
# Epoch 2/30
# 61/61 [==============================] - 35s 564ms/step - loss: 0.8763 - accuracy: 0.8036 - auc_5: 0.9358 - val_loss: 1.1814 - val_accuracy: 0.7314 - val_auc_5: 0.9159
# Epoch 3/30
# 61/61 [==============================] - 36s 587ms/step - loss: 0.6973 - accuracy: 0.8450 - auc_5: 0.9578 - val_loss: 0.6144 - val_accuracy: 0.8657 - val_auc_5: 0.9682
# Epoch 4/30
# 61/61 [==============================] - 35s 566ms/step - loss: 0.5189 - accuracy: 0.8811 - auc_5: 0.9732 - val_loss: 0.3602 - val_accuracy: 0.9194 - val_auc_5: 0.9855
# Epoch 5/30
# 61/61 [==============================] - 34s 557ms/step - loss: 0.4620 - accuracy: 0.8966 - auc_5: 0.9786 - val_loss: 0.3951 - val_accuracy: 0.9215 - val_auc_5: 0.9853
# Epoch 6/30
# 61/61 [==============================] - 34s 563ms/step - loss: 0.4079 - accuracy: 0.9090 - auc_5: 0.9825 - val_loss: 0.4057 - val_accuracy: 0.9153 - val_auc_5: 0.9874
# Epoch 7/30
# 61/61 [==============================] - 38s 623ms/step - loss: 0.3475 - accuracy: 0.9168 - auc_5: 0.9865 - val_loss: 0.3588 - val_accuracy: 0.9236 - val_auc_5: 0.9881
# Epoch 8/30
# 61/61 [==============================] - 35s 565ms/step - loss: 0.3757 - accuracy: 0.9111 - auc_5: 0.9864 - val_loss: 0.5449 - val_accuracy: 0.8967 - val_auc_5: 0.9778
# Epoch 9/30
# 61/61 [==============================] - 37s 603ms/step - loss: 0.2997 - accuracy: 0.9251 - auc_5: 0.9890 - val_loss: 0.5348 - val_accuracy: 0.9029 - val_auc_5: 0.9837
# Epoch 10/30
# 61/61 [==============================] - 34s 564ms/step - loss: 0.3133 - accuracy: 0.9313 - auc_5: 0.9901 - val_loss: 0.4333 - val_accuracy: 0.8988 - val_auc_5: 0.9867
# Epoch 11/30
# 61/61 [==============================] - 36s 588ms/step - loss: 0.3619 - accuracy: 0.9214 - auc_5: 0.9877 - val_loss: 0.2852 - val_accuracy: 0.9360 - val_auc_5: 0.9913
# Epoch 12/30
# 61/61 [==============================] - 34s 564ms/step - loss: 0.2993 - accuracy: 0.9328 - auc_5: 0.9896 - val_loss: 0.2334 - val_accuracy: 0.9483 - val_auc_5: 0.9925
# Epoch 13/30
# 61/61 [==============================] - 34s 562ms/step - loss: 0.2901 - accuracy: 0.9354 - auc_5: 0.9908 - val_loss: 0.1551 - val_accuracy: 0.9628 - val_auc_5: 0.9977
# Epoch 14/30
# 61/61 [==============================] - 38s 627ms/step - loss: 0.2641 - accuracy: 0.9380 - auc_5: 0.9924 - val_loss: 0.4097 - val_accuracy: 0.8967 - val_auc_5: 0.9872
# Epoch 15/30
# 61/61 [==============================] - 35s 579ms/step - loss: 0.2558 - accuracy: 0.9457 - auc_5: 0.9932 - val_loss: 0.2523 - val_accuracy: 0.9587 - val_auc_5: 0.9950
# Epoch 16/30
# 61/61 [==============================] - 35s 568ms/step - loss: 0.2215 - accuracy: 0.9452 - auc_5: 0.9942 - val_loss: 0.2840 - val_accuracy: 0.9483 - val_auc_5: 0.9948
# Epoch 17/30
# 61/61 [==============================] - 35s 572ms/step - loss: 0.2408 - accuracy: 0.9499 - auc_5: 0.9933 - val_loss: 0.2131 - val_accuracy: 0.9566 - val_auc_5: 0.9965
# Epoch 18/30
# 61/61 [==============================] - 35s 566ms/step - loss: 0.1936 - accuracy: 0.9566 - auc_5: 0.9953 - val_loss: 0.1649 - val_accuracy: 0.9752 - val_auc_5: 0.9976
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_0.h5
# <ipython-input-24-500a5c08ff90>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 100ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.99      0.94      0.97       203
#    pneumonia       0.98      0.91      0.95       139
#      regular       0.92      0.99      0.95       263
#
#     accuracy                           0.96       605
#    macro avg       0.96      0.95      0.96       605
# weighted avg       0.96      0.96      0.96       605
# 61/61 [==============================] - 36s 594ms/step - loss: 0.3102 - accuracy: 0.9287 - auc_6: 0.9889 - val_loss: 0.1329 - val_accuracy: 0.9731 - val_auc_6: 0.9971
# Epoch 14/30
# 61/61 [==============================] - 34s 562ms/step - loss: 0.2196 - accuracy: 0.9437 - auc_6: 0.9932 - val_loss: 0.1908 - val_accuracy: 0.9607 - val_auc_6: 0.9959
# Epoch 15/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.3032 - accuracy: 0.9370 - auc_6: 0.9908 - val_loss: 0.2104 - val_accuracy: 0.9483 - val_auc_6: 0.9948
# Epoch 16/30
# 61/61 [==============================] - 36s 596ms/step - loss: 0.2287 - accuracy: 0.9478 - auc_6: 0.9930 - val_loss: 0.2756 - val_accuracy: 0.9401 - val_auc_6: 0.9940
# Epoch 17/30
# 61/61 [==============================] - 35s 573ms/step - loss: 0.2346 - accuracy: 0.9426 - auc_6: 0.9932 - val_loss: 0.4641 - val_accuracy: 0.9112 - val_auc_6: 0.9843
# Epoch 18/30
# 61/61 [==============================] - 36s 590ms/step - loss: 0.2528 - accuracy: 0.9463 - auc_6: 0.9925 - val_loss: 0.1875 - val_accuracy: 0.9442 - val_auc_6: 0.9948
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_1.h5
# <ipython-input-24-500a5c08ff90>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 78ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       1.00      0.98      0.99       175
#    pneumonia       1.00      0.93      0.97       152
#      regular       0.95      1.00      0.98       278
#
#     accuracy                           0.98       605
#    macro avg       0.98      0.97      0.98       605
# weighted avg       0.98      0.98      0.98       605
#
# Accuracy: 0.9768595041322314
# Specificity for covid: 1.00
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.96
# Macro-average Specificity: 0.99
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.2754 - accuracy: 0.9380 - auc_7: 0.9922 - val_loss: 0.6652 - val_accuracy: 0.8988 - val_auc_7: 0.9776
# Epoch 17/30
# 61/61 [==============================] - 35s 571ms/step - loss: 0.2325 - accuracy: 0.9468 - auc_7: 0.9936 - val_loss: 0.6526 - val_accuracy: 0.9050 - val_auc_7: 0.9785
# Epoch 18/30
# 61/61 [==============================] - 38s 620ms/step - loss: 0.2188 - accuracy: 0.9442 - auc_7: 0.9945 - val_loss: 0.5059 - val_accuracy: 0.9236 - val_auc_7: 0.9860
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_2.h5
# <ipython-input-24-500a5c08ff90>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 80ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.99      0.94      0.97       180
#    pneumonia       0.96      0.93      0.95       136
#      regular       0.94      0.98      0.96       289
#
#     accuracy                           0.96       605
#    macro avg       0.96      0.95      0.96       605
# weighted avg       0.96      0.96      0.96       605
#
# Accuracy: 0.9586776859504132
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.94
# Macro-average Specificity: 0.98
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 49s 603ms/step - loss: 1.7776 - accuracy: 0.6806 - auc_8: 0.8485 - val_loss: 1.4436 - val_accuracy: 0.6901 - val_auc_8: 0.8463
# Epoch 2/30
# 61/61 [==============================] - 38s 629ms/step - loss: 0.8447 - accuracy: 0.8248 - auc_8: 0.9453 - val_loss: 1.3052 - val_accuracy: 0.7045 - val_auc_8: 0.8855
# Epoch 3/30
# 61/61 [==============================] - 39s 640ms/step - loss: 0.7090 - accuracy: 0.8413 - auc_8: 0.9560 - val_loss: 0.6064 - val_accuracy: 0.8471 - val_auc_8: 0.9557
# Epoch 19/30
# 61/61 [==============================] - 37s 605ms/step - loss: 0.2421 - accuracy: 0.9540 - auc_8: 0.9938 - val_loss: 0.0732 - val_accuracy: 0.9711 - val_auc_8: 0.9988
# Epoch 20/30
# 61/61 [==============================] - 37s 601ms/step - loss: 0.2275 - accuracy: 0.9473 - auc_8: 0.9944 - val_loss: 0.1349 - val_accuracy: 0.9587 - val_auc_8: 0.9975
# Epoch 21/30
# 61/61 [==============================] - 34s 568ms/step - loss: 0.2373 - accuracy: 0.9488 - auc_8: 0.9942 - val_loss: 0.2792 - val_accuracy: 0.9401 - val_auc_8: 0.9937
# Epoch 22/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.2056 - accuracy: 0.9483 - auc_8: 0.9949 - val_loss: 0.2333 - val_accuracy: 0.9360 - val_auc_8: 0.9929
# Epoch 23/30
# 61/61 [==============================] - 35s 565ms/step - loss: 0.1865 - accuracy: 0.9566 - auc_8: 0.9955 - val_loss: 0.1625 - val_accuracy: 0.9566 - val_auc_8: 0.9968
# Epoch 24/30
# 61/61 [==============================] - 36s 591ms/step - loss: 0.1867 - accuracy: 0.9587 - auc_8: 0.9962 - val_loss: 0.1649 - val_accuracy: 0.9690 - val_auc_8: 0.9967
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_3.h5
# <ipython-input-24-500a5c08ff90>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 86ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.99      0.91      0.95       187
#    pneumonia       0.97      0.97      0.97       145
#      regular       0.94      0.99      0.96       273
#
#     accuracy                           0.96       605
#    macro avg       0.97      0.96      0.96       605
# weighted avg       0.96      0.96      0.96       605
#
# Accuracy: 0.9619834710743802
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.95
# Macro-average Specificity: 0.98
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# 61/61 [==============================] - 36s 594ms/step - loss: 0.2371 - accuracy: 0.9375 - auc_9: 0.9933 - val_loss: 0.1468 - val_accuracy: 0.9545 - val_auc_9: 0.9973
# Epoch 16/30
# 61/61 [==============================] - 39s 631ms/step - loss: 0.2426 - accuracy: 0.9483 - auc_9: 0.9934 - val_loss: 0.1546 - val_accuracy: 0.9649 - val_auc_9: 0.9966
# Epoch 17/30
# 61/61 [==============================] - 35s 577ms/step - loss: 0.2777 - accuracy: 0.9437 - auc_9: 0.9926 - val_loss: 0.3289 - val_accuracy: 0.9421 - val_auc_9: 0.9928
# Epoch 18/30
# 61/61 [==============================] - 37s 614ms/step - loss: 0.1912 - accuracy: 0.9592 - auc_9: 0.9955 - val_loss: 0.6415 - val_accuracy: 0.8678 - val_auc_9: 0.9699
# Epoch 19/30
# 61/61 [==============================] - 36s 594ms/step - loss: 0.1989 - accuracy: 0.9592 - auc_9: 0.9956 - val_loss: 0.1690 - val_accuracy: 0.9607 - val_auc_9: 0.9967
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_rmsprop_fold_4.h5
# <ipython-input-24-500a5c08ff90>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 80ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.99      0.96      0.97       173
#    pneumonia       1.00      0.94      0.97       154
#      regular       0.95      1.00      0.97       277
#
#     accuracy                           0.97       604
#    macro avg       0.98      0.96      0.97       604
# weighted avg       0.97      0.97      0.97       604
#
# Accuracy: 0.9718543046357616
# Specificity for covid: 1.00
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.95
# Macro-average Specificity: 0.98
# Final Metrics Across All Folds:
# Average Accuracy: 0.96 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.99 ± 0.00
# Class covid - Average Recall: 0.95 ± 0.02
# Class covid - Average F1 Score: 0.97 ± 0.01
# Class pneumonia - Average Precision: 0.98 ± 0.01
# Class pneumonia - Average Recall: 0.94 ± 0.02
# Class pneumonia - Average F1 Score: 0.96 ± 0.01
# Class regular - Average Precision: 0.94 ± 0.01
# Class regular - Average Recall: 0.99 ± 0.01
# Class regular - Average F1 Score: 0.96 ± 0.01
