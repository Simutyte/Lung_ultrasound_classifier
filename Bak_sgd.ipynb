# %%
import torch
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random
import os
import torchvision.transforms.functional as TF
import shutil
import math
from torch.utils.data import DataLoader
import torch.utils.data as data
from datetime import datetime
import torch
import torch.nn as nn
import torch.optim as optim

# %% [markdown]
# #Images

# %%
# !git clone https://github.com/BorgwardtLab/covid19_ultrasound.git
# !cd covid19_ultrasound/pocovidnet/
# !pip install -e .
# Out:
# Cloning into 'covid19_ultrasound'...
# remote: Enumerating objects: 4531, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 4531 (delta 37), reused 29 (delta 10), pack-reused 4453
# Receiving objects: 100% (4531/4531), 165.49 MiB | 13.71 MiB/s, done.
# Resolving deltas: 100% (369/369), done.
# Updating files: 100% (3873/3873), done.
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
#copy data folder for further work
# !cp -r /content/covid19_ultrasound/data /content/

# %%
#check how many files are in each folder (images or video files)
# !ls -1 /content/data/pocus_images/convex | wc -l
# !ls -1 /content/data/pocus_images/linear | wc -l
# !ls -1 /content/data/pocus_videos/convex | wc -l
# !ls -1 /content/data/pocus_videos/linear | wc -l
# Out:
# 29
# 3
# 124
# 11

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Get the files used by the authors of the dataset, with some modifications (mostly path fixes)
file_names = ['crop.json', 'crop_processed_data.py', 'get_and_process_web_data.sh', 'build_image_dataset.py', 'cross_val_splitter.py']

# define source and destination path
source_folder = '/content/drive/MyDrive/Bakis'
destination_folder = '/content/'

# Copy the files
for file_name in file_names:
    source_path = os.path.join(source_folder, file_name)
    destination_path = os.path.join(destination_folder, file_name)
    if os.path.isfile(source_path):
        shutil.copy(source_path, destination_path)

# %%
#Files from web
# !cd covid19_ultrasound/data
# !sh /content/get_and_process_web_data.sh
# Out:
# youtube-dl could not be found, installing now..
# --2024-05-21 20:41:46--  https://yt-dl.org/downloads/latest/youtube-dl
# Resolving yt-dl.org (yt-dl.org)... 95.143.172.170, 2001:1a50:11:0:5f:8f:acaa:177
# Connecting to yt-dl.org (yt-dl.org)|95.143.172.170|:443... connected.
# HTTP request sent, awaiting response... 451 Unavailable For Legal Reasons
# 2024-05-21 20:41:48 ERROR 451: Unavailable For Legal Reasons.
#
# Grabbing data now..
# --2024-05-21 20:41:48--  https://clarius.com/wp-content/uploads/2020/03/1-blines.gif
# Resolving clarius.com (clarius.com)... 104.26.8.204, 104.26.9.204, 172.67.72.226, ...
# Connecting to clarius.com (clarius.com)|104.26.8.204|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10635005 (10M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Cov-clarius.gif’
#
# tmp/pocus_videos/co 100%[===================>]  10.14M  7.85MB/s    in 1.3s
#
# 2024-05-21 20:41:50 (7.85 MB/s) - ‘tmp/pocus_videos/convex/Cov-clarius.gif’ saved [10635005/10635005]
#
# --2024-05-21 20:41:50--  https://clarius.com/wp-content/uploads/2020/03/3-large-consolidation.gif
# Resolving clarius.com (clarius.com)... 104.26.8.204, 104.26.9.204, 172.67.72.226, ...
# Connecting to clarius.com (clarius.com)|104.26.8.204|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 
41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1311393 (1.2M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Reg-bcpocus.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.25M   391KB/s    in 3.3s
#
# 2024-05-21 20:42:00 (391 KB/s) - ‘tmp/pocus_videos/convex/Reg-bcpocus.gif’ saved [1311393/1311393]
#
# /content/get_and_process_web_data.sh: 25: ab: not found
# /content/get_and_process_web_data.sh: 26: ab: not found
# /content/get_and_process_web_data.sh: 27: ab: not found
# --2024-05-21 20:42:00--  https://images.squarespace-cdn.com/content/v1/5c69e7d7b91449698da66e65/1590627160853-3ULNVXBBJD5LVR930CU1/ke17ZwdGBToddI8pDm48kI8YiP-OhoX1jaED3zwYDitZw-zPPgdn4jUwVcJE1ZvWQUxwkmyExglNqGp0IvTJZUJFbgE-7XRK3dMEBRBhUpw0zQBx-_xluAT7IF9HiONY7KDc7zDddqX0ywCRyjQsO3pixv1ek7N_oX80uiIUqvU/LungPoint.ezgif.gif?format=750w
# Resolving images.squarespace-cdn.com (images.squarespace-cdn.com)... 151.101.0.238, 151.101.64.238, 151.101.128.238, ...
# Connecting to images.squarespace-cdn.com (images.squarespace-cdn.com)|151.101.0.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15815746 (15M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-nephropocus.gif’
#
# tmp/pocus_videos/li 100%[===================>]  15.08M  --.-KB/s    in 0.04s
#
# 2024-05-21 20:42:00 (343 MB/s) - ‘tmp/pocus_videos/linear/Reg-nephropocus.gif’ saved [15815746/15815746]
#
# --2024-05-21 20:42:00--  https://hls.cf.brightcove.com/1611106596001/4304256093001/1611106596001_4304256093001_s-1.ts?pubId=1611106596001&videoId=4304084884001
# --2024-05-21 20:42:00--  https://i0.wp.com/criticalcarenorthampton.com/wp-content/uploads/2016/11/pneumothorax-case-3-litfl-ultrasound-clinical-cases.gif?resize=480,360
# Resolving hls.cf.brightcove.com (hls.cf.brightcove.com)... --2024-05-21 20:42:00--  https://i0.wp.com/criticalcarenorthampton.com/wp-content/uploads/2016/11/normal-lung.gif?resize=480,360
# Resolving i0.wp.com (i0.wp.com)... Resolving i0.wp.com (i0.wp.com)... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... connected.
# connected.
# HTTP request sent, awaiting response... HTTP request sent, awaiting response... 200 OK
# Length: 2090784 (2.0M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-NormalLung.gif’
#
#           tmp/pocus   0%[                    ]       0  --.-KB/s               200 OK
# Length: 4468440 (4.3M) [image/gif]
# Saving to: ‘tmp/pocus_videos/linear/Reg-minimalmovement.gif’
#
# tmp/pocus_videos/li 100%[===================>]   1.99M  --.-KB/s    in 0.01s
#
# 2024-05-21 20:42:00 (159 MB/s) - ‘tmp/pocus_videos/linear/Reg-NormalLung.gif’ saved [2090784/2090784]
#
# tmp/pocus_videos/li 100%[===================>]   4.26M  --.-KB/s    in 0.02s
#
# 2024-05-21 20:42:00 (199 MB/s) - ‘tmp/pocus_videos/linear/Reg-minimalmovement.gif’ saved [4468440/4468440]
#
# failed: Name or service not known.
# wget: unable to resolve host address ‘hls.cf.brightcove.com’
# --2024-05-21 20:42:00--  https://f1.media.brightcove.com/3/1611106596001/4304256034001/1611106596001_4304256034001_s-1.ts?pubId=1611106596001&videoId=4304052567001
# Resolving f1.media.brightcove.com (f1.media.brightcove.com)... 151.101.2.27, 151.101.66.27, 151.101.130.27, ...
# Connecting to f1.media.brightcove.com (f1.media.brightcove.com)|151.101.2.27|:443... connected.
# HTTP request sent, awaiting response... 503 No healthy IP available for the backend
# 2024-05-21 20:42:00 ERROR 503: No healthy IP available for the backend.
#
# --2024-05-21 20:42:00--  https://img.grepmed.com/uploads/7415/blines-pocus-pulmonary-lung-covid19-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 676851 (661K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 660.99K   757KB/s    in 0.9s
#
# 2024-05-21 20:42:02 (757 KB/s) - ‘tmp/pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4’ saved [676851/676851]
#
# --2024-05-21 20:42:02--  https://img.grepmed.com/uploads/7410/sparing-lung-ultrasound-subpleural-blines-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 495270 (484K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov-grepmed2.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 483.66K   601KB/s    in 0.8s
#
# 2024-05-21 20:42:03 (601 KB/s) - ‘tmp/pocus_videos/convex/Cov-grepmed2.mp4’ saved [495270/495270]
#
# --2024-05-21 20:42:03--  https://img.grepmed.com/uploads/5721/airbronchogram-pulmonary-pocus-pneumonia-lung-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2328631 (2.2M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/pneu-gred-6.gif’
#
# tmp/pocus_videos/co 100%[===================>]   2.22M  2.03MB/s    in 1.1s
#
# 2024-05-21 20:42:06 (2.03 MB/s) - ‘tmp/pocus_videos/convex/pneu-gred-6.gif’ saved [2328631/2328631]
#
# --2024-05-21 20:42:06--  https://img.grepmed.com/uploads/6903/ultrasound-pocus-bronchograms-lung-pulmonary-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 752146 (735K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia1.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 734.52K   864KB/s    in 0.9s
#
# 2024-05-21 20:42:07 (864 KB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia1.mp4’ saved [752146/752146]
#
# --2024-05-21 20:42:07--  https://img.grepmed.com/uploads/6876/bronchograms-air-pulmonary-pocus-ultrasound-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2206754 (2.1M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   2.10M  1.91MB/s    in 1.1s
#
# 2024-05-21 20:42:09 (1.91 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4’ saved [2206754/2206754]
#
# --2024-05-21 20:42:09--  https://img.grepmed.com/uploads/6431/ultrasound-lung-pneumonia-shredsign-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1626541 (1.6M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia4.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.55M  1.51MB/s    in 1.0s
#
# 2024-05-21 20:42:11 (1.51 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia4.mp4’ saved [1626541/1626541]
#
# --2024-05-21 20:42:11--  https://img.grepmed.com/uploads/1304/airbronchograms-pneumonia-sonostuff-effusion-clinical-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1061627 (1.0M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/pneu-gred-7.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.01M   942KB/s    in 1.1s
#
# 2024-05-21 20:42:13 (942 KB/s) - ‘tmp/pocus_videos/convex/pneu-gred-7.gif’ saved [1061627/1061627]
#
# --2024-05-21 20:42:13--  https://img.grepmed.com/uploads/6439/pulmonary-ultrasound-pocus-clinical-lung-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1346485 (1.3M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia3.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   1.28M  1.13MB/s    in 1.1s
#
# 2024-05-21 20:42:15 (1.13 MB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-pneumonia3.mp4’ saved [1346485/1346485]
#
# --2024-05-21 20:42:15--  https://img.grepmed.com/uploads/7408/pocus-alines-lung-normal-ultrasound-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186605 (182K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Reg-Grep-Alines.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 182.23K   402KB/s    in 0.5s
#
# 2024-05-21 20:42:16 (402 KB/s) - ‘tmp/pocus_videos/convex/Reg-Grep-Alines.mp4’ saved [186605/186605]
#
# --2024-05-21 20:42:16--  https://img.grepmed.com/uploads/5325/clinical-pulmonary-lung-normal-artifact-original.gif
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1882045 (1.8M) [image/gif]
# Saving to: ‘tmp/pocus_videos/convex/Reg-Grep-Normal.gif’
#
# tmp/pocus_videos/co 100%[===================>]   1.79M  1.81MB/s    in 1.0s
#
# 2024-05-21 20:42:18 (1.81 MB/s) - ‘tmp/pocus_videos/convex/Reg-Grep-Normal.gif’ saved [1882045/1882045]
#
# --2024-05-21 20:42:18--  https://img.grepmed.com/uploads/7583/lung-pocus-ultrasound-shredsign-consolidation-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 805344 (786K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 786.47K   847KB/s    in 0.9s
#
# 2024-05-21 20:42:20 (847 KB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4’ saved [805344/805344]
#
# --2024-05-21 20:42:20--  https://img.grepmed.com/uploads/7582/pocus-pneumonia-bacterial-hepatization-clinical-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 371402 (363K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 362.70K   531KB/s    in 0.7s
#
# 2024-05-21 20:42:21 (531 KB/s) - ‘tmp/pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4’ saved [371402/371402]
#
# --2024-05-21 20:42:21--  https://img.grepmed.com/uploads/6952/pocus-clinical-lung-pulmonary-pneumonia-original.mp4
# Resolving img.grepmed.com (img.grepmed.com)... 18.154.206.120, 18.154.206.65, 18.154.206.35, ...
# Connecting to img.grepmed.com (img.grepmed.com)|18.154.206.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 372273 (364K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/
42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2147566 (2.0M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Vir_blines_advancesVid9.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   2.05M  2.73MB/s    in 0.8s
#
# 2024-05-21 20:42:42 (2.73 MB/s) - ‘tmp/pocus_videos/convex/Vir_blines_advancesVid9.mp4’ saved [2147566/2147566]
#
# --2024-05-21 20:42:42--  https://ars.els-cdn.com/content/image/1-s2.0-S0733862715000772-mmc10.mp4
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4055640 (3.9M) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Pneu_consol_advancesVid10.mp4’
#
# tmp/pocus_videos/co 100%[===================>]   3.87M  3.88MB/s    in 1.0s
#
# 2024-05-21 20:42:44 (3.88 MB/s) - ‘tmp/pocus_videos/convex/Pneu_consol_advancesVid10.mp4’ saved [4055640/4055640]
#
# --2024-05-21 20:42:44--  https://static-content.springer.com/esm/art%3A10.1186%2Fcc5668/MediaObjects/13054_2007_5188_MOESM1_ESM.avi
# Resolving static-content.springer.com (static-content.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to static-content.springer.com (static-content.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19393024 (18M) [application/x-troff-msvideo]
# Saving to: ‘tmp/pocus_videos/convex/Reg_clinicalreview_mov1.mp4’
#
# tmp/pocus_videos/co 100%[===================>]  18.49M  --.-KB/s    in 0.05s
#
# 2024-05-21 20:42:50 (397 MB/s) - ‘tmp/pocus_videos/convex/Reg_clinicalreview_mov1.mp4’ saved [19393024/19393024]
#
# --2024-05-21 20:42:50--  https://static-content.springer.com/esm/art%3A10.1186%2Fcc5668/MediaObjects/13054_2007_5188_MOESM4_ESM.avi
# Resolving static-content.springer.com (static-content.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to static-content.springer.com (static-content.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13299200 (13M) [application/x-troff-msvideo]
# Saving to: ‘tmp/pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4’
#
# tmp/pocus_videos/co 100%[===================>]  12.68M  --.-KB/s    in 0.04s
#
# 2024-05-21 20:42:50 (361 MB/s) - ‘tmp/pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4’ saved [13299200/13299200]
#
# --2024-05-21 20:42:50--  https://ars.els-cdn.com/content/image/1-s2.0-S2352047720300204-gr1_lrg.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48606 (47K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png’
#
# tmp/pocus_images/li 100%[===================>]  47.47K  --.-KB/s    in 0.002s
#
# 2024-05-21 20:43:00 (23.5 MB/s) - ‘tmp/pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png’ saved [48606/48606]
#
# --2024-05-21 20:43:00--  https://ars.els-cdn.com/content/image/1-s2.0-S0002937820304683-gr1.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40305 (39K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pregnantPublication1.png’
#
# tmp/pocus_images/co 100%[===================>]  39.36K  --.-KB/s    in 0.001s
#
# 2024-05-21 20:43:01 (34.4 MB/s) - ‘tmp/pocus_images/convex/Cov_pregnantPublication1.png’ saved [40305/40305]
#
# --2024-05-21 20:43:01--  https://ars.els-cdn.com/content/image/1-s2.0-S0002937820304683-gr1.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40305 (39K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pregnantPublication2.png’
#
# tmp/pocus_images/co 100%[===================>]  39.36K  --.-KB/s    in 0.001s
#
# 2024-05-21 20:43:01 (28.8 MB/s) - ‘tmp/pocus_images/convex/Cov_pregnantPublication2.png’ saved [40305/40305]
#
# --2024-05-21 20:43:01--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig1_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig1.png’
#
# tmp/pocus_images/co     [ <=>                ]  29.99K  --.-KB/s    in 0.07s
#
# 2024-05-21 20:43:02 (437 KB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig1.png’ saved [30712]
#
# --2024-05-21 20:43:02--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig2_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig2.png’
#
# tmp/pocus_images/co     [ <=>                ]  31.42K  --.-KB/s    in 0.06s
#
# 2024-05-21 20:43:02 (520 KB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig2.png’ saved [32172]
#
# --2024-05-21 20:43:02--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig3_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig3.png’
#
# tmp/pocus_images/co     [  <=>               ]  74.43K   187KB/s    in 0.4s
#
# 2024-05-21 20:43:03 (187 KB/s) - ‘tmp/pocus_images/convex/Cov_blines_thoraric_paperfig3.png’ saved [76216]
#
# --2024-05-21 20:43:03--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig7_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png’
#
# tmp/pocus_images/co     [ <=>                ]  34.69K  --.-KB/s    in 0.07s
#
# 2024-05-21 20:43:03 (511 KB/s) - ‘tmp/pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png’ saved [35518]
#
# --2024-05-21 20:43:03--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig4_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png’
#
# tmp/pocus_images/co     [ <=>                ]  32.72K  --.-KB/s    in 0.02s
#
# 2024-05-21 20:43:04 (1.77 MB/s) - ‘tmp/pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png’ saved [33509]
#
# --2024-05-21 20:43:04--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig8_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png’
#
# tmp/pocus_images/co     [ <=>                ]  30.15K  --.-KB/s    in 0.07s
#
# 2024-05-21 20:43:04 (442 KB/s) - ‘tmp/pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png’ saved [30874]
#
# --2024-05-21 20:43:04--  https://media.springernature.com/lw685/springer-static/image/art%3A10.1007%2Fs40477-020-00458-7/MediaObjects/40477_2020_458_Fig5_HTML.jpg
# Resolving media.springernature.com (media.springernature.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to media.springernature.com (media.springernature.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png’
#
# tmp/pocus_images/co     [ <=>                ]  26.89K  --.-KB/s    in 0.1s
#
# 2024-05-21 20:43:05 (246 KB/s) - ‘tmp/pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png’ saved [27536]
#
# --2024-05-21 20:43:05--  https://journals.viamedica.pl/advances_in_respiratory_medicine/article/viewFile/41845/36561/110994
# Resolving journals.viamedica.pl (journals.viamedica.pl)... 195.116.62.118
# Connecting to journals.viamedica.pl (journals.viamedica.pl)|195.116.62.118|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://journals.viamedica.pl/ [following]
# --2024-05-21 20:43:08--  https://journals.viamedica.pl/
# Reusing existing connection to journals.viamedica.pl:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘tmp/pocus_images/convex/Reg_publication1.png’
#
# tmp/pocus_images/co     [    <=>             ]  92.01K   141KB/s    in 0.7s
#
# 2024-05-21 20:43:09 (141 KB/s) - ‘tmp/pocus_images/convex/Reg_publication1.png’ saved [94215]
#
# --2024-05-21 20:43:09--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig03.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167679 (164K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb1.png’
#
# tmp/pocus_images/co 100%[===================>] 163.75K   163KB/s    in 1.0s
#
# 2024-05-21 20:43:12 (163 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb1.png’ saved [167679/167679]
#
# --2024-05-21 20:43:12--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig03.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 167679 (164K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb1_2.png’
#
# tmp/pocus_images/co 100%[===================>] 163.75K   162KB/s    in 1.0s
#
# 2024-05-21 20:43:13 (162 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb1_2.png’ saved [167679/167679]
#
# --2024-05-21 20:43:13--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig06-1-1024x682.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 428501 (418K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_efsumb3.png’
#
# tmp/pocus_images/co 100%[===================>] 418.46K   207KB/s    in 2.0s
#
# 2024-05-21 20:43:16 (207 KB/s) - ‘tmp/pocus_images/convex/Cov_efsumb3.png’ saved [428501/428501]
#
# --2024-05-21 20:43:16--  https://wfumb.info/wp-content/uploads/2020/04/wfumb_april_fig01.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 325738 (318K) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_efsumb2.png’
#
# tmp/pocus_images/co 100%[===================>] 318.10K   185KB/s    in 1.7s
#
# 2024-05-21 20:43:19 (185 KB/s) - ‘tmp/pocus_images/convex/Reg_efsumb2.png’ saved [325738/325738]
#
# --2024-05-21 20:43:19--  https://sonographiebilder.de/fileadmin/_processed_/c/b/csm_Pneumonie_li_canifizierend_24ebb9e166.jpg
# Resolving sonographiebilder.de (sonographiebilder.de)... 88.198.28.130
# Connecting to sonographiebilder.de (sonographiebilder.de)|88.198.28.130|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 
:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.
# --2024-05-21 20:43:23--  https://cdn.amegroups.cn/journals/amepc/files/journals/8/articles/46675/public/46675-PB8-6552-R1.png
# Resolving cdn.amegroups.cn (cdn.amegroups.cn)... 163.181.164.229
# Connecting to cdn.amegroups.cn (cdn.amegroups.cn)|163.181.164.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1508419 (1.4M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_Chen_2020_3A.png’
#
# tmp/pocus_images/co 100%[===================>]   1.44M  8.51MB/s    in 0.2s
#
# 2024-05-21 20:43:24 (8.51 MB/s) - ‘tmp/pocus_images/convex/Reg_Chen_2020_3A.png’ saved [1508419/1508419]
#
# --2024-05-21 20:43:24--  https://cdn.amegroups.cn/journals/amepc/files/journals/8/articles/46675/public/46675-PB8-6552-R1.png
# Resolving cdn.amegroups.cn (cdn.amegroups.cn)... 163.181.164.229
# Connecting to cdn.amegroups.cn (cdn.amegroups.cn)|163.181.164.229|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1508419 (1.4M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Reg_Chen_2020_6A.png’
#
# tmp/pocus_images/co 100%[===================>]   1.44M  --.-KB/s    in 0.01s
#
# 2024-05-21 20:43:24 (134 MB/s) - ‘tmp/pocus_images/convex/Reg_Chen_2020_6A.png’ saved [1508419/1508419]
#
# --2024-05-21 20:43:24--  https://ars.els-cdn.com/content/image/1-s2.0-S0012369212605662-gr2.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117836 (115K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg’
#
# tmp/pocus_images/co 100%[===================>] 115.07K  --.-KB/s    in 0.003s
#
# 2024-05-21 20:43:24 (33.6 MB/s) - ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg’ saved [117836/117836]
#
# --2024-05-21 20:43:24--  https://ars.els-cdn.com/content/image/1-s2.0-S0012369212605662-gr2.jpg
# Resolving ars.els-cdn.com (ars.els-cdn.com)... 104.18.32.42, 172.64.155.214, 2606:4700:4400::6812:202a, ...
# Connecting to ars.els-cdn.com (ars.els-cdn.com)|104.18.32.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117836 (115K) [image/jpeg]
# Saving to: ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg’
#
# tmp/pocus_images/co 100%[===================>] 115.07K  --.-KB/s    in 0.005s
#
# 2024-05-21 20:43:25 (22.1 MB/s) - ‘tmp/pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg’ saved [117836/117836]
#
# --2024-05-21 20:43:25--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_a.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   437KB/s    in 3.0s
#
# 2024-05-21 20:43:29 (437 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_a.jpg’ saved [1352950/1352950]
#
# --2024-05-21 20:43:29--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_b.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   409KB/s    in 3.2s
#
# 2024-05-21 20:43:33 (409 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_b.jpg’ saved [1352950/1352950]
#
# --2024-05-21 20:43:33--  https://wfumb.info/wp-content/uploads/2020/12/wfumb-dec2pics.png
# Resolving wfumb.info (wfumb.info)... 78.129.255.112
# Connecting to wfumb.info (wfumb.info)|78.129.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1352950 (1.3M) [image/png]
# Saving to: ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_c.jpg’
#
# tmp/pocus_images/co 100%[===================>]   1.29M   473KB/s    in 2.8s
#
# 2024-05-21 20:43:36 (473 KB/s) - ‘tmp/pocus_images/convex/Cov_wfumb_case_dez_c.jpg’ saved [1352950/1352950]
#
# --2024-05-21 20:43:36--  https://www.medrxiv.org/content/medrxiv/early/2020/10/22/2020.10.13.20212258/DC3/embed/media-3.mp4
# Resolving www.medrxiv.org (www.medrxiv.org)... 104.21.11.180, 172.67.166.236, 2606:4700:3033::6815:bb4, ...
# Connecting to www.medrxiv.org (www.medrxiv.org)|104.21.11.180|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464883 (454K) [video/mp4]
# Saving to: ‘tmp/pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4’
#
# tmp/pocus_videos/co 100%[===================>] 453.99K   913KB/s    in 0.5s
#
# 2024-05-21 20:43:38 (913 KB/s) - ‘tmp/pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4’ saved [464883/464883]
#
# Data fetched. Postprocessing...
# Done, shutting down.

# %%
#how many files we get from web
# !ls -1 /content/tmp/pocus_images/convex | wc -l
# !ls -1 /content/tmp/pocus_images/linear | wc -l
# !ls -1 /content/tmp/pocus_videos/convex | wc -l
# !ls -1 /content/tmp/pocus_videos/linear | wc -l
# Out:
# 31
# 4
# 41
# 9

# %%
#crop web files and put into data folder
# !python3 /content/crop_processed_data.py
# Out:
# pocus_videos/convex/Reg-nephropocus.gif [[25, 90, 250], [0, 30.0]]
# (30, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-Youtube.mp4 [[40, 150, 280], [2299, 2429]]
# Problem reading file: tmp/pocus_videos/convex/Reg-Youtube.mp4
# pocus_videos/convex/pneu-everyday.gif [[30, 90, 340], [0, 61.0]]
# (61, 340, 340, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-clarius.gif [[30, 100, 350], [0, 103.0]]
# (103, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-bcpocus.gif [[0, 100, 400], [0, 59.0]]
# (59, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-clarius3.gif [[60, 100, 300], [0, 117.0]]
# (117, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Pneu-Youtube-start20sec.mp4 [[120, 650, 500], [667, 777]]
# Problem reading file: tmp/pocus_videos/linear/Pneu-Youtube-start20sec.mp4
# pocus_videos/linear/Reg-NormalLung.gif [[0, 30, 330], [0, 35.0]]
# (35, 330, 330, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-Youtube-Video_902_Lung_POCUS-left.mp4 [[70, 30, 190], [0, 96.0]]
# Problem reading file: tmp/pocus_videos/linear/Reg-Youtube-Video_902_Lung_POCUS-left.mp4
# pocus_videos/linear/Reg-Youtube-start20sec.mp4 [[125, 50, 500], [667, 777]]
# Problem reading file: tmp/pocus_videos/linear/Reg-Youtube-start20sec.mp4
# pocus_videos/linear/Reg-minimalmovement.gif [[0, 10, 350], [0, 45.0]]
# (45, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_images/convex/Pneu_clarius.jpg [[40, 200, 380], [0, 0.0]]
# [ERROR:0@2.124] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Pneu_clarius.jpg in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Pneu_clarius.jpg
# pocus_images/convex/Pneu_clarius2.png [[30, 200, 380], [0, 0.0]]
# Problem reading file: tmp/pocus_images/convex/Pneu_clarius2.png
# pocus_videos/convex/Reg-Grep-Normal.gif [[40, 60, 400], [0, 33.0]]
# (33, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Vir_blines_advancesVid9.mp4 [[30, 200, 300], [0, 240.0]]
# (240, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu_clinicalreview_MOV4.mp4 [[20, 150, 400], [0, 96.0]]
# (96, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7453.mp4 [[50, 150, 370], [0, 210.0]]
# (210, 370, 370, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov_new_pregnant_vid8.avi [[200, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid8.avi
# pocus_videos/convex/Cov-grep-7525.mp4 [[150, 150, 400], [0, 361.0]]
# (361, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia2_1.mp4 [[180, 250, 500], [0, 300.0]]
# (300, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7543.mp4 [[50, 150, 350], [0, 70.0]]
# (70, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia4.mp4 [[0, 0, 410], [0, 151.0]]
# (151, 410, 410, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia1.mp4 [[100, 100, 300], [0, 151.0]]
# (151, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pulmonary-pneumonia.mp4 [[100, 250, 500], [0, 187.0]]
# (187, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/pneu-gred-7.gif [[15, 50, 150], [0, 48.0]]
# (48, 150, 150, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-pneumonia3.mp4 [[50, 100, 300], [0, 114.0]]
# (114, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg-Grep-Alines.mp4 [[80, 100, 420], [0, 85.0]]
# (85, 420, 420, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/pneu-gred-6.gif [[50, 150, 250], [0, 54.0]]
# (54, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu_consol_advancesVid10.mp4 [[20, 50, 350], [0, 450.0]]
# (450, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg_clinicalreview_mov1.mp4 [[20, 100, 400], [0, 197.0]]
# (197, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grepmed-blines-pocus-.mp4 [[200, 320, 450], [0, 225.0]]
# (225, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grepmed2.mp4 [[50, 100, 280], [0, 298.0]]
# (298, 280, 280, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7507.mp4 [[80, 150, 300], [0, 159.0]]
# (159, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov_new_pregnant_vid3.avi [[220, 600, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid3.avi
# pocus_videos/convex/Pneu-grep-bacterial-hepatization-clinical.mp4 [[100, 250, 400], [0, 300.0]]
# (300, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7511.mp4 [[180, 220, 500], [0, 269.0]]
# (269, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7505.mp4 [[50, 100, 500], [0, 365.0]]
# (365, 500, 500, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Reg_alines_advancesVid4.mp4 [[60, 100, 450], [0, 177.0]]
# (177, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Cov-grep-7510.mp4 [[170, 250, 450], [0, 267.0]]
# (267, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/convex/Pneu-grep-shredsign-consolidation.mp4 [[100, 250, 400], [0, 458.0]]
# (458, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-nephropocus.gif [[0, 125, 350], [0, 150.0]]
# (150, 350, 350, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7431.mp4 [[180, 380, 400], [0, 116.0]]
# (116, 400, 400, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7432.mp4 [[120, 500, 550], [0, 280.0]]
# (280, 550, 550, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Cov-grep-7500.mp4 [[20, 80, 300], [0, 75.0]]
# (75, 300, 300, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_videos/linear/Reg-grep-normal-alines-original.mp4 [[0, 180, 250], [0, 165.0]]
# (165, 250, 250, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# pocus_images/convex/Cov_ablines_covidmanifestations_paper1.png [[200, 300, 1000], [0, 1.0]]
# pocus_images/convex/Cov_pregnantPublication1.png [[25, 320, 250], [0, 1.0]]
# pocus_images/convex/Cov_blines_covidmanifestation_paper2.png [[120, 220, 500], [0, 1.0]]
# pocus_images/convex/Reg_com_acquired_paper.png [[10, 360, 150], [0, 1.0]]
# [ERROR:0@24.866] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Reg_com_acquired_paper.png in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Reg_com_acquired_paper.png
# pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png [[0, 0, 160], [0, 1.0]]
# [ERROR:0@24.867] global cap.cpp:164 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.8.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): tmp/pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png in function 'icvExtractPattern'
#
#
# Problem reading file: tmp/pocus_images/convex/Pneu_air_bronchogram_com_acquired_paper.png
# pocus_images/linear/Pneu_consol_pedriatic_pneumonia.png [[330, 10, 240], [0, 1.0]]
# pocus_images/linear/Cov_irregularpleural_covidmanifestations_paper3.png [[120, 200, 800], [0, 1.0]]
# pocus_images/linear/Pneu_leftbasal_pedriatic_pneumonia.png [[10, 30, 230], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig2.png [[40, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig3.png [[50, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_blines_thoraric_paperfig1.png [[80, 200, 800], [0, 1.0]]
# pocus_videos/linear/Cov_linear_abrams_2020_v1.mp4 [[40, 100, 400], [0, 64.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5991d2b0aa00] moov atom not found
# Problem reading file: tmp/pocus_videos/linear/Cov_linear_abrams_2020_v1.mp4
# pocus_images/convex/Pneu_sonographiebilder2.jpg [[60, 100, 400], [0, 1.0]]
# pocus_images/convex/Reg_efsumb2.png [[100, 250, 500], [0, -9.223372036854776e+18]]
# pocus_images/convex/Pneu_sonographiebilder1.jpg [[80, 200, 400], [0, 1.0]]
# pocus_images/convex/Reg_publication1.png [[20, 30, 250], [0, -9.223372036854776e+18]]
# [png @ 0x5991d2db6500] Invalid PNG signature 0xA0A3C21444F4354.
# [png @ 0x5991d2cd8180] Invalid PNG signature 0xA0A3C21444F4354.
# Problem reading file: tmp/pocus_images/convex/Reg_publication1.png
# pocus_images/convex/Cov_pleuralthickening_thoraric_paperfig8.png [[50, 150, 400], [0, 1.0]]
# pocus_images/convex/Cov_whitelungs_thoraric_paperfig5.png [[90, 200, 350], [0, 1.0]]
# pocus_images/convex/Cov_efsumb3.png [[50, 200, 600], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_efsumb1.png [[30, 50, 200], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_pleuraleffusion_thoraric_paperfig9.png [[30, 150, 450], [0, 1.0]]
# pocus_images/convex/Cov_subpleuralthickening_thoraric_paperfig6.png [[40, 150, 400], [0, 1.0]]
# pocus_videos/convex/Pneu_AIR BRONC2.mov [[40, 150, 300], [0, 52.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5991d285bb40] moov atom not found
# Problem reading file: tmp/pocus_videos/convex/Pneu_AIR BRONC2.mov
# pocus_videos/convex/Reg_Alines-1-90.mov [[20, 150, 350], [0, 78.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5991d2b0aa00] moov atom not found
# Problem reading file: tmp/pocus_videos/convex/Reg_Alines-1-90.mov
# pocus_images/convex/Cov_efsumb1_2.png [[20, 400, 200], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_pregnantPublication2.png [[140, 630, 115], [0, 1.0]]
# pocus_images/convex/Cov_siemens_1.png [[180, 500, 800], [0, 1.0]]
# Problem reading file: tmp/pocus_images/convex/Cov_siemens_1.png
# pocus_images/convex/Cov_siemens_2.png [[180, 500, 750], [0, 1.0]]
# Problem reading file: tmp/pocus_images/convex/Cov_siemens_2.png
# pocus_images/linear/Cov_siemens_3.png [[20, 500, 950], [0, 1.0]]
# Problem reading file: tmp/pocus_images/linear/Cov_siemens_3.png
# pocus_videos/linear/Reg_siemens_vid_3.mp4 [[120, 400, 500], [0, 269.0]]
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x5991d2b0aa00] moov atom not found
# Problem reading file: tmp/pocus_videos/linear/Reg_siemens_vid_3.mp4
# pocus_videos/convex/Cov_new_pregnant_vid4.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid4.avi
# pocus_videos/convex/Cov_new_pregnant_vid5.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid5.avi
# pocus_videos/convex/Cov_new_pregnant_vid7.avi [[200, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid7.avi
# pocus_videos/convex/Cov_new_pregnant_vid6.avi [[250, 700, 800], [0, 150.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid6.avi
# pocus_videos/convex/Cov_new_pregnant_vid2.avi [[250, 700, 800], [0, 142.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid2.avi
# pocus_videos/convex/Cov_new_pregnant_vid1.avi [[250, 700, 800], [0, 144.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_new_pregnant_vid1.avi
# pocus_videos/convex/Pneu_Youtube_case.mp4 [[40, 100, 270], [0, 164.0]]
# Problem reading file: tmp/pocus_videos/convex/Pneu_Youtube_case.mp4
# pocus_images/convex/Reg_Chen_2020_3A.png [[20, 50, 230], [0, -9.223372036854776e+18]]
# pocus_images/convex/Pneu_Reissig_2012_fig2A.jpg [[25, 20, 220], [0, 1.0]]
# pocus_images/convex/Pneu_Reissig_2012_fig2B.jpg [[25, 300, 230], [0, 1.0]]
# pocus_images/convex/Reg_Chen_2020_6A.png [[20, 50, 200], [0, -9.223372036854776e+18]]
# pocus_videos/convex/Cov_wfumb_case_dez.mp4 [[20, 75, 300], [0, 91.0]]
# Problem reading file: tmp/pocus_videos/convex/Cov_wfumb_case_dez.mp4
# pocus_images/convex/Cov_wfumb_case_dez_a.jpg [[70, 250, 400], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_wfumb_case_dez_c.jpg [[580, 200, 480], [0, -9.223372036854776e+18]]
# pocus_images/convex/Cov_wfumb_case_dez_b.jpg [[70, 1150, 430], [0, -9.223372036854776e+18]]
# pocus_videos/convex/Cov_Arnthfield_2020_Vid3.mp4 [[100, 250, 450], [0, 120.0]]
# (120, 450, 450, 3)
# OpenCV: FFMPEG: tag 0x5634504d/'MP4V' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'

# %%
# check if new files appear in the folders
# !ls -1 /content/data/pocus_images/convex | wc -l
# !ls -1 /content/data/pocus_images/linear | wc -l
# !ls -1 /content/data/pocus_videos/convex | wc -l
# !ls -1 /content/data/pocus_videos/linear | wc -l
# Out:
# 53
# 6
# 155
# 18

# %%
#temp delete
#!rm -rf tmp

# %%
#crop videos files, images, put into image_dataset folder
# !python3 /content/build_image_dataset.py
# Out:
# Reg_Image_181602_trimmed_crop.mp4 framerate 29.03790956871808 width 386.0 height 386.0 number frames: 374.0
# --> taking every  9 th image
# Pneu_northumbria_0409_set1_vid2.avi framerate 22.25 width 520.0 height 520.0 number frames: 93.0
# --> taking every  7 th image
# Cov-grep-7525.mp4 framerate 20.833 width 400.0 height 400.0 number frames: 361.0
# --> taking every  6 th image
# Cov_denault_proposedUS_vid11.mov framerate 60.0 width 852.0 height 852.0 number frames: 143.0
# --> taking every  20 th image
# Reg_Avi_lung-sliding.MP4 framerate 18.0 width 528.0 height 528.0 number frames: 56.0
# --> taking every  6 th image
# Pneu_northumbria_0409_set2_vid3.avi framerate 22.25 width 503.0 height 503.0 number frames: 92.0
# --> taking every  7 th image
# Cov_denault_proposedUS_vid5.mov framerate 60.0 width 706.0 height 706.0 number frames: 210.0
# --> taking every  20 th image
# Reg-Grep-Normal.mp4 framerate 10.0 width 400.0 height 400.0 number frames: 33.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set6_vid5.avi framerate 22.243482420473573 width 509.0 height 509.0 number frames: 93.0
# --> taking every  7 th image
# Cov_emdocs_vid3.gif framerate 21.083333333333332 width 748.0 height 748.0 number frames: 75.0
# --> taking every  7 th image
# Cov-grep-7453.mp4 framerate 20.833 width 370.0 height 370.0 number frames: 210.0
# --> taking every  6 th image
# Reg_pat4Image_140024.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 436.0
# --> taking every  8 th image
# Pneu_Avi_Video_006.mp4 framerate 22.243713733075435 width 609.0 height 609.0 number frames: 92.0
# --> taking every  7 th image
# Cov-grepmed2.mp4 framerate 33.333 width 280.0 height 280.0 number frames: 298.0
# --> taking every  11 th image
# Cov-grep-7511.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 269.0
# --> taking every  10 th image
# Reg_pat1Image_133138.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 260.0
# --> taking every  8 th image
# Pneu_Avi_Video_005.mp4 framerate 22.249388753056234 width 607.0 height 607.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid4.avi framerate 22.249388753056234 width 519.0 height 519.0 number frames: 91.0
# --> taking every  7 th image
# Cov_combatting_Image2.mp4 framerate 31.833333333333332 width 440.0 height 440.0 number frames: 191.0
# --> taking every  10 th image
# Cov_denault_proposedUS_vid10.mov framerate 60.0 width 852.0 height 852.0 number frames: 141.0
# --> taking every  20 th image
# Cov_combatting_image4.mp4 framerate 27.4 width 476.0 height 476.0 number frames: 137.0
# --> taking every  9 th image
# Pneu_northumbria_0409_set6_vid3.avi framerate 22.25 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Reg_pat3Image_135026.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 278.0
# --> taking every  8 th image
# Reg_pat4Image_140434.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 323.0
# --> taking every  8 th image
# Pneu-grep-pulmonary-pneumonia.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 187.0
# --> taking every  10 th image
# Pneu-grep-shredsign-consolidation.mp4 framerate 46.0 width 400.0 height 400.0 number frames: 458.0
# --> taking every  15 th image
# Reg-nephropocus.mp4 framerate 10.0 width 250.0 height 250.0 number frames: 30.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set5_vid2.avi framerate 22.25 width 516.0 height 516.0 number frames: 92.0
# --> taking every  7 th image
# Cov-Atlas-Day+3.gif framerate 10.0 width 240.0 height 240.0 number frames: 40.0
# --> taking every  3 th image
# Cov_combatting_Image1.mp4 framerate 28.25 width 440.0 height 440.0 number frames: 113.0
# --> taking every  9 th image
# Reg_Avi_Image004.mp4 framerate 50.261259019656634 width 586.0 height 586.0 number frames: 202.0
# --> taking every  16 th image
# Pneu_northumbria_0409_set3_vid1.avi framerate 22.25 width 481.0 height 481.0 number frames: 90.0
# --> taking every  7 th image
# Reg_pat2Image_133824.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 271.0
# --> taking every  8 th image
# Pneu_liftl_pneu_case3_clip3.mp4 framerate 15.0 width 280.0 height 280.0 number frames: 25.0
# --> taking every  5 th image
# Cov-Atlas-suspectedCovid.mp4 framerate 25.0 width 1080.0 height 1080.0 number frames: 100.0
# --> taking every  8 th image
# Reg-Atlas-lungcurtain.gif framerate 10.0 width 212.0 height 212.0 number frames: 60.0
# --> taking every  3 th image
# pneu-everyday.mp4 framerate 10.0 width 340.0 height 340.0 number frames: 61.0
# --> taking every  3 th image
# Cov_denault_proposedUS_vid12.mov framerate 60.0 width 852.0 height 852.0 number frames: 161.0
# --> taking every  20 th image
# Reg_pat1Image_133327.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 218.0
# --> taking every  8 th image
# Reg_alines_advancesVid4.mp4 framerate 29.97 width 450.0 height 450.0 number frames: 177.0
# --> taking every  9 th image
# Pneu_Avi_Video_004.mp4 framerate 22.743947175348495 width 606.0 height 606.0 number frames: 31.0
# --> taking every  7 th image
# Cov_convex_volpecelli_sonographic_v3.mov framerate 39.0 width 416.0 height 416.0 number frames: 399.0
# --> taking every  13 th image
# Reg_Image_182106_crop.mp4 framerate 31.15547489413188 width 382.0 height 382.0 number frames: 206.0
# --> taking every  10 th image
# Pneu_northumbria_0409_set6_vid8.avi framerate 22.249388753056234 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Reg_pat2Image_133952.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 254.0
# --> taking every  8 th image
# Cov-Atlas+(45).gif framerate 10.0 width 174.0 height 174.0 number frames: 21.0
# --> taking every  3 th image
# Cov_convex_volpecelli_sonographic_v5.mov framerate 39.0 width 444.0 height 444.0 number frames: 401.0
# --> taking every  13 th image
# Pneu_northumbria_0409_set2_vid2.avi framerate 22.25 width 524.0 height 524.0 number frames: 93.0
# --> taking every  7 th image
# Reg_Image_181739_trimmed_crop.mp4 framerate 29.028603794958936 width 386.0 height 386.0 number frames: 104.0
# --> taking every  9 th image
# Reg_pat4Image_135904.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 266.0
# --> taking every  8 th image
# Reg_pat3Image_135128.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 208.0
# --> taking every  8 th image
# Reg_Avi_Video_004.mp4 framerate 50.261259019656634 width 597.0 height 597.0 number frames: 202.0
# --> taking every  16 th image
# pneu-gred-7.mp4 framerate 16.667 width 150.0 height 150.0 number frames: 48.0
# --> taking every  5 th image
# Reg_pat4Image_140606.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 218.0
# --> taking every  8 th image
# Pneu-grep-pneumonia4.mp4 framerate 33.333 width 410.0 height 410.0 number frames: 151.0
# --> taking every  11 th image
# Reg_Image_182340_crop.mp4 framerate 37.109587550331916 width 400.0 height 400.0 number frames: 309.0
# --> taking every  12 th image
# Reg_northumbria_0409_set3_vid1.avi framerate 22.25 width 470.0 height 470.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid1.avi framerate 22.25 width 514.0 height 514.0 number frames: 92.0
# --> taking every  7 th image
# Reg_northumbria_0409_set5_vid2.avi framerate 29.97002997002997 width 864.0 height 864.0 number frames: 98.0
# --> taking every  9 th image
# Reg-NormalLungs.mp4 framerate 25.0 width 148.0 height 141.0 number frames: 131.0
# --> taking every  8 th image
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# [swscaler @ 0x5636a4a79b40] Slice parameters 0, 141 are invalid
# Pneu_northumbria_0409_set1_vid1.avi framerate 22.25 width 516.0 height 516.0 number frames: 90.0
# --> taking every  7 th image
# Reg_Avi_lung-sliding-2.MP4 framerate 18.0 width 528.0 height 528.0 number frames: 56.0
# --> taking every  6 th image
# Pneu_northumbria_1009_vid1.avi framerate 22.25 width 501.0 height 501.0 number frames: 93.0
# --> taking every  7 th image
# Reg_liftl_pneucase3_clip1.mp4 framerate 15.0 width 286.0 height 286.0 number frames: 24.0
# --> taking every  5 th image
# Pneu-Atlas-pneumonia.gif framerate 10.0 width 208.0 height 208.0 number frames: 59.0
# --> taking every  3 th image
# Reg_pat3Image_134811.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 206.0
# --> taking every  8 th image
# Reg_pat3Image_135215.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 317.0
# --> taking every  8 th image
# Cov_Arnthfield_2020_Vid3.mp4 framerate 30.0 width 450.0 height 450.0 number frames: 120.0
# --> taking every  10 th image
# Reg_northumbria_1009_vid5.avi framerate 22.243482420473573 width 475.0 height 475.0 number frames: 93.0
# --> taking every  7 th image
# Pneu-Atlas-pneumonia2.gif framerate 10.0 width 327.0 height 327.0 number frames: 40.0
# --> taking every  3 th image
# Reg_northumbria_1009_vid1.avi framerate 22.25 width 478.0 height 478.0 number frames: 92.0
# --> taking every  7 th image
# Reg-Atlas-alines.gif framerate 10.0 width 165.0 height 165.0 number frames: 60.0
# --> taking every  3 th image
# Pneu-grep-pneumonia1.mp4 framerate 25.0 width 300.0 height 300.0 number frames: 151.0
# --> taking every  8 th image
# Cov_denault_proposedUS_vid13.mov framerate 60.0 width 852.0 height 852.0 number frames: 174.0
# --> taking every  20 th image
# Reg_pat1Image_133043.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 245.0
# --> taking every  8 th image
# Reg-Atlas.gif framerate 10.0 width 250.0 height 250.0 number frames: 59.0
# --> taking every  3 th image
# Pneu-grep-pneumonia3.mp4 framerate 33.333 width 300.0 height 300.0 number frames: 114.0
# --> taking every  11 th image
# Reg_Avi_Image003.mp4 framerate 50.261259019656634 width 520.0 height 520.0 number frames: 202.0
# --> taking every  16 th image
# Reg_pat2Image_134441.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 214.0
# --> taking every  8 th image
# Cov_denault_proposedUS_vid14.mov framerate 60.0 width 852.0 height 852.0 number frames: 137.0
# --> taking every  20 th image
# Pneu_northumbria_0409_set5_vid1.avi framerate 22.25 width 509.0 height 509.0 number frames: 92.0
# --> taking every  7 th image
# Pneu_basalpneumonia_liftle_case1.mp4 framerate 15.0 width 340.0 height 340.0 number frames: 42.0
# --> taking every  5 th image
# Reg_pat2Image_134348.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 207.0
# --> taking every  8 th image
# Cov-Atlas+(44).gif framerate 10.0 width 139.0 height 139.0 number frames: 41.0
# --> taking every  3 th image
# Reg_Avi_Video_001.mp4 framerate 22.243713733075435 width 609.0 height 609.0 number frames: 92.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set6_vid2.avi framerate 22.25 width 517.0 height 517.0 number frames: 92.0
# --> taking every  7 th image
# Cov-clarius.mp4 framerate 10.0 width 350.0 height 350.0 number frames: 103.0
# --> taking every  3 th image
# Pneu-grep-bacterial-hepatization-clinical.mp4 framerate 30.0 width 400.0 height 400.0 number frames: 300.0
# --> taking every  10 th image
# Pneu_Avi_Video_002.mp4 framerate 22.243482420473573 width 609.0 height 609.0 number frames: 93.0
# --> taking every  7 th image
# Pneu_from_article_rippey.mp4 framerate 15.0 width 272.0 height 272.0 number frames: 42.0
# --> taking every  5 th image
# Reg_pat2Image_134240.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 254.0
# --> taking every  8 th image
# Reg_liftl_case3_clip2.mp4 framerate 15.0 width 264.0 height 264.0 number frames: 32.0
# --> taking every  5 th image
# Pneu_Avi_Video_001.mp4 framerate 22.249388753056234 width 608.0 height 608.0 number frames: 91.0
# --> taking every  7 th image
# pneu-gred-6.mp4 framerate 10.0 width 250.0 height 250.0 number frames: 54.0
# --> taking every  3 th image
# Cov_recommendations_lightbeam_mov6.mov framerate 29.97002997002997 width 538.0 height 538.0 number frames: 309.0
# --> taking every  9 th image
# Reg_Avi_lung-sliding-3.MP4 framerate 18.0 width 512.0 height 512.0 number frames: 55.0
# --> taking every  6 th image
# Reg_pat1Image_133232.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 199.0
# --> taking every  8 th image
# Reg_northumbria_1009_vid7.avi framerate 22.243713733075435 width 511.0 height 511.0 number frames: 92.0
# --> taking every  7 th image
# Cov_denault_proposedUS_vid2.mov framerate 60.0 width 842.0 height 842.0 number frames: 459.0
# --> taking every  20 th image
# Pneu_Basal-pneumonia-RUQ_crop.mp4 framerate 15.0 width 268.0 height 268.0 number frames: 27.0
# --> taking every  5 th image
# Reg_northumbria_1009_vid2.avi framerate 22.25 width 476.0 height 476.0 number frames: 92.0
# --> taking every  7 th image
# Pneu_Pneumonia-LITFL-Ultrasound_crop.mp4 framerate 15.0 width 316.0 height 316.0 number frames: 27.0
# --> taking every  5 th image
# Cov-grep-7507.mp4 framerate 30.0 width 300.0 height 300.0 number frames: 159.0
# --> taking every  10 th image
# Pneu_northumbria_0409_set2_vid4.avi framerate 22.25 width 523.0 height 523.0 number frames: 79.0
# --> taking every  7 th image
# Pneu_consol_advancesVid10.mp4 framerate 29.97 width 350.0 height 350.0 number frames: 450.0
# --> taking every  9 th image
# Cov_convex_volpecelli_sonographic_v1.mov framerate 39.0 width 450.0 height 450.0 number frames: 403.0
# --> taking every  13 th image
# Cov-Atlas-Day+2.gif framerate 10.0 width 142.0 height 142.0 number frames: 83.0
# --> taking every  3 th image
# Cov-Atlas-Day+1.gif framerate 10.0 width 408.0 height 408.0 number frames: 33.0
# --> taking every  3 th image
# Cov_convex_volpecelli_sonographic_v2.mov framerate 39.0 width 432.0 height 432.0 number frames: 402.0
# --> taking every  13 th image
# Reg_pat4Image_140238.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 215.0
# --> taking every  8 th image
# pneu-radiopaeda.mp4 framerate 30.0 width 221.0 height 236.0 number frames: 223.0
# --> taking every  10 th image
# Reg_pat2Image_134138.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 236.0
# --> taking every  8 th image
# Cov-grep-7505.mp4 framerate 60.0 width 500.0 height 500.0 number frames: 365.0
# --> taking every  20 th image
# Cov-grepmed-blines-pocus-.mp4 framerate 20.0 width 450.0 height 450.0 number frames: 225.0
# --> taking every  6 th image
# Pneu-grep-pneumonia2_1.mp4 framerate 30.0 width 500.0 height 500.0 number frames: 300.0
# --> taking every  10 th image
# Pneu_Avi_Video_003.mp4 framerate 22.243482420473573 width 607.0 height 607.0 number frames: 93.0
# --> taking every  7 th image
# Reg_northumbria_0409_set3_vid2.avi framerate 22.25 width 502.0 height 502.0 number frames: 94.0
# --> taking every  7 th image
# Pneu_northumbria_0409_set4_vid1.avi framerate 22.25 width 500.0 height 500.0 number frames: 90.0
# --> taking every  7 th image
# Reg_pat4Image_140705.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 266.0
# --> taking every  8 th image
# Cov-Atlas-Day+4.gif framerate 10.0 width 230.0 height 230.0 number frames: 40.0
# --> taking every  3 th image
# Pneu_northumbria_0409_set3_vid2.avi framerate 22.25 width 528.0 height 528.0 number frames: 92.0
# --> taking every  7 th image
# Cov-clarius3.mp4 framerate 10.0 width 300.0 height 300.0 number frames: 117.0
# --> taking every  3 th image
# Cov_combatting_Image5.mp4 framerate 30.333333333333332 width 394.0 height 394.0 number frames: 182.0
# --> taking every  10 th image
# Cov_denault_proposedUS_vid1.mov framerate 60.0 width 702.0 height 702.0 number frames: 145.0
# --> taking every  20 th image
# Reg_pat3Image_134904.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 245.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set6_vid7.avi framerate 22.25 width 510.0 height 510.0 number frames: 91.0
# --> taking every  7 th image
# Reg_pat3Image_134711.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 216.0
# --> taking every  8 th image
# Cov-Atlas-+(43).gif framerate 10.0 width 163.0 height 163.0 number frames: 39.0
# --> taking every  3 th image
# Reg_Avi_Image008.mp4 framerate 50.25252525252525 width 574.0 height 574.0 number frames: 199.0
# --> taking every  16 th image
# Reg_Avi_Video_003.mp4 framerate 22.26935312831389 width 608.0 height 608.0 number frames: 84.0
# --> taking every  7 th image
# Reg_pat1Image_132943.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 280.0
# --> taking every  8 th image
# Cov_emdocs_vid1.gif framerate 22.0 width 353.0 height 353.0 number frames: 134.0
# --> taking every  7 th image
# Reg_clinicalreview_mov1.mp4 framerate 50.0 width 400.0 height 400.0 number frames: 197.0
# --> taking every  16 th image
# Reg_Avi_Image002.mp4 framerate 50.261259019656634 width 568.0 height 568.0 number frames: 202.0
# --> taking every  16 th image
# Cov-grep-7510.mp4 framerate 30.0 width 450.0 height 450.0 number frames: 267.0
# --> taking every  10 th image
# Reg_northumbria_0409_set5_vid1.avi framerate 50.0 width 605.0 height 497.0 number frames: 200.0
# --> taking every  16 th image
# Reg_pat1Image_133410.mpeg framerate 25.0 width 370.0 height 370.0 number frames: 182.0
# --> taking every  8 th image
# Pneu_northumbria_0409_set4_vid2.avi framerate 22.25 width 494.0 height 494.0 number frames: 91.0
# --> taking every  7 th image
# Cov_recommendations_likebutterfly_mov5.mov framerate 22.666666666666668 width 370.0 height 370.0 number frames: 138.0
# --> taking every  7 th image
# Pneu_liftl_pneu_case3_clip4.mp4 framerate 15.0 width 306.0 height 306.0 number frames: 41.0
# --> taking every  5 th image
# Cov_convex_volpecelli_sonographic_v4.mov framerate 39.0 width 414.0 height 414.0 number frames: 405.0
# --> taking every  13 th image
# Reg-Grep-Alines.mp4 framerate 25.0 width 420.0 height 420.0 number frames: 85.0
# --> taking every  8 th image
# Cov-grep-7543.mp4 framerate 20.833 width 350.0 height 350.0 number frames: 70.0
# --> taking every  6 th image
# Reg-bcpocus.mp4 framerate 10.0 width 400.0 height 400.0 number frames: 59.0
# --> taking every  3 th image
# Cov_combatting_Image3.mp4 framerate 29.0 width 440.0 height 440.0 number frames: 174.0
# --> taking every  9 th image
# Pneu_northumbria_0409_set2_vid1.avi framerate 22.25 width 508.0 height 508.0 number frames: 91.0
# --> taking every  7 th image
# Reg_northumbria_1009_vid6.avi framerate 22.243482420473573 width 484.0 height 484.0 number frames: 93.0
# --> taking every  7 th image
# Reg_Avi_Video_002.mp4 framerate 50.79365079365079 width 608.0 height 608.0 number frames: 64.0
# --> taking every  16 th image
# Reg_northumbria_1009_vid3.avi framerate 22.249388753056234 width 441.0 height 441.0 number frames: 91.0
# --> taking every  7 th image
# Pneu_liftl_pneu_case3_clip5.mp4 framerate 15.0 width 272.0 height 272.0 number frames: 26.0
# --> taking every  5 th image
# Reg_recommendations_alines_mov1.mov framerate 18.0 width 322.0 height 322.0 number frames: 180.0
# --> taking every  6 th image
# Pneu_clinicalreview_MOV4.mp4 framerate 50.0 width 400.0 height 400.0 number frames: 96.0
# --> taking every  16 th image
# Reg_Image_181432_crop.mp4 framerate 19.142098644683525 width 242.0 height 242.0 number frames: 137.0
# --> taking every  6 th image
# Reg-nephropocus.mp4 framerate 10.0 width 350.0 height 350.0 number frames: 150.0
# --> taking every  3 th image
# Cov-Atlas-pleural2.mp4 framerate 25.0 width 414.0 height 414.0 number frames: 75.0
# --> taking every  8 th image
# Reg-NormalLung.mp4 framerate 12.0 width 330.0 height 330.0 number frames: 35.0
# --> taking every  4 th image
# Reg-minimalmovement.mp4 framerate 15.0 width 350.0 height 350.0 number frames: 45.0
# --> taking every  5 th image
# Cov-grep-7500.mp4 framerate 25.0 width 300.0 height 300.0 number frames: 75.0
# --> taking every  8 th image
# Pneu_prospective_file3.mp4 framerate 25.0 width 260.0 height 260.0 number frames: 151.0
# --> taking every  8 th image
# Reg_Image_181206_crop.mp4 framerate 19.03846153846154 width 234.0 height 234.0 number frames: 495.0
# --> taking every  6 th image
# Cov-grep-7432.mp4 framerate 29.97 width 550.0 height 550.0 number frames: 280.0
# --> taking every  9 th image
# Cov_emdocs_vid2.gif framerate 20.0 width 388.0 height 388.0 number frames: 106.0
# --> taking every  6 th image
# Reg_Image_18122_crop.mp4 framerate 19.10307487996731 width 208.0 height 208.0 number frames: 187.0
# --> taking every  6 th image
# Reg-grep-normal-alines-original.mp4 framerate 60.0 width 250.0 height 250.0 number frames: 165.0
# --> taking every  20 th image
# Cov-grep-7431.mp4 framerate 39.0 width 400.0 height 400.0 number frames: 116.0
# --> taking every  13 th image
# Cov-Atlas-pleural.mp4 framerate 23.976023976023978 width 364.0 height 364.0 number frames: 77.0
# --> taking every  7 th image

# %%
#check how many files we have (here are the images, no video files left)
# !ls -1 /content/image_dataset/covid | wc -l
# !ls -1 /content/image_dataset/pneumonia | wc -l
# !ls -1 /content/image_dataset/regular | wc -l
# Out:
# 918
# 726
# 1380

# %%
#create splits for 5 fold cross validation
#for another method in "make folders to be ready for train and test"
#!python3 /content/cross_val_splitter.py --splits 5

# %% [markdown]
# #Make folders to be ready for train and test

# %% [markdown]
# **Using POCUS cropped images (image-dataset)**
#
# Making folders fold0 - fold5, where each folder has test, validation and train folders.
#
# First, we let kfold divide the data into 5 splits, which contain train and test data. Then we take a part of the train data, which we will use for validation (for early stopping)

# %%
import os
import shutil
from sklearn.model_selection import KFold, train_test_split
import numpy as np

data_dir = '/content/image_dataset'
classes = ['covid', 'pneumonia', 'regular']

data = []
labels = []

for class_name in classes:
    class_dir = os.path.join(data_dir, class_name)
    for image_name in os.listdir(class_dir):
        data.append(os.path.join(class_dir, image_name))
        labels.append(class_name)

data = np.array(data)
labels = np.array(labels)

kf = KFold(n_splits=5, shuffle=True, random_state=42)
split_dir = os.path.join(data_dir, 'splits')
os.makedirs(split_dir, exist_ok=True)

for fold, (train_idx, test_idx) in enumerate(kf.split(data)):
    fold_dir = os.path.join(split_dir, f'fold_{fold}')
    os.makedirs(fold_dir, exist_ok=True)

    train_dir = os.path.join(fold_dir, 'train')
    val_dir = os.path.join(fold_dir, 'val')
    test_dir = os.path.join(fold_dir, 'test')
    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    train_data, val_data = train_test_split(train_idx, test_size=0.2, random_state=42)

    for idx in train_data:
        class_name = labels[idx]
        dest_folder = os.path.join(train_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

    for idx in val_data:
        class_name = labels[idx]
        dest_folder = os.path.join(val_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

    for idx in test_idx:
        class_name = labels[idx]
        dest_folder = os.path.join(test_dir, class_name)
        os.makedirs(dest_folder, exist_ok=True)
        shutil.copy(data[idx], dest_folder)

# %%
import os

def count_files(directory):
    """Funkcija skaičiuoja failus kiekvienoje direktorijoje ir jos subdirektorijose."""
    total_files = 0
    for root, dirs, files in os.walk(directory):
        total_files += len(files)
    return total_files

data_dir = '/content/image_dataset/splits'  # Čia nurodykite savo splits katalogą

# Eiti per kiekvieną fold direktoriją
for fold in os.listdir(data_dir):
    fold_dir = os.path.join(data_dir, fold)
    train_dir = os.path.join(fold_dir, 'train')
    val_dir = os.path.join(fold_dir, 'val')
    test_dir = os.path.join(fold_dir, 'test')

    # Skaičiuojame failus kiekvienoje direktorijoje
    train_count = count_files(train_dir)
    val_count = count_files(val_dir)
    test_count = count_files(test_dir)

    print(f'{fold}:')
    print(f'  Training data: {train_count} files')
    print(f'  Validation data: {val_count} files')
    print(f'  Testing data: {test_count} files')
# Out:
# fold_0:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_2:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_1:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_3:
#   Training data: 1935 files
#   Validation data: 484 files
#   Testing data: 605 files
# fold_4:
#   Training data: 1936 files
#   Validation data: 484 files
#   Testing data: 604 files

# %% [markdown]
# **Using POCUS cross validation splits**
# (old method)
#
# Making folders fold0 - fold5, where each folder has test and train folders.
#
# In each fold, it will combine previous splits images (what are in cross_validation folder) as indicated:
#
# fold0:
# *   test -> images from folder split0;
# *   train -> images from folders split1-4
#
# other folders are generated in the same way

# %%
# import os

# base_dir = "/content/"
# crossval_dir = os.path.join(base_dir, "mySplits")

# # Base folders
# for i in range(0, 5):
#     fold_dir = os.path.join(crossval_dir, f"fold{i}")
#     train_dir = os.path.join(fold_dir, "train")
#     test_dir = os.path.join(fold_dir, "test")

#     # test and train folders
#     os.makedirs(train_dir, exist_ok=True)
#     os.makedirs(test_dir, exist_ok=True)

#     # classes folders
#     for class_name in ['covid', 'pneumonia', 'regular']:
#         os.makedirs(os.path.join(train_dir, class_name), exist_ok=True)
#         os.makedirs(os.path.join(test_dir, class_name), exist_ok=True)

# %%
# classes_names = ['covid', 'pneumonia', 'regular']  # classes names

# src_dir = '/content/cross_validation/'
# dest_dir = '/content/mySplits/'

# for i in range(0, 5):
#     test_index = i  # Test split
#     train_indices = [j for j in range(0, 5) if j != i]  # The remaining splits will be used for training
#     print(test_index)
#     print(train_indices)

#     # Copy test images
#     for cls in classes_names:
#         src_folder = os.path.join(src_dir, f"split{test_index}", cls)
#         dst_folder = os.path.join(dest_dir, f"fold{i}", "test", cls)

#         for filename in os.listdir(src_folder):
#             src_file = os.path.join(src_folder, filename)
#             dst_file = os.path.join(dst_folder, filename)
#             shutil.copy(src_file, dst_file)

#     # Copy train images
#     for train_index in train_indices:
#         for cls in classes_names:
#             src_folder = os.path.join(src_dir, f"split{train_index}", cls)
#             dst_folder = os.path.join(dest_dir, f"fold{i}", "train", cls)
#             for filename in os.listdir(src_folder):
#                 src_file = os.path.join(src_folder, filename)
#                 dst_file = os.path.join(dst_folder, filename)
#                 shutil.copy(src_file, dst_file)

# %% [markdown]
# #Trying and evaluating with Keras

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils import class_weight
import numpy as np
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
import itertools
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Data generators with augmentation for the training set
train_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,  # Added vertical flip
    brightness_range=[0.8,1.2],  # Adjust brightness
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(
    preprocessing_function=tf.keras.applications.efficientnet.preprocess_input
)


# Specify image dimensions, batch size
img_height = 224
img_width = 224
batch_size = 32

# %%
#functions
# Plot the training graph
def plot_training(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Training accuracy in red
    plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
    # Validation accuracy in blue
    plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
    plt.title('Treniravimo ir validacijos tikslumas')
    plt.legend()

    plt.figure()

    # Training loss in red
    plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
    # Validation loss in blue
    plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
    plt.title('Treniravimo ir validacijos nuostoliai')
    plt.legend()

    plt.show()

# Function to calculate specificity for each class
def calculate_specificity(conf_matrix, class_index):
    tn = np.sum(conf_matrix) - np.sum(conf_matrix[class_index, :]) - np.sum(conf_matrix[:, class_index]) + conf_matrix[class_index, class_index]
    fp = np.sum(conf_matrix[:, class_index]) - conf_matrix[class_index, class_index]
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0
    return specificity

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Klasifikavimo lentelė',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Tikra klasė')
    plt.xlabel('Spėjama klasė')

# Focal Loss
def focal_loss(gamma=2., alpha=4.):
    gamma = float(gamma)
    alpha = float(alpha)
    def focal_loss_fixed(y_true, y_pred):
        epsilon = 1.e-9
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        y_true = tf.cast(y_true, tf.float32)
        loss = -y_true * alpha * tf.pow((1 - y_pred), gamma) * tf.math.log(y_pred)
        loss = tf.reduce_sum(loss, axis=1)
        return loss
    return focal_loss_fixed

# %% [markdown]
# ## Cross entropy + sgd + 0.01

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = SGD(learning_rate=0.01, momentum=0.9)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 54s 607ms/step - loss: 0.8630 - accuracy: 0.6274 - auc: 0.8084 - val_loss: 0.5952 - val_accuracy: 0.7665 - val_auc: 0.9160
# Epoch 2/30
# 61/61 [==============================] - 38s 624ms/step - loss: 0.5760 - accuracy: 0.7685 - auc: 0.9156 - val_loss: 0.6499 - val_accuracy: 0.7004 - val_auc: 0.8933
# Epoch 3/30
# 61/61 [==============================] - 36s 585ms/step - loss: 0.4680 - accuracy: 0.8165 - auc: 0.9414 - val_loss: 0.3943 - val_accuracy: 0.8492 - val_auc: 0.9591
# Epoch 4/30
# 61/61 [==============================] - 35s 575ms/step - loss: 0.4064 - accuracy: 0.8398 - auc: 0.9560 - val_loss: 0.3480 - val_accuracy: 0.8740 - val_auc: 0.9692
# Epoch 5/30
# 61/61 [==============================] - 36s 592ms/step - loss: 0.3630 - accuracy: 0.8574 - auc: 0.9629 - val_loss: 0.2508 - val_accuracy: 0.9050 - val_auc: 0.9839
# Epoch 6/30
# 61/61 [==============================] - 36s 596ms/step - loss: 0.3264 - accuracy: 0.8755 - auc: 0.9698 - val_loss: 0.2648 - val_accuracy: 0.9070 - val_auc: 0.9813
# Epoch 7/30
# 61/61 [==============================] - 34s 562ms/step - loss: 0.1325 - accuracy: 0.9499 - auc: 0.9945 - val_loss: 0.1162 - val_accuracy: 0.9607 - val_auc: 0.9962
# Epoch 23/30
# 61/61 [==============================] - 35s 563ms/step - loss: 0.1371 - accuracy: 0.9525 - auc: 0.9941 - val_loss: 0.2520 - val_accuracy: 0.9029 - val_auc: 0.9829
# Epoch 24/30
# 61/61 [==============================] - 38s 612ms/step - loss: 0.1280 - accuracy: 0.9494 - auc: 0.9941 - val_loss: 0.1329 - val_accuracy: 0.9483 - val_auc: 0.9951
# Epoch 25/30
# 61/61 [==============================] - 35s 570ms/step - loss: 0.1237 - accuracy: 0.9550 - auc: 0.9953 - val_loss: 0.1765 - val_accuracy: 0.9318 - val_auc: 0.9909
# Epoch 26/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.1098 - accuracy: 0.9581 - auc: 0.9954 - val_loss: 0.1127 - val_accuracy: 0.9649 - val_auc: 0.9935
# Epoch 27/30
# 61/61 [==============================] - 36s 577ms/step - loss: 0.1291 - accuracy: 0.9499 - auc: 0.9943 - val_loss: 1.2728 - val_accuracy: 0.7769 - val_auc: 0.9077
# Epoch 28/30
# 61/61 [==============================] - 34s 563ms/step - loss: 0.1461 - accuracy: 0.9411 - auc: 0.9925 - val_loss: 0.1830 - val_accuracy: 0.9463 - val_auc: 0.9887
# Epoch 29/30
# 61/61 [==============================] - 36s 584ms/step - loss: 0.0896 - accuracy: 0.9638 - auc: 0.9975 - val_loss: 0.2240 - val_accuracy: 0.9277 - val_auc: 0.9853
# Epoch 30/30
# 61/61 [==============================] - 36s 583ms/step - loss: 0.1189 - accuracy: 0.9654 - auc: 0.9945 - val_loss: 0.4886 - val_accuracy: 0.8368 - val_auc: 0.9515
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_0.h5
# <ipython-input-22-6063d8b55738>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 6s 212ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.66      0.98      0.79       203
#    pneumonia       0.99      0.65      0.78       139
#      regular       0.95      0.78      0.86       263
#
#     accuracy                           0.81       605
#    macro avg       0.87      0.80      0.81       605
# weighted avg       0.86      0.81      0.82       605
#
# Accuracy: 0.8148760330578513
# Specificity for covid: 0.75
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.97
# Macro-average Specificity: 0.91
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes
# 61/61 [==============================] - 35s 567ms/step - loss: 0.1765 - accuracy: 0.9364 - auc_1: 0.9908 - val_loss: 0.0938 - val_accuracy: 0.9669 - val_auc_1: 0.9981
# Epoch 17/30
# 61/61 [==============================] - 34s 559ms/step - loss: 0.1675 - accuracy: 0.9359 - auc_1: 0.9916 - val_loss: 0.1390 - val_accuracy: 0.9525 - val_auc_1: 0.9950
# Epoch 18/30
# 61/61 [==============================] - 34s 554ms/step - loss: 0.1839 - accuracy: 0.9318 - auc_1: 0.9891 - val_loss: 0.1761 - val_accuracy: 0.9339 - val_auc_1: 0.9915
# Epoch 19/30
# 61/61 [==============================] - 36s 589ms/step - loss: 0.1894 - accuracy: 0.9261 - auc_1: 0.9894 - val_loss: 0.1280 - val_accuracy: 0.9483 - val_auc_1: 0.9962
# Epoch 20/30
# 61/61 [==============================] - 38s 620ms/step - loss: 0.1832 - accuracy: 0.9328 - auc_1: 0.9903 - val_loss: 0.2493 - val_accuracy: 0.9112 - val_auc_1: 0.9821
# Epoch 21/30
# 61/61 [==============================] - 34s 558ms/step - loss: 0.1602 - accuracy: 0.9447 - auc_1: 0.9916 - val_loss: 0.1521 - val_accuracy: 0.9339 - val_auc_1: 0.9943
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_1.h5
# <ipython-input-22-6063d8b55738>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 110ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       0.98      0.94      0.96       175
#    pneumonia       0.96      0.96      0.96       152
#      regular       0.95      0.97      0.96       278
#
#     accuracy                           0.96       605
#    macro avg       0.96      0.96      0.96       605
# weighted avg       0.96      0.96      0.96       605
#
# Accuracy: 0.9619834710743802
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.96
# Macro-average Specificity: 0.98
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 47s 567ms/step - loss: 0.8431 - accuracy: 0.6222 - auc_2: 0.8141 - val_loss: 0.8234 - val_accuracy: 0.6550 - val_auc_2: 0.8386
# Epoch 2/30
# 61/61 [==============================] - 36s 583ms/step - loss: 0.5409 - accuracy: 0.7917 - auc_2: 0.9267 - val_loss: 0.9257 - val_accuracy: 0.6281 - val_auc_2: 0.8355
# Epoch 3/30
# 61/61 [==============================] - 34s 559ms/step - loss: 0.4329 - accuracy: 0.8315 - auc_2: 0.9491 - val_loss: 0.5728 - val_accuracy: 0.7624 - val_auc_2: 0.9182
# Epoch 4/30
:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_2.h5
# <ipython-input-22-6063d8b55738>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 106ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.97      0.89      0.93       180
#    pneumonia       0.94      0.96      0.95       136
#      regular       0.93      0.97      0.95       289
#
#     accuracy                           0.94       605
#    macro avg       0.95      0.94      0.94       605
# weighted avg       0.94      0.94      0.94       605
#
# Accuracy: 0.943801652892562
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.94
# Macro-average Specificity: 0.97
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 47s 572ms/step - loss: 0.8482 - accuracy: 0.6382 - auc_3: 0.8165 - val_loss: 1.0408 - val_accuracy: 0.5083 - val_auc_3: 0.7339
# Epoch 2/30
# 61/61 [==============================] - 35s 577ms/step - loss: 0.5841 - accuracy: 0.7685 - auc_3: 0.9119 - val_loss: 0.8804 - val_accuracy: 0.5930 - val_auc_3: 0.8326
# Epoch 3/30
# 61/61 [==============================] - 35s 564ms/step - loss: 0.4985 - accuracy: 0.8047 - auc_3: 0.9362 - val_loss: 0.4905 - val_accuracy: 0.8058 - val_auc_3: 0.9371
# Epoch 4/30
# 61/61 [==============================] - 35s 569ms/step - loss: 0.4456 - accuracy: 0.8331 - auc_3: 0.9459 - val_loss: 0.6156 - val_accuracy: 0.7459 - val_auc_3: 0.9099
# Epoch 5/30
# 61/61 [==============================] - 35s 572ms/step - loss: 0.3838 - accuracy: 0.8543 - auc_3: 0.9610 - val_loss: 0.4690 - val_accuracy: 0.7831 - val_auc_3: 0.9414
# Epoch 6/30
# 61/61 [==============================] - 34s 560ms/step - loss: 0.3812 - accuracy: 0.8615 - auc_3: 0.9606 - val_loss: 0.4159 - val_accuracy: 0.8450 - val_auc_3: 0.9527
# Epoch 7/30
# 61/61 [==============================] - 35s 564ms/step - loss: 0.3613 - accuracy: 0.8574 - auc_3: 0.9649 - val_loss: 0.3443 - val_accuracy: 0.8595 - val_auc_3: 0.9697
# Epoch 8/30
# 61/61 [==============================] - 36s 584ms/step - loss: 0.3053 - accuracy: 0.8791 - auc_3: 0.9752 - val_loss: 0.6681 - val_accuracy: 0.7087 - val_auc_3: 0.8908
# Epoch 9/30
# 61/61 [==============================] - 36s 583ms/step - loss: 0.2815 - accuracy: 0.8992 - auc_3: 0.9776 - val_loss: 0.2790 - val_accuracy: 0.8781 - val_auc_3: 0.9797
# Epoch 10/30
# 61/61 [==============================] - 35s 567ms/step - loss: 0.2875 - accuracy: 0.8930 - auc_3: 0.9773 - val_loss: 0.4405 - val_accuracy: 0.7810 - val_auc_3: 0.9450
# Epoch 11/30
# 61/61 [==============================] - 34s 560ms/step - loss: 0.2614 - accuracy: 0.9049 - auc_3: 0.9813 - val_loss: 0.3654 - val_accuracy: 0.8430 - val_auc_3: 0.9624
# Epoch 12/30
# 61/61 [==============================] - 38s 628ms/step - loss: 0.2508 - accuracy: 0.9013 - auc_3: 0.9818 - val_loss: 0.2535 - val_accuracy: 0.9091 - val_auc_3: 0.9829
# Epoch 13/30
# 61/61 [==============================] - 34s 570ms/step - loss: 0.2530 - accuracy: 0.8972 - auc_3: 0.9818 - val_loss: 0.2729 - val_accuracy: 0.9050 - val_auc_3: 0.9841
# Epoch 14/30
# 61/61 [==============================] - 36s 588ms/step - loss: 0.2226 - accuracy: 0.9209 - auc_3: 0.9852 - val_loss: 0.1669 - val_accuracy: 0.9298 - val_auc_3: 0.9934
# Epoch 15/30
# 61/61 [==============================] - 35s 577ms/step - loss: 0.2600 - accuracy: 0.9028 - auc_3: 0.9813 - val_loss: 0.2513 - val_accuracy: 0.9070 - val_auc_3: 0.9819
# Epoch 16/30
# 61/61 [==============================] - 35s 562ms/step - loss: 0.2165 - accuracy: 0.9199 - auc_3: 0.9860 - val_loss: 0.2158 - val_accuracy: 0.9112 - val_auc_3: 0.9870
# Epoch 17/30
# 61/61 [==============================] - 35s 574ms/step - loss: 0.2057 - accuracy: 0.9168 - auc_3: 0.9884 - val_loss: 0.2846 - val_accuracy: 0.8719 - val_auc_3: 0.9775
# Epoch 18/30
# 61/61 [==============================] - 34s 564ms/step - loss: 0.2021 - accuracy: 0.9209 - auc_3: 0.9872 - val_loss: 0.1711 - val_accuracy: 0.9236 - val_auc_3: 0.9925
# Epoch 19/30
# 61/61 [==============================] - 38s 621ms/step - loss: 0.2043 - accuracy: 0.9230 - auc_3: 0.9884 - val_loss: 0.3349 - val_accuracy: 0.8595 - val_auc_3: 0.9690
# <ipython-input-21-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_3.h5
# <ipython-input-22-6063d8b55738>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 82ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.99      0.87      0.93       187
#    pneumonia       0.95      0.87      0.91       145
#      regular       0.87      0.99      0.93       273
#
#     accuracy                           0.92       605
#    macro avg       0.94      0.91      0.92       605
# weighted avg       0.93      0.92      0.92       605
#
# Accuracy: 0.9239669421487603
# Specificity for covid: 1.00
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.88
# Macro-average Specificity: 0.96
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes
:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-21-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-21-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-21-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_fold_4.h5
# <ipython-input-22-6063d8b55738>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
#  8/19 [===========>..................] - ETA: 0s

# %% [markdown]
# ## Cross entropy + sgd + 0.001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = SGD(learning_rate=0.001, momentum=0.9)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 59s 657ms/step - loss: 1.0912 - accuracy: 0.4563 - auc: 0.6447 - val_loss: 0.9544 - val_accuracy: 0.5000 - val_auc: 0.7249
# Epoch 2/30
# 61/61 [==============================] - 36s 596ms/step - loss: 0.8315 - accuracy: 0.6326 - auc: 0.8077 - val_loss: 0.8277 - val_accuracy: 0.5579 - val_auc: 0.8020
# Epoch 3/30
# 61/61 [==============================] - 38s 627ms/step - loss: 0.7188 - accuracy: 0.6941 - auc: 0.8621 - val_loss: 0.7396 - val_accuracy: 0.6054 - val_auc: 0.8426
# Epoch 4/30
# 61/61 [==============================] - 38s 624ms/step - loss: 0.6771 - accuracy: 0.7245 - auc: 0.8771 - val_loss: 0.6625 - val_accuracy: 0.6612 - val_auc: 0.8741
# Epoch 5/30
# Epoch 21/30
# 61/61 [==============================] - 37s 600ms/step - loss: 0.3226 - accuracy: 0.8822 - auc: 0.9713 - val_loss: 0.2579 - val_accuracy: 0.8926 - val_auc: 0.9818
# Epoch 22/30
# 61/61 [==============================] - 37s 597ms/step - loss: 0.3114 - accuracy: 0.8817 - auc: 0.9727 - val_loss: 0.2724 - val_accuracy: 0.8864 - val_auc: 0.9793
# Epoch 23/30
# 61/61 [==============================] - 39s 638ms/step - loss: 0.2999 - accuracy: 0.8801 - auc: 0.9755 - val_loss: 0.2380 - val_accuracy: 0.8946 - val_auc: 0.9843
# Epoch 24/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.2738 - accuracy: 0.8879 - auc: 0.9792 - val_loss: 0.2452 - val_accuracy: 0.8740 - val_auc: 0.9830
# Epoch 25/30
# 61/61 [==============================] - 38s 625ms/step - loss: 0.2907 - accuracy: 0.8780 - auc: 0.9753 - val_loss: 0.2495 - val_accuracy: 0.8802 - val_auc: 0.9826
# Epoch 26/30
# 61/61 [==============================] - 37s 605ms/step - loss: 0.2830 - accuracy: 0.8853 - auc: 0.9776 - val_loss: 0.2407 - val_accuracy: 0.8967 - val_auc: 0.9834
# Epoch 27/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.2691 - accuracy: 0.8941 - auc: 0.9796 - val_loss: 0.2598 - val_accuracy: 0.8740 - val_auc: 0.9816
# Epoch 28/30
# 61/61 [==============================] - 37s 606ms/step - loss: 0.2762 - accuracy: 0.8915 - auc: 0.9782 - val_loss: 0.2353 - val_accuracy: 0.9029 - val_auc: 0.9844
# Epoch 29/30
# 61/61 [==============================] - 38s 608ms/step - loss: 0.2675 - accuracy: 0.8977 - auc: 0.9797 - val_loss: 0.2503 - val_accuracy: 0.9174 - val_auc: 0.9838
# Epoch 30/30
# 61/61 [==============================] - 38s 619ms/step - loss: 0.2603 - accuracy: 0.9008 - auc: 0.9806 - val_loss: 0.2196 - val_accuracy: 0.9194 - val_auc: 0.9863
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_0.h5
# <ipython-input-23-eadf520904ae>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 6s 194ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.96      0.83      0.89       203
#    pneumonia       0.91      0.95      0.93       139
#      regular       0.88      0.95      0.91       263
#
#     accuracy                           0.91       605
#    macro avg       0.92      0.91      0.91       605
# weighted avg       0.91      0.91      0.91       605
#
# Accuracy: 0.9090909090909091
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.97
# Specificity for regular: 0.90
# Macro-average Specificity: 0.95
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes
:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_1.h5
# <ipython-input-23-eadf520904ae>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 5s 109ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       0.99      0.85      0.91       175
#    pneumonia       1.00      0.89      0.94       152
#      regular       0.87      1.00      0.93       278
#
#     accuracy                           0.93       605
#    macro avg       0.95      0.92      0.93       605
# weighted avg       0.94      0.93      0.93       605
#
# Accuracy: 0.9305785123966942
# Specificity for covid: 1.00
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.88
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 2
# Class index 0: Weight 1.12
# Class index 1: Weight 1.36
# Class index 2: Weight 0.73
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 50s 611ms/step - loss: 1.0584 - accuracy: 0.4873 - auc_2: 0.6580 - val_loss: 0.9363 - val_accuracy: 0.5269 - val_auc_2: 0.7433
# Epoch 2/30
# 61/61 [==============================] - 39s 636ms/step - loss: 0.8103 - accuracy: 0.6667 - auc_2: 0.8215 - val_loss: 0.8148 - val_accuracy: 0.5640 - val_auc_2: 0.8100
# Epoch 3/30
# 61/61 [==============================] - 39s 646ms/step - loss: 0.6886 - accuracy: 0.7137 - auc_2: 0.8738 - val_loss: 0.7152 - val_accuracy: 0.6364 - val_auc_2: 0.8528
# Epoch 4/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.6160 - accuracy: 0.7571 - auc_2: 0.9022 - val_loss: 0.5734 - val_accuracy: 0.7459 - val_auc_2: 0.9201
# Epoch 5/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.5758 - accuracy: 0.7736 - auc_2: 0.9127 - val_loss: 0.5645 - val_accuracy: 0.7500 - val_auc_2: 0.9127
# Epoch 6/30
# 61/61 [==============================] - 39s 638ms/step - loss: 0.5097 - accuracy: 0.7974 - auc_2: 0.9289 - val_loss: 0.5545 - val_accuracy: 0.7541 - val_auc_2: 0.9174
# Epoch 7/30
# 61/61 [==============================] - 38s 616ms/step - loss: 0.4991 - accuracy: 0.8098 - auc_2: 0.9336 - val_loss: 0.4666 - val_accuracy: 0.7789 - val_auc_2: 0.9411
# Epoch 8/30
# 61/61 [==============================] - 37s 613ms/step - loss: 0.2879 - accuracy: 0.8920 - auc_2: 0.9773 - val_loss: 0.3170 - val_accuracy: 0.8636 - val_auc_2: 0.9695
# Epoch 24/30
# 61/61 [==============================] - 37s 612ms/step - loss: 0.2647 - accuracy: 0.8982 - auc_2: 0.9799 - val_loss: 0.4592 - val_accuracy: 0.7955 - val_auc_2: 0.9451
# Epoch 25/30
# 61/61 [==============================] - 37s 606ms/step - loss: 0.2503 - accuracy: 0.9054 - auc_2: 0.9827 - val_loss: 0.2687 - val_accuracy: 0.8905 - val_auc_2: 0.9796
# Epoch 26/30
# 61/61 [==============================] - 38s 628ms/step - loss: 0.2582 - accuracy: 0.8997 - auc_2: 0.9807 - val_loss: 0.3394 - val_accuracy: 0.8492 - val_auc_2: 0.9690
# Epoch 27/30
# 61/61 [==============================] - 37s 602ms/step - loss: 0.2526 - accuracy: 0.9008 - auc_2: 0.9822 - val_loss: 0.3043 - val_accuracy: 0.8719 - val_auc_2: 0.9726
# Epoch 28/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.2352 - accuracy: 0.9023 - auc_2: 0.9843 - val_loss: 0.2772 - val_accuracy: 0.8698 - val_auc_2: 0.9775
# Epoch 29/30
# 61/61 [==============================] - 39s 633ms/step - loss: 0.2607 - accuracy: 0.9023 - auc_2: 0.9809 - val_loss: 0.2853 - val_accuracy: 0.8802 - val_auc_2: 0.9766
# Epoch 30/30
# 61/61 [==============================] - 38s 623ms/step - loss: 0.2348 - accuracy: 0.9075 - auc_2: 0.9841 - val_loss: 0.3059 - val_accuracy: 0.8574 - val_auc_2: 0.9738
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_2.h5
# <ipython-input-23-eadf520904ae>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 90ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.95      0.85      0.90       180
#    pneumonia       0.93      0.93      0.93       136
#      regular       0.90      0.96      0.92       289
#
#     accuracy                           0.92       605
#    macro avg       0.92      0.91      0.92       605
# weighted avg       0.92      0.92      0.92       605
#
# Accuracy: 0.9173553719008265
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.90
# Macro-average Specificity: 0.95
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 51s 637ms/step - loss: 1.0942 - accuracy: 0.4527 - auc_3: 0.6337 - val_loss: 0.9358 - val_accuracy: 0.5806 - val_auc_3: 0.7616
# Epoch 2/30
:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_3.h5
# <ipython-input-23-eadf520904ae>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 86ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.94      0.88      0.91       187
#    pneumonia       0.94      0.84      0.89       145
#      regular       0.86      0.95      0.90       273
#
#     accuracy                           0.90       605
#    macro avg       0.91      0.89      0.90       605
# weighted avg       0.90      0.90      0.90       605
#
# Accuracy: 0.9008264462809917
# Specificity for covid: 0.97
# Specificity for pneumonia: 0.98
# Specificity for regular: 0.88
# Macro-average Specificity: 0.94
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 51s 641ms/step - loss: 1.0864 - accuracy: 0.4571 - auc_4: 0.6366 - val_loss: 0.9134 - val_accuracy: 0.5950 - val_auc_4: 0.7774
# Epoch 2/30
# 61/61 [==============================] - 39s 635ms/step - loss: 0.8164 - accuracy: 0.6410 - auc_4: 0.8168 - val_loss: 0.7647 - val_accuracy: 0.6343 - val_auc_4: 0.8440
# Epoch 3/30
# 61/61 [==============================] - 37s 609ms/step - loss: 0.7465 - accuracy: 0.6854 - auc_4: 0.8525 - val_loss: 0.6699 - val_accuracy: 0.7045 - val_auc_4: 0.8809
# Epoch 4/30
# 61/61 [==============================] - 38s 609ms/step - loss: 0.6662 - accuracy: 0.7288 - auc_4: 0.8814 - val_loss: 0.6267 - val_accuracy: 0.7231 - val_auc_4: 0.8931
# Epoch 5/30
# 61/61 [==============================] - 38s 627ms/step - loss: 0.6042 - accuracy: 0.7567 - auc_4: 0.9054 - val_loss: 0.5584 - val_accuracy: 0.7645 - val_auc_4: 0.9171
# Epoch 6/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.5827 - accuracy: 0.7701 - auc_4: 0.9082 - val_loss: 0.5042 - val_accuracy: 0.8079 - val_auc_4: 0.9337
# Epoch 7/30
# 61/61 [==============================] - 39s 640ms/step - loss: 0.5370 - accuracy: 0.7939 - auc_4: 0.9235 - val_loss: 0.4694 - val_accuracy: 0.8120 - val_auc_4: 0.9428
# Epoch 8/30
# 61/61 [==============================] - 37s 604ms/step - loss: 0.4932 - accuracy: 0.7986 - auc_4: 0.9358 - val_loss: 0.4799 - val_accuracy: 0.7893 - val_auc_4: 0.9378
# Epoch 9/30
# 61/61 [==============================] - 37s 609ms/step - loss: 0.4922 - accuracy: 0.8022 - auc_4: 0.9327 - val_loss: 0.4234 - val_accuracy: 0.8306 - val_auc_4: 0.9519
# Epoch 10/30
:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/cross_sgd_001_fold_4.h5
# <ipython-input-23-eadf520904ae>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 160ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.98      0.73      0.84       173
#    pneumonia       0.90      0.92      0.91       154
#      regular       0.85      0.97      0.90       277
#
#     accuracy                           0.89       604
#    macro avg       0.91      0.87      0.88       604
# weighted avg       0.90      0.89      0.89       604
#
# Accuracy: 0.8890728476821192
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.96
# Specificity for regular: 0.85
# Macro-average Specificity: 0.94
# Final Metrics Across All Folds:
# Average Accuracy: 0.91 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.96 ± 0.02
# Class covid - Average Recall: 0.83 ± 0.05
# Class covid - Average F1 Score: 0.89 ± 0.03
# Class pneumonia - Average Precision: 0.93 ± 0.04
# Class pneumonia - Average Recall: 0.91 ± 0.04
# Class pneumonia - Average F1 Score: 0.92 ± 0.02
# Class regular - Average Precision: 0.87 ± 0.02
# Class regular - Average Recall: 0.96 ± 0.02
# Class regular - Average F1 Score: 0.92 ± 0.01

# %% [markdown]
# ## Focal loss + sgd + 0.001

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = SGD(learning_rate=0.001, momentum=0.9)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 52s 619ms/step - loss: 1.8368 - accuracy: 0.5726 - auc_5: 0.7493 - val_loss: 1.1794 - val_accuracy: 0.6550 - val_auc_5: 0.8551
# Epoch 2/30
# 61/61 [==============================] - 39s 641ms/step - loss: 1.1904 - accuracy: 0.7214 - auc_5: 0.8751 - val_loss: 0.8673 - val_accuracy: 0.7438 - val_auc_5: 0.9174
# 61/61 [==============================] - 38s 627ms/step - loss: 0.3891 - accuracy: 0.8925 - auc_5: 0.9787 - val_loss: 0.3780 - val_accuracy: 0.9029 - val_auc_5: 0.9793
# Epoch 18/30
# 61/61 [==============================] - 38s 617ms/step - loss: 0.3716 - accuracy: 0.8910 - auc_5: 0.9803 - val_loss: 0.2894 - val_accuracy: 0.9112 - val_auc_5: 0.9867
# Epoch 19/30
# 61/61 [==============================] - 37s 600ms/step - loss: 0.3790 - accuracy: 0.8894 - auc_5: 0.9795 - val_loss: 0.2203 - val_accuracy: 0.9504 - val_auc_5: 0.9922
# Epoch 20/30
# 61/61 [==============================] - 38s 626ms/step - loss: 0.3564 - accuracy: 0.8966 - auc_5: 0.9817 - val_loss: 0.2797 - val_accuracy: 0.9050 - val_auc_5: 0.9872
# Epoch 21/30
# 61/61 [==============================] - 37s 603ms/step - loss: 0.3736 - accuracy: 0.9023 - auc_5: 0.9809 - val_loss: 0.2549 - val_accuracy: 0.9318 - val_auc_5: 0.9894
# Epoch 22/30
# 61/61 [==============================] - 39s 634ms/step - loss: 0.3485 - accuracy: 0.9096 - auc_5: 0.9823 - val_loss: 0.2701 - val_accuracy: 0.9442 - val_auc_5: 0.9890
# Epoch 23/30
# 61/61 [==============================] - 37s 605ms/step - loss: 0.3122 - accuracy: 0.9147 - auc_5: 0.9855 - val_loss: 0.2221 - val_accuracy: 0.9380 - val_auc_5: 0.9916
# Epoch 24/30
# 61/61 [==============================] - 38s 618ms/step - loss: 0.3321 - accuracy: 0.9090 - auc_5: 0.9832 - val_loss: 0.2207 - val_accuracy: 0.9401 - val_auc_5: 0.9919
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_0.h5
# <ipython-input-24-d4ad4cf9fd93>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 81ms/step
# Results for fold 0
#               precision    recall  f1-score   support
#
#        covid       0.98      0.86      0.92       203
#    pneumonia       0.96      0.92      0.94       139
#      regular       0.89      1.00      0.94       263
#
#     accuracy                           0.93       605
#    macro avg       0.94      0.93      0.93       605
# weighted avg       0.94      0.93      0.93       605
#
# Accuracy: 0.9338842975206612
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.91
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 1
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 50s 627ms/step - loss: 1.9271 - accuracy: 0.5545 - auc_6: 0.7383 - val_loss: 1.2145 - val_accuracy: 0.6921 - val_auc_6: 0.8523
# Epoch 2/30
# Epoch 17/30
# 61/61 [==============================] - 40s 651ms/step - loss: 0.4228 - accuracy: 0.8832 - auc_6: 0.9767 - val_loss: 0.3143 - val_accuracy: 0.9070 - val_auc_6: 0.9864
# Epoch 18/30
# 61/61 [==============================] - 40s 655ms/step - loss: 0.4548 - accuracy: 0.8889 - auc_6: 0.9756 - val_loss: 0.3161 - val_accuracy: 0.9153 - val_auc_6: 0.9865
# Epoch 19/30
# 61/61 [==============================] - 38s 617ms/step - loss: 0.4190 - accuracy: 0.8925 - auc_6: 0.9776 - val_loss: 0.2938 - val_accuracy: 0.9256 - val_auc_6: 0.9873
# Epoch 20/30
# 61/61 [==============================] - 38s 618ms/step - loss: 0.3693 - accuracy: 0.9096 - auc_6: 0.9821 - val_loss: 0.2904 - val_accuracy: 0.9215 - val_auc_6: 0.9874
# Epoch 21/30
# 61/61 [==============================] - 40s 652ms/step - loss: 0.4238 - accuracy: 0.8956 - auc_6: 0.9773 - val_loss: 0.2460 - val_accuracy: 0.9277 - val_auc_6: 0.9904
# Epoch 22/30
# 61/61 [==============================] - 39s 634ms/step - loss: 0.3466 - accuracy: 0.9034 - auc_6: 0.9832 - val_loss: 0.2666 - val_accuracy: 0.9318 - val_auc_6: 0.9899
# Epoch 23/30
# 61/61 [==============================] - 39s 627ms/step - loss: 0.3530 - accuracy: 0.9065 - auc_6: 0.9827 - val_loss: 0.3690 - val_accuracy: 0.8864 - val_auc_6: 0.9813
# Epoch 24/30
# 61/61 [==============================] - 41s 672ms/step - loss: 0.3510 - accuracy: 0.9003 - auc_6: 0.9828 - val_loss: 0.3041 - val_accuracy: 0.9132 - val_auc_6: 0.9864
# Epoch 25/30
# 61/61 [==============================] - 39s 639ms/step - loss: 0.3791 - accuracy: 0.8951 - auc_6: 0.9805 - val_loss: 0.2844 - val_accuracy: 0.9174 - val_auc_6: 0.9869
# Epoch 26/30
# 61/61 [==============================] - 38s 617ms/step - loss: 0.3283 - accuracy: 0.9096 - auc_6: 0.9853 - val_loss: 0.3415 - val_accuracy: 0.9008 - val_auc_6: 0.9835
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_1.h5
# <ipython-input-24-d4ad4cf9fd93>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 4s 130ms/step
# Results for fold 1
#               precision    recall  f1-score   support
#
#        covid       0.96      0.93      0.94       175
#    pneumonia       0.99      0.86      0.92       152
#      regular       0.90      0.99      0.94       278
#
#     accuracy                           0.94       605
#    macro avg       0.95      0.92      0.94       605
# weighted avg       0.94      0.94      0.94       605
#
# Accuracy: 0.9371900826446281
# Specificity for covid: 0.99
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.91
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes
:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_2.h5
# <ipython-input-24-d4ad4cf9fd93>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 87ms/step
# Results for fold 2
#               precision    recall  f1-score   support
#
#        covid       0.98      0.88      0.93       180
#    pneumonia       0.98      0.90      0.94       136
#      regular       0.90      1.00      0.95       289
#
#     accuracy                           0.94       605
#    macro avg       0.96      0.92      0.94       605
# weighted avg       0.94      0.94      0.94       605
#
# Accuracy: 0.9388429752066115
# Specificity for covid: 0.99
# Specificity for pneumonia: 1.00
# Specificity for regular: 0.90
# Macro-average Specificity: 0.96
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 3
# Class index 0: Weight 1.13
# Class index 1: Weight 1.39
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 54s 671ms/step - loss: 1.9248 - accuracy: 0.5535 - auc_8: 0.7367 - val_loss: 1.1478 - val_accuracy: 0.6736 - val_auc_8: 0.8656
# Epoch 2/30
# 61/61 [==============================] - 39s 646ms/step - loss: 1.2170 - accuracy: 0.7101 - auc_8: 0.8672 - val_loss: 1.0833 - val_accuracy: 0.7107 - val_auc_8: 0.8810
# Epoch 3/30
# 61/61 [==============================] - 38s 617ms/step - loss: 1.0203 - accuracy: 0.7602 - auc_8: 0.9029 - val_loss: 0.6665 - val_accuracy: 0.8471 - val_auc_8: 0.9593
# Epoch 4/30
# 61/61 [==============================] - 39s 644ms/step - loss: 0.9231 - accuracy: 0.7680 - auc_8: 0.9139 - val_loss: 0.7143 - val_accuracy: 0.8223 - val_auc_8: 0.9442
# Epoch 5/30
# 61/61 [==============================] - 40s 656ms/step - loss: 0.7614 - accuracy: 0.7984 - auc_8: 0.9377 - val_loss: 0.5120 - val_accuracy: 0.8698 - val_auc_8: 0.9685
# Epoch 6/30
# 61/61 [==============================] - 37s 614ms/step - loss: 0.6805 - accuracy: 0.8289 - auc_8: 0.9475 - val_loss: 0.4917 - val_accuracy: 0.8719 - val_auc_8: 0.9736
# Epoch 7/30
# 61/61 [==============================] - 40s 650ms/step - loss: 0.6297 - accuracy: 0.8424 - auc_8: 0.9550 - val_loss: 0.3614 - val_accuracy: 0.8946 - val_auc_8: 0.9827
# Epoch 8/30
# 61/61 [==============================] - 40s 649ms/step - loss: 0.6556 - accuracy: 0.8326 - auc_8: 0.9534 - val_loss: 0.4250 - val_accuracy: 0.8802 - val_auc_8: 0.9787
# Epoch 9/30
# 61/61 [==============================] - 38s 615ms/step - loss: 0.6251 - accuracy: 0.8398 - auc_8: 0.9543 - val_loss: 0.3872 - val_accuracy: 0.8926 - val_auc_8: 0.9805
# Epoch 10/30
# Epoch 25/30
# 61/61 [==============================] - 38s 621ms/step - loss: 0.3200 - accuracy: 0.9132 - auc_8: 0.9845 - val_loss: 0.1985 - val_accuracy: 0.9525 - val_auc_8: 0.9935
# Epoch 26/30
# 61/61 [==============================] - 39s 635ms/step - loss: 0.3160 - accuracy: 0.9116 - auc_8: 0.9856 - val_loss: 0.2311 - val_accuracy: 0.9277 - val_auc_8: 0.9915
# Epoch 27/30
# 61/61 [==============================] - 39s 631ms/step - loss: 0.3183 - accuracy: 0.9096 - auc_8: 0.9854 - val_loss: 0.2316 - val_accuracy: 0.9215 - val_auc_8: 0.9912
# Epoch 28/30
# 61/61 [==============================] - 37s 610ms/step - loss: 0.3287 - accuracy: 0.9178 - auc_8: 0.9849 - val_loss: 0.2160 - val_accuracy: 0.9380 - val_auc_8: 0.9924
# Epoch 29/30
# 61/61 [==============================] - 39s 643ms/step - loss: 0.2810 - accuracy: 0.9163 - auc_8: 0.9878 - val_loss: 0.1991 - val_accuracy: 0.9318 - val_auc_8: 0.9927
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_3.h5
# <ipython-input-24-d4ad4cf9fd93>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 3s 88ms/step
# Results for fold 3
#               precision    recall  f1-score   support
#
#        covid       0.98      0.92      0.95       187
#    pneumonia       0.96      0.93      0.94       145
#      regular       0.93      0.98      0.95       273
#
#     accuracy                           0.95       605
#    macro avg       0.96      0.94      0.95       605
# weighted avg       0.95      0.95      0.95       605
#
# Accuracy: 0.9504132231404959
# Specificity for covid: 0.99
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.94
# Macro-average Specificity: 0.97
# Found 1936 images belonging to 3 classes.
# Found 604 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 4
# Class index 0: Weight 1.11
# Class index 1: Weight 1.40
# Class index 2: Weight 0.72
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 53s 624ms/step - loss: 1.8931 - accuracy: 0.5692 - auc_9: 0.7427 - val_loss: 1.2192 - val_accuracy: 0.6364 - val_auc_9: 0.8456
# Epoch 2/30
# 61/61 [==============================] - 40s 650ms/step - loss: 1.1406 - accuracy: 0.7257 - auc_9: 0.8801 - val_loss: 1.1754 - val_accuracy: 0.6839 - val_auc_9: 0.8641
# Epoch 3/30
# 61/61 [==============================] - 39s 636ms/step - loss: 1.0111 - accuracy: 0.7546 - auc_9: 0.9033 - val_loss: 1.0956 - val_accuracy: 0.7293 - val_auc_9: 0.8873
# Epoch 4/30
# 61/61 [==============================] - 37s 607ms/step - loss: 0.8335 - accuracy: 0.7846 - auc_9: 0.9287 - val_loss: 0.9823 - val_accuracy: 0.7438 - val_auc_9: 0.9028
# 61/61 [==============================] - 39s 636ms/step - loss: 0.3652 - accuracy: 0.9055 - auc_9: 0.9814 - val_loss: 0.3612 - val_accuracy: 0.9112 - val_auc_9: 0.9813
# Epoch 20/30
# 61/61 [==============================] - 38s 620ms/step - loss: 0.3631 - accuracy: 0.9060 - auc_9: 0.9818 - val_loss: 0.5620 - val_accuracy: 0.8781 - val_auc_9: 0.9644
# Epoch 21/30
# 61/61 [==============================] - 37s 603ms/step - loss: 0.3853 - accuracy: 0.9034 - auc_9: 0.9808 - val_loss: 0.3685 - val_accuracy: 0.9132 - val_auc_9: 0.9810
# Epoch 22/30
# 61/61 [==============================] - 39s 634ms/step - loss: 0.3206 - accuracy: 0.9117 - auc_9: 0.9842 - val_loss: 0.4161 - val_accuracy: 0.9091 - val_auc_9: 0.9782
# Epoch 23/30
# 61/61 [==============================] - 37s 614ms/step - loss: 0.2851 - accuracy: 0.9199 - auc_9: 0.9874 - val_loss: 0.5318 - val_accuracy: 0.8781 - val_auc_9: 0.9706
# <ipython-input-22-216799bd4a55>:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'r-', label='Treniravimo tikslumas', color='red')
# <ipython-input-22-216799bd4a55>:13: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'b-', label='Validacijos tikslumas', color='blue')
# <ipython-input-22-216799bd4a55>:20: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(epochs, loss, 'r-', label='Treniravimo nuostoliai', color='red')
# <ipython-input-22-216799bd4a55>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b-" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, val_loss, 'b-', label='Validacijos nuostoliai', color='blue')
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_0.001_fold_4.h5
# <ipython-input-24-d4ad4cf9fd93>:120: DeprecationWarning: `np.math` is a deprecated alias for the standard library `math` module (Deprecated Numpy 1.25). Replace usages of `np.math` with `math`
#   test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
# 19/19 [==============================] - 5s 136ms/step
# Results for fold 4
#               precision    recall  f1-score   support
#
#        covid       0.95      0.87      0.91       173
#    pneumonia       0.97      0.92      0.94       154
#      regular       0.90      0.97      0.93       277
#
#     accuracy                           0.93       604
#    macro avg       0.94      0.92      0.93       604
# weighted avg       0.93      0.93      0.93       604
#
# Accuracy: 0.9288079470198676
# Specificity for covid: 0.98
# Specificity for pneumonia: 0.99
# Specificity for regular: 0.91
# Macro-average Specificity: 0.96
# Final Metrics Across All Folds:
# Average Accuracy: 0.94 ± 0.01
# Final Metrics for Each Class Across All Folds:
# Class covid - Average Precision: 0.97 ± 0.01
# Class covid - Average Recall: 0.89 ± 0.03
# Class covid - Average F1 Score: 0.93 ± 0.02
# Class pneumonia - Average Precision: 0.97 ± 0.01
# Class pneumonia - Average Recall: 0.90 ± 0.03
# Class pneumonia - Average F1 Score: 0.94 ± 0.01
# Class regular - Average Precision: 0.90 ± 0.01
# Class regular - Average Recall: 0.99 ± 0.01
# Class regular - Average F1 Score: 0.94 ± 0.01

# %% [markdown]
# ## Focal loss + sgd + 0.01

# %%
# For overall results
all_accuracies = []
all_specificities = []
class_precision = {}
class_recall = {}
class_f1 = {}

for fold in range(5):
    base_dir = f'/content/image_dataset/splits/fold_{fold}'
    train_dir = os.path.join(base_dir, 'train')
    test_dir = os.path.join(base_dir, 'test')
    val_dir = os.path.join(base_dir, 'val')


    # Data generators
    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
    )

    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical',  # Use 'sparse' if you have integer labels and are using SparseCategoricalCrossentropy
        shuffle=False
    )

    val_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical'
    )

    # Compute class weights
    class_weights_array = class_weight.compute_class_weight(
        class_weight='balanced',
        classes=np.unique(train_generator.classes),
        y=train_generator.classes
    )
    class_weights = {i: weight for i, weight in enumerate(class_weights_array)}

    print(f"Training fold {fold}")

    # Print the computed class weights
    for class_index, weight in class_weights.items():
        print(f"Class index {class_index}: Weight {weight:.2f}")

    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Calculate the number of layers to make trainable
    total_layers = len(base_model.layers)
    layers_to_train = int(total_layers * 0.30)  # 30% of the total number of layers

    # Make the first 30% of layers trainable
    for layer in base_model.layers[:layers_to_train]:
        layer.trainable = True

    # Freeze the rest of the layers
    for layer in base_model.layers[layers_to_train:]:
        layer.trainable = False

    # Freeze the layers of the base model
    #base_model.trainable = False


    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.5)(x)  # Dropout added here
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)  # Another Dropout layer
    # Add a fully connected layer for classification
    output_layer = Dense(3, activation='softmax')(x)


    # Construct the final model
    model = Model(inputs=base_model.input, outputs=output_layer)

    #optimizer
    my_optimizer = SGD(learning_rate=0.01, momentum=0.9)

    # Compile the model
    model.compile(optimizer=my_optimizer, loss=focal_loss(), metrics=['accuracy', AUC()])

    # Early stopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


    #model params
    total_params = model.count_params()
    trainable_params = np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_weights])
    non_trainable_params = total_params - trainable_params

    print(f"Total parameters: {total_params}")
    print(f"Trainable parameters: {trainable_params}")
    print(f"Non-trainable parameters: {non_trainable_params}")

    # Train the model
    history = model.fit(
        train_generator,
        epochs=30,
        validation_data=val_generator,
        class_weight=class_weights,
        callbacks=[early_stopping]
    )

    #training results
    plot_training(history)

    # Save the model
    model_save_path = f'/content/drive/MyDrive/Bakis/ModelOutputs/focal_sgd_fold_{fold}.h5'
    model.save(model_save_path)
    print(f"Model saved to {model_save_path}")


    # Predict the label of the test data
    test_steps_per_epoch = np.math.ceil(test_generator.samples / test_generator.batch_size)
    predictions = model.predict(test_generator, steps=test_steps_per_epoch)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    # Calculate the metrics
    report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    accuracy = accuracy_score(true_classes, predicted_classes)

    print(f"Results for fold {fold}")
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    print('Accuracy:', accuracy)

    # Calculate and print specificity for each class
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        class_name = list(test_generator.class_indices.keys())[i]
        print(f'Specificity for {class_name}: {spec:.2f}')

    # Calculate specificity for each class and compute macro-average
    specificities = []
    for i in range(len(test_generator.class_indices)):
        spec = calculate_specificity(conf_matrix, i)
        specificities.append(spec)

    # Calculate and print macro-average specificity
    macro_avg_specificity = np.mean(specificities)
    print(f'Macro-average Specificity: {macro_avg_specificity:.2f}')

    # Plot the confusion matrix
    plot_confusion_matrix(conf_matrix, classes=class_labels)
    plt.show()

    for label in class_labels:
        if label not in class_precision:
            class_precision[label] = []
            class_recall[label] = []
            class_f1[label] = []

        class_precision[label].append(report[label]['precision'])
        class_recall[label].append(report[label]['recall'])
        class_f1[label].append(report[label]['f1-score'])

    all_accuracies.append(accuracy)

# Bendrų rezultatų skaičiavimas
print("Final Metrics Across All Folds:")
print(f"Average Accuracy: {np.mean(all_accuracies):.2f} ± {np.std(all_accuracies):.2f}")

print("Final Metrics for Each Class Across All Folds:")
for label in class_labels:
    avg_precision = np.mean(class_precision[label])
    std_precision = np.std(class_precision[label])
    avg_recall = np.mean(class_recall[label])
    std_recall = np.std(class_recall[label])
    avg_f1 = np.mean(class_f1[label])
    std_f1 = np.std(class_f1[label])

    print(f"Class {label} - Average Precision: {avg_precision:.2f} ± {std_precision:.2f}")
    print(f"Class {label} - Average Recall: {avg_recall:.2f} ± {std_recall:.2f}")
    print(f"Class {label} - Average F1 Score: {avg_f1:.2f} ± {std_f1:.2f}")
# Out:
# Found 1935 images belonging to 3 classes.
# Found 605 images belonging to 3 classes.
# Found 484 images belonging to 3 classes.
# Training fold 0
# Class index 0: Weight 1.15
# Class index 1: Weight 1.37
# Class index 2: Weight 0.71
# Total parameters: 5364390
# Trainable parameters: 1370869
# Non-trainable parameters: 3993521
# Epoch 1/30
# 61/61 [==============================] - 69s 762ms/step - loss: 1.3950 - accuracy: 0.7034 - auc_6: 0.8615 - val_loss: 1.1682 - val_accuracy: 0.7128 - val_auc_6: 0.8645
# Epoch 2/30
# 61/61 [==============================] - 46s 752ms/step - loss: 0.7522 - accuracy: 0.8258 - auc_6: 0.9476 - val_loss: 0.6692 - val_accuracy: 0.8182 - val_auc_6: 0.9440
# Epoch 3/30
# 61/61 [==============================] - 47s 748ms/step - loss: 0.5612 - accuracy: 0.8636 - auc_6: 0.9657 - val_loss: 0.5351 - val_accuracy: 0.8409 - val_auc_6: 0.9603
# Epoch 4/30
# 61/61 [==============================] - 37s 598ms/step - loss: 0.4961 - accuracy: 0.8667 - auc_6: 0.9711 - val_loss: 0.6198 - val_accuracy: 0.8657 - val_auc_6: 0.9585
# Epoch 5/30
# 61/61 [==============================] - 41s 670ms/step - loss: 0.3882 - accuracy: 0.8868 - auc_6: 0.9792 - val_loss: 0.3451 - val_accuracy: 0.8843 - val_auc_6: 0.9816
# Epoch 6/30
# 61/61 [==============================] - 42s 694ms/step - loss: 0.3728 - accuracy: 0.9049 - auc_6: 0.9821 - val_loss: 0.2908 - val_accuracy: 0.9236 - val_auc_6: 0.9867
# Epoch 7/30
# 61/61 [==============================] - 46s 744ms/step - loss: 0.3663 - accuracy: 0.9070 - auc_6: 0.9833 - val_loss: 0.4433 - val_accuracy: 0.8926 - val_auc_6: 0.9754
# Epoch 8/30
# 61/61 [==============================] - 49s 796ms/step - loss: 0.3181 - accuracy: 0.9225 - auc_6: 0.9861 - val_loss: 0.3505 - val_accuracy: 0.9091 - val_auc_6: 0.9841
# Epoch 9/30
# 61/61 [==============================] - 44s 710ms/step - loss: 0.2869 - accuracy: 0.9214 - auc_6: 0.9875 - val_loss: 0.1300 - val_accuracy: 0.9649 - val_auc_6: 0.9972
# Epoch 10/30
# 61/61 [==============================] - 51s 842ms/step - loss: 0.2438 - accuracy: 0.9370 - auc_6: 0.9904 - val_loss: 0.1412 - val_accuracy: 0.9607 - val_auc_6: 0.9965
# Epoch 11/30
# 11/61 [====>.........................] - ETA: 24s - loss: 0.2201 - accuracy: 0.9254 - auc_6: 0.9911
